# %%
import pandas as pd

# %%
file = 'data/Library_Usage.csv'

# %%
file_df = pd.read_csv(file)
# Out:
# /tmp/ipykernel_9066/1860407902.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_df = pd.read_csv(file)

# %%
file_df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# ...

# %%
file_df['Year Patron Registered'].describe()
# Out:
# count    436290.000000
# mean       2015.598327
# std           6.148953
# min        2003.000000
# 25%        2012.000000
# 50%        2017.000000
# 75%        2021.000000
# max        2023.000000
# Name: Year Patron Registered, dtype: float64
