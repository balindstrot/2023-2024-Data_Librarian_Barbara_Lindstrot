# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../data/Library_Usage.csv")
# Out:
# /tmp/ipykernel_3465/1253275998.py:3: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")

# %%
df.set_index('Circulation Active Year')
# Out:
#                          Patron Type Code Patron Type Definition  \
# Circulation Active Year
# 2023.0                                  5                  Staff
# 2023.0                                  5                  Staff
# 2023.0                                  5                  Staff
# 2023.0                                  5                  Staff
# 2023.0                                  5                  Staff
# ...                                   ...                    ...
# 2022.0                                  0                  Adult
# 2015.0                                  2                   Teen
# 2022.0                                  0                  Adult
# 2020.0                                 15           Teacher Card
# 2023.0                                 55          Retired Staff
#
#                          Total Checkouts  Total Renewals          Age Range  \
# Circulation Active Year
# ...

# %%
df.loc[df['Total Checkouts'] > 2000]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 3                      5                  Staff             3934
# 5                      5                  Staff             2635
# 13                     5                  Staff             2917
# 22                     5                  Staff             2053
# 179                    0                  Adult             4806
# ...                  ...                    ...              ...
# 436038                 0                  Adult             2047
# 436081                 3                 Senior             2750
# 436184                 5                  Staff             5315
# 436185                 5                  Staff             3883
# 436211                 5                  Staff             2933
#
#         Total Renewals       Age Range Home Library Code  \
# 3                 2140             NaN                o2
# 5                 4075  45 to 54 years                w2
# ...

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# ...

# %%
row_filter_10_younger = df['Age Range'] == '0 to 9 years'
df.loc[row_filter_10_younger]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 39                     1               Juvenile              108
# 45                     1               Juvenile                0
# 47                     1               Juvenile               48
# 60                     1               Juvenile                0
# 86                     1               Juvenile                0
# ...                  ...                    ...              ...
# 436151                 1               Juvenile                0
# 436164                 1               Juvenile                0
# 436176                 1               Juvenile                7
# 436253                 1               Juvenile                0
# 436281                 1               Juvenile                1
#
#         Total Renewals     Age Range Home Library Code  \
# 39                 108  0 to 9 years                o7
# 45                   0  0 to 9 years                 x
# ...

# %% [markdown]
# Aufgabe Nr. 3 siehe Notebook "2-5_Fallstudie"

# %%
row_filter_Richmond = df['Home Library Definition'] == 'Richmond'
df.loc[row_filter_Richmond]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 42                    10                Visitor                9
# 53                     0                  Adult              838
# 83                     0                  Adult                1
# 118                    4                Welcome                0
# 163                   10                Visitor               27
# ...                  ...                    ...              ...
# 435822                16    Digital Access Card                0
# 435823                 1               Juvenile                3
# 435824                 4                Welcome                0
# 435825                 1               Juvenile                3
# 435826                 3                 Senior                0
#
#         Total Renewals          Age Range Home Library Code  \
# 42                   5     45 to 54 years                r3
# 53                 382     55 to 59 years                r3
# ...

# %% [markdown]
# Aufgaben zu Quiz:

# %%
filter_aktiv_alter = ((df['Age Range'] == '60 to 64 years') & (df['Circulation Active Year'] == 2016))
df.loc[filter_aktiv_alter].count()
# Out:
# Patron Type Code                19
# Patron Type Definition          19
# Total Checkouts                 19
# Total Renewals                  19
# Age Range                       19
# Home Library Code               19
# Home Library Definition         19
# Circulation Active Month        19
# Circulation Active Year         19
# Notice Preference Code          17
# Notice Preference Definition    17
# Provided Email Address          19
# Year Patron Registered          19
# Within San Francisco County     19
# dtype: int64

# %%
count_NaN = df['Age Range'].isna().sum()

# %%
count_NaN
# Out:
# 912

# %%
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 15813                  0                  Adult               21
# 48288                  0                  Adult               13
# 56716                  0                  Adult               81
# 130257                 0                  Adult               70
# 166476                 0                  Adult               53
# 176068                 0                  Adult                9
# 235929                 0                  Adult                2
# 254518                 0                  Adult               80
# 273630                 0                  Adult              431
# 291507                 0                  Adult              221
# 297673                 0                  Adult             2408
# 302637                 0                  Adult               12
# 303489                 0                  Adult                1
# ...
