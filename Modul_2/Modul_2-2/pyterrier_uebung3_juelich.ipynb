# %%
pip install python-terrier
# Out:
# Requirement already satisfied: python-terrier in /home/barbara/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: numpy in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (1.24.3)
# Requirement already satisfied: pandas in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (2.0.3)
# Requirement already satisfied: wget in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (3.2)
# Requirement already satisfied: tqdm in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (4.65.0)
# Requirement already satisfied: pyjnius>=1.4.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (1.6.1)
# Requirement already satisfied: matchpy in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: scikit-learn in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (1.3.0)
# Requirement already satisfied: deprecated in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (1.2.14)
# Requirement already satisfied: chest in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: scipy in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (1.10.1)
# Requirement already satisfied: requests in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (1.2.0)
# Requirement already satisfied: nptyping==1.4.4 in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (1.4.4)
# Requirement already satisfied: more-itertools in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (8.12.0)
# Requirement already satisfied: ir-datasets>=0.3.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: jinja2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: statsmodels in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (0.14.0)
# Requirement already satisfied: ir-measures>=0.3.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (0.3.3)
# Requirement already satisfied: dill in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (0.3.6)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied: typish>=1.7.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.12.2)
# Requirement already satisfied: inscriptis>=2.2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (2.4.0.1)
# Requirement already satisfied: lxml>=4.5.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.9.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.6)
# Requirement already satisfied: ijson>=3.1.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (3.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /home/barbara/anaconda3/lib/python3.8/site-packages (from ir-measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests->python-terrier) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests->python-terrier) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests->python-terrier) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests->python-terrier) (2023.11.17)
# Requirement already satisfied: heapdict in /home/barbara/anaconda3/lib/python3.8/site-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/barbara/anaconda3/lib/python3.8/site-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jinja2->python-terrier) (2.1.3)
# Requirement already satisfied: multiset<3.0,>=2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from pandas->python-terrier) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from scikit-learn->python-terrier) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from statsmodels->python-terrier) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from statsmodels->python-terrier) (23.1)
# Requirement already satisfied: soupsieve>1.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.5)
# Requirement already satisfied: six in /home/barbara/anaconda3/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/barbara/anaconda3/lib/python3.8/site-packages (3.8.1)
# Requirement already satisfied: click in /home/barbara/anaconda3/lib/python3.8/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/barbara/anaconda3/lib/python3.8/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /home/barbara/anaconda3/lib/python3.8/site-packages (from nltk) (4.65.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyterrier as pt
import requests
import pandas as pd
import pickle
import nltk
import numpy as np

# %%
query = "Jülich"
url = f"https://www.bibsonomy.org/json/search/{query}?items=1000"

# %%
res = requests.get(url)

# %%
data = res.json()

# %%
data
# Out:
# {'types': {'Bookmark': {'pluralLabel': 'Bookmarks'},
#   'Publication': {'pluralLabel': 'Publications'},
#   'GoldStandardPublication': {'pluralLabel': 'GoldStandardPublications'},
#   'GoldStandardBookmark': {'pluralLabel': 'GoldStandardBookmarks'},
#   'Tag': {'pluralLabel': 'Tags'},
#   'User': {'pluralLabel': 'Users'},
#   'Group': {'pluralLabel': 'Groups'},
#   'Sphere': {'pluralLabel': 'Spheres'}},
#  'properties': {'count': {'valueType': 'number'},
#   'date': {'valueType': 'date'},
#   'changeDate': {'valueType': 'date'},
#   'url': {'valueType': 'url'},
#   'id': {'valueType': 'url'},
#   'tags': {'valueType': 'item'},
#   'user': {'valueType': 'item'}},
#  'items': [{'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/e5557907b1206e81eb5d65bf5758fb5d/alberska',
#    'tags': ['inm',
#     'ethic',
#     'studies',
#     'medical_imaging',
#     'institute',
#     'internship',
#     'neurocience',
#     'cognitive_neurosciences',
#     'research'],
#    'intraHash': 'e5557907b1206e81eb5d65bf5758fb5d',
#    'label': 'Forschungszentrum Jülich - INM',
#    'user': 'alberska',
#    'description': 'Institut für Neurowissenschaften und Medizin - Jülich Forschungszentrum.',
#    'date': '2018-12-12 22:27:23',
#    'changeDate': '2018-12-12 22:29:52',
#    'count': 1,
#    'url': 'http://www.fz-juelich.de/inm/DE/Home/home_node.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f6ac83276c20b9aecaa6a6fa786cce40/torstenschuenemann',
#    'tags': ['Innovation', 'Lernwerkstatt', 'LW1'],
#    'intraHash': 'f6ac83276c20b9aecaa6a6fa786cce40',
#    'label': 'heise online - RWTH Aachen und Forschungszentrum Jülich kooperieren',
#    'user': 'torstenschuenemann',
#    'description': 'RWTH Aachen und Forschungszentrum Jülich kooperieren',
#    'date': '2007-08-06 18:02:08',
#    'changeDate': '2008-06-01 22:04:56',
#    'count': 1,
#    'url': 'http://www.heise.de/newsticker/meldung/93915/from/rss09'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/e8161c5dc17bb1c9376898c37756c1a8/schmidt2',
#    'tags': ['jülich',
#     'forschungszentrum',
#     'bottleneck',
#     'phenotyping',
#     'phänotypisierung'],
#    'intraHash': 'e8161c5dc17bb1c9376898c37756c1a8',
#    'label': 'Forschungszentrum Jülich - Forschung - Phänotypisierung',
#    'user': 'schmidt2',
#    'description': 'Phänotypisierung ist die quantitative Analyse pflanzlicher Strukturen und Funktionen. Die quantitative Analyse von strukturellen und funktionellen Eigenschaften ist der Schlüssel, mit dem Grundlagenwissen in die Praxis von Landwirtschaft, aber auch in die ökologische Forschung überführt wird. In der Grundlagenforschung ist die Phänotypisierung das bottle-neck für Erkenntnisgewinn in der funktionellen Genomforschung.',
#    'date': '2013-02-13 15:55:45',
#    'changeDate': '2013-02-13 15:55:45',
#    'count': 1,
#    'url': 'https://www.fz-juelich.de/ibg/ibg-2/DE/Forschung/Ph%C3%A4notypisierung/artikel.html?nn=548268'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/ce228a1fd03d4ca5b798187e650f9d55/schmidt2',
#    'tags': ['jülich', 'jppc', 'phenotyping'],
#    'intraHash': 'ce228a1fd03d4ca5b798187e650f9d55',
#    'label': 'JPPC: the Jülich Plant Phenotyping Centre at the Forschungszentrum Jülich ICG-3 - Phytosphere',
#    'user': 'schmidt2',
#    'description': '',
#    'date': '2011-09-22 13:45:30',
#    'changeDate': '2011-09-22 13:48:48',
#    'count': 1,
#    'url': 'http://www2.fz-juelich.de/icg/icg-3/jppc'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/0ac911d2dc1c1db4e66681f544205e13/schmidt2',
#    'tags': ['jülich', 'forschungszentrum', 'whitepaper', 'phenotyping'],
#    'intraHash': '0ac911d2dc1c1db4e66681f544205e13',
#    'label': 'Forschungszentrum Jülich - White Paper Phenotyping (2009)',
#    'user': 'schmidt2',
#    'description': '',
#    'date': '2013-02-13 15:56:06',
#    'changeDate': '2013-02-13 15:56:06',
#    'count': 1,
#    'url': 'https://www.fz-juelich.de/ibg/ibg-2/DE/_SharedDocs/Dokumente/2009%20White%20Paper%20Phenotyping/_node.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/8aef4d1d71e4d0cf89c6de848cc8d557/vitelot',
#    'tags': ['Chrome', 'stack', 'Bookmarks_Bar'],
#    'intraHash': '8aef4d1d71e4d0cf89c6de848cc8d557',
#    'label': 'Young Investigators Group Leader - Forschungszentrum Jülich | Academic Positions Europe',
#    'user': 'vitelot',
#    'description': '',
#    'date': '2017-08-14 13:30:39',
#    'changeDate': '2017-08-14 13:43:37',
#    'count': 1,
#    'url': 'http://academicpositions.eu/ad/forschungszentrum-julich/2015/young-investigators-group-leader/60012/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/dab6f0c6641226f2fa25f30dd284dedc/danilola',
#    'tags': ['bibliothek',
#     'schule',
#     'bibinalert',
#     'angebot',
#     'deutschlandliest',
#     'benutzer_in',
#     'öb',
#     'aktion'],
#    'intraHash': 'dab6f0c6641226f2fa25f30dd284dedc',
#    'label': 'AZ-Web.de - Schüler finden in Stadtbücherei Jülich ihren Platz',
#    'user': 'danilola',
#    'description': 'Jülich. Nach dem erfolgreichen Jahr 2008, in dem die Stadtbücherei Jülicher Leseratten zahlreiche aufregende Aktionen rund um Bücher und Literatur bot, hat ihr Leiter, Werner Wieczoreck, eine positive Bilanz gezogen.  Besonders die Aktion «Deutschland liest sei sehr gut angekommen.',
#    'date': '2009-01-27 07:37:39',
#    'changeDate': '2009-07-16 18:14:35',
#    'count': 1,
#    'url': 'http://www.az-web.de/lokales/juelich-detail-az/792817?_link=&skip=&_g=Schueler-finden-in-Stadtbuecherei-Juelich-ihren-Platz.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/d8287ab5eaafea553c4e0b0a4b952da9/flimm',
#    'tags': ['kinder'],
#    'intraHash': 'd8287ab5eaafea553c4e0b0a4b952da9',
#    'label': 'Brückenkopf-Park Jülich',
#    'user': 'flimm',
#    'description': '',
#    'date': '2010-04-06 13:05:11',
#    'changeDate': '2010-04-06 13:05:11',
#    'count': 1,
#    'url': 'http://www.brueckenkopf-park.de/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/524cd4378bf6be541d8a3835d42445b7/anabas',
#    'tags': ['web2.0', 'library2.0', 'del.icio.us', 'social_media'],
#    'intraHash': '524cd4378bf6be541d8a3835d42445b7',
#    'label': 'Delicious am FZ Jülich',
#    'user': 'anabas',
#    'description': '',
#    'date': '2010-08-30 13:43:48',
#    'changeDate': '2010-09-23 14:43:50',
#    'count': 1,
#    'url': 'http://www.fz-juelich.de/zb/datapool/general/tutorial_delicious_praesentation.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a477450f82d7967c9f8a73a9d57a8545/sjanzen',
#    'tags': ['materials'],
#    'intraHash': 'a477450f82d7967c9f8a73a9d57a8545',
#    'label': 'Projektträger Jülich Werkstofftechnologien',
#    'user': 'sjanzen',
#    'description': '',
#    'date': '2011-11-10 15:01:50',
#    'changeDate': '2011-11-11 08:48:54',
#    'count': 1,
#    'url': 'http://www.fz-juelich.de/ptj/werkstofftechnologien'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/922a7fe7d8f824f8d7ac292d6434ae5e/maier',
#    'tags': ['eLearning'],
#    'intraHash': '922a7fe7d8f824f8d7ac292d6434ae5e',
#    'label': 'GoInfo: Online-Tutorial FZ Jülich',
#    'user': 'maier',
#    'description': '',
#    'date': '2008-08-25 16:11:09',
#    'changeDate': '2008-08-25 16:11:10',
#    'count': 1,
#    'url': 'http://wwwzb.zb.kfa-juelich.de/goinfo/inhalt.htm'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/4e101d8db00d532b775529b4d8e4254c/robingarcia',
#    'tags': ['Weitere_Lesezeichen'],
#    'intraHash': '4e101d8db00d532b775529b4d8e4254c',
#    'label': 'Projektträger Jülich: Systemmedizin der Leber - LiSyM',
#    'user': 'robingarcia',
#    'description': '',
#    'date': '2017-03-17 10:35:12',
#    'changeDate': '2017-04-13 10:01:50',
#    'count': 1,
#    'url': 'https://www.ptj.de/lisym'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/980c4f1ebb929d9e3afb25a5cfbeada5/danilola',
#    'tags': ['kinder',
#     'leitung',
#     'bibliothek',
#     'schule',
#     'bibinalert',
#     'personal',
#     'angebot',
#     '2009-02',
#     'kooperation',
#     'leseförderung',
#     'öb',
#     'stadtbibliothek'],
#    'intraHash': '980c4f1ebb929d9e3afb25a5cfbeada5',
#    'label': 'Das JüLichT - Stadtteile: Stadtbücherei Jülich plant Lesecafé, Theatergruppe und School Corner',
#    'user': 'danilola',
#    'description': 'Von seiner besten Seite zeigt sich der neue Leiter der Jülicher Stadtbücherei Werner Wieczorek: Ein erfolgreiches erstes Jahr liegt hinter ihm. Auch, wenn der Bibliothekar auf die gute Arbeit seiner Vorgängerin Christa Bartels bauen konnte, stellt er seine eigenen Weichen.',
#    'date': '2009-02-15 10:01:25',
#    'changeDate': '2009-07-16 18:14:24',
#    'count': 1,
#    'url': 'http://www.das-juelicht.de/nachrichten/artikel/8400.php'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9220d5e71e2f2cceed6b0bffc5087917/a_olympia',
#    'tags': ['aachen', 'j'],
#    'intraHash': '9220d5e71e2f2cceed6b0bffc5087917',
#    'label': 'heise online - RWTH Aachen und Forschungszentrum Jülich kooperieren',
#    'user': 'a_olympia',
#    'description': '',
#    'date': '2007-08-06 21:53:41',
#    'changeDate': '2007-08-18 13:01:15',
#    'count': 1,
#    'url': 'http://www.heise.de/newsticker/meldung/93915'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/dc6fc99e2644a226b740c4b154b7f309/schmidt2',
#    'tags': ['overview', 'technologies', 'jppc'],
#    'intraHash': 'dc6fc99e2644a226b740c4b154b7f309',
#    'label': 'ICG-3 JPPC-Jülich Plant Phenotyping Centre: technologies for plant phenotyping',
#    'user': 'schmidt2',
#    'description': '',
#    'date': '2011-09-22 13:47:04',
#    'changeDate': '2011-09-22 13:48:40',
#    'count': 1,
#    'url': 'http://www2.fz-juelich.de/icg/icg-3/jppc/methods'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f4e405abc3e878a4b48f83f1b70dc947/schmidt2',
#    'tags': ['2009', 'slides', 'workshop', 'epso', 'jppc'],
#    'intraHash': 'f4e405abc3e878a4b48f83f1b70dc947',
#    'label': 'Jülich Plant Phenotyping Centre - JPPC - EPSO Workshop 2009 on Plant Phenotyping',
#    'user': 'schmidt2',
#    'description': '',
#    'date': '2011-09-22 13:53:29',
#    'changeDate': '2011-09-22 13:53:29',
#    'count': 1,
#    'url': 'http://www.plantphenomics.com/phenotyping2009/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f2a9dd3e4de40be3fec437bcc963547b/swatschi',
#    'tags': ['lv_wisskomm', 'conference', 'theory'],
#    'intraHash': 'f2a9dd3e4de40be3fec437bcc963547b',
#    'label': 'JUWEL - Volltextserver des Forschungszentrums Jülich: Item 2128/2893',
#    'user': 'swatschi',
#    'description': '',
#    'date': '2008-03-13 17:10:03',
#    'changeDate': '2008-03-13 17:10:03',
#    'count': 2,
#    'url': 'http://juwel.fz-juelich.de:8080/dspace/handle/2128/2893'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/c2ca92adaf56a3e73eb31a138af7cd53/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'c2ca92adaf56a3e73eb31a138af7cd53',
#    'label': 'Home Page of Bin A. Wang and Bin Wang',
#    'user': 'dblp',
#    'description': 'homepages/193/8273,\nBin A. Wang and Bin Wang, Home Page, https://www.wikidata.org/entity/Q87293810, Research Centre Jülich, Institute of Neuroscience and Medicine, Jülich, Germany',
#    'date': '2020-09-09 15:20:09',
#    'changeDate': '2020-09-09 15:20:09',
#    'count': 1,
#    'url': 'https://www.wikidata.org/entity/Q87293810'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f3a456f8900d2a3976fdf0bc73c36b8c/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'f3a456f8900d2a3976fdf0bc73c36b8c',
#    'label': 'Home Page of Tao Liu',
#    'user': 'dblp',
#    'description': 'homepages/43/656-15,\nTao Liu, Home Page, https://www.researchgate.net/profile/Tao_Liu142, Forschungszentrum Jülich, Germany',
#    'date': '2020-05-21 11:59:32',
#    'changeDate': '2020-05-21 11:59:32',
#    'count': 1,
#    'url': 'https://www.researchgate.net/profile/Tao_Liu142'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/258e8e47d605fa39f4aa11bcd4aa53ce/dblp',
#    'tags': ['dblp'],
#    'intraHash': '258e8e47d605fa39f4aa11bcd4aa53ce',
#    'label': 'Home Page of Stefanie Haustein',
#    'user': 'dblp',
#    'description': 'homepages/03/9465,\nStefanie Haustein, Home Page, https://id.loc.gov/authorities/names/n2012030867, Forschungszentrum Jülich',
#    'date': '2020-09-19 12:14:33',
#    'changeDate': '2020-09-19 12:14:33',
#    'count': 1,
#    'url': 'https://id.loc.gov/authorities/names/n2012030867'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/eca54bd2d962d4083b375fda5817fccf/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'eca54bd2d962d4083b375fda5817fccf',
#    'label': 'Home Page of Markus Diesmann',
#    'user': 'dblp',
#    'description': 'homepages/95/5761,\nMarkus Diesmann, Home Page, https://www.researcherid.com/rid/H-3722-2013, Forschungszentrum Jülich, Germany',
#    'date': '2019-01-11 12:22:58',
#    'changeDate': '2019-01-11 12:22:58',
#    'count': 1,
#    'url': 'https://www.researcherid.com/rid/H-3722-2013'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/54724b5ef62f14310e8de375534bf047/dblp',
#    'tags': ['dblp'],
#    'intraHash': '54724b5ef62f14310e8de375534bf047',
#    'label': 'Home Page of Felix Fischer',
#    'user': 'dblp',
#    'description': 'homepages/f/FelixFischer,\nFelix Fischer, Home Page, http://www.medizinischeinformatik.fh-aachen.de/mitarbeiter/fischer.html, FH Aachen, Jülich, Germany',
#    'date': '2020-07-31 11:53:58',
#    'changeDate': '2020-07-31 11:53:58',
#    'count': 1,
#    'url': 'http://www.medizinischeinformatik.fh-aachen.de/mitarbeiter/fischer.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/1ca7444f8be0af3a515a07906ab216e7/dblp',
#    'tags': ['dblp'],
#    'intraHash': '1ca7444f8be0af3a515a07906ab216e7',
#    'label': 'Home Page of Edoardo Di Napoli',
#    'user': 'dblp',
#    'description': 'homepages/10/7481,\nEdoardo Di Napoli, Home Page, https://www.mendeley.com/profiles/edoardo-di-napoli//, Forschungszentrum Jülich, Germany',
#    'date': '2020-09-19 12:06:58',
#    'changeDate': '2020-09-19 12:06:58',
#    'count': 1,
#    'url': 'https://www.mendeley.com/profiles/edoardo-di-napoli//'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/fe3fc71c28b5ebeb8dce4c1019c47e44/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'fe3fc71c28b5ebeb8dce4c1019c47e44',
#    'label': 'Home Page of Martin G. Schultz',
#    'user': 'dblp',
#    'description': 'homepages/132/0161,\nMartin G. Schultz, Home Page, https://www.researcherid.com/rid/I-9512-2012, Forschungszentrum Jülich GmbH, Germany',
#    'date': '2019-01-11 13:09:23',
#    'changeDate': '2019-01-11 13:09:23',
#    'count': 1,
#    'url': 'https://www.researcherid.com/rid/I-9512-2012'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a5ab39edc55614340c35d1c6608d6ff0/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'a5ab39edc55614340c35d1c6608d6ff0',
#    'label': 'Home Page of Lukas Arnold',
#    'user': 'dblp',
#    'description': 'homepages/49/1004,\nLukas Arnold, Home Page, https://orcid.org/0000-0002-5939-8995, Jülich Supercomputing Centre, Germany',
#    'date': '2017-12-08 02:29:41',
#    'changeDate': '2017-12-08 02:29:41',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0002-5939-8995'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/67ab87e8af4f4d68bbd9e235ea055c1d/dblp',
#    'tags': ['dblp'],
#    'intraHash': '67ab87e8af4f4d68bbd9e235ea055c1d',
#    'label': 'Home Page of Dirk Pleiter',
#    'user': 'dblp',
#    'description': 'homepages/70/3241,\nDirk Pleiter, Home Page, https://orcid.org/0000-0001-7296-7817, Jülich Supercomputing Centre, Germany',
#    'date': '2019-10-03 11:39:57',
#    'changeDate': '2019-10-03 11:39:57',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0001-7296-7817'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/4da3bf4844498b9a2cf830bc5665fbe5/dblp',
#    'tags': ['dblp'],
#    'intraHash': '4da3bf4844498b9a2cf830bc5665fbe5',
#    'label': 'Home Page of Thomas Meyer',
#    'user': 'dblp',
#    'description': 'homepages/m/ThomasMeyer5,\nThomas Meyer, Home Page, https://orcid.org/0000-0002-6582-1278, Forschungszentrum Jülich, Institute of Bio- and Geosciences, Germany',
#    'date': '2018-12-20 11:39:54',
#    'changeDate': '2018-12-20 11:39:54',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0002-6582-1278'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/1d18e6e369fc5eb4b76aa2300778b062/dblp',
#    'tags': ['dblp'],
#    'intraHash': '1d18e6e369fc5eb4b76aa2300778b062',
#    'label': 'Home Page of Christian Wagner',
#    'user': 'dblp',
#    'description': 'homepages/01/2903-7,\nChristian Wagner, Home Page, https://d-nb.info/gnd/1166883922, FZ Jülich, Peter Grünberg Institute (PGI), Germany',
#    'date': '2020-05-20 12:01:23',
#    'changeDate': '2020-05-20 12:01:23',
#    'count': 1,
#    'url': 'https://d-nb.info/gnd/1166883922'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/739dacb2bccf76c8b736cec405918a9e/dblp',
#    'tags': ['dblp'],
#    'intraHash': '739dacb2bccf76c8b736cec405918a9e',
#    'label': 'Home Page of Alexander Grünberger and Alexander Manuel Grünberger',
#    'user': 'dblp',
#    'description': 'homepages/136/0886,\nAlexander Grünberger and Alexander Manuel Grünberger, Home Page, https://gepris.dfg.de/gepris/person/420450975, Jülich Research Centre, Germany',
#    'date': '2020-12-01 11:40:07',
#    'changeDate': '2020-12-01 11:40:07',
#    'count': 1,
#    'url': 'https://gepris.dfg.de/gepris/person/420450975'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a21d1d0d2b7498fbbb10a02e0b4e3e22/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'a21d1d0d2b7498fbbb10a02e0b4e3e22',
#    'label': 'Home Page of Simon B. Eickhoff',
#    'user': 'dblp',
#    'description': 'homepages/03/7228,\nSimon B. Eickhoff, Home Page, https://d-nb.info/gnd/132476576, Research Centre Jülich, Institute of Neuroscience and Medicine, Germany',
#    'date': '2019-01-11 12:30:00',
#    'changeDate': '2019-01-11 12:30:00',
#    'count': 1,
#    'url': 'https://d-nb.info/gnd/132476576'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/c889ca8ca097b5e912f1c67d59deecf0/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'c889ca8ca097b5e912f1c67d59deecf0',
#    'label': 'Home Page of Marc-André Hermanns',
#    'user': 'dblp',
#    'description': 'homepages/84/1090,\nMarc-André Hermanns, Home Page, https://www.linkedin.com/in/marcandrehermanns/, Research Centre Jülich, Central Institute for Applied Mathematics, Germany',
#    'date': '2020-11-28 11:40:09',
#    'changeDate': '2020-11-28 11:40:09',
#    'count': 1,
#    'url': 'https://www.linkedin.com/in/marcandrehermanns/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/efe69d268c7b2a0896e0072c297c8145/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'efe69d268c7b2a0896e0072c297c8145',
#    'label': 'Home Page of Qi Tang',
#    'user': 'dblp',
#    'description': 'homepages/40/4498-4,\nQi Tang, Home Page, https://orcid.org/0000-0002-2109-7935, Forschungszentrum Jülich, Institute of Bio- and Geosciences, Germany',
#    'date': '2018-01-31 11:45:28',
#    'changeDate': '2018-01-31 11:45:28',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0002-2109-7935'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/e68bd6093727e93489f9c5290ba91ff7/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'e68bd6093727e93489f9c5290ba91ff7',
#    'label': 'Home Page of Ahmed Shiraz Memon and A. Shiraz Memon',
#    'user': 'dblp',
#    'description': 'homepages/79/3774,\nAhmed Shiraz Memon and A. Shiraz Memon, Home Page, https://orcid.org/0000-0001-6500-8968, Jülich Supercomputing Centre, Germany',
#    'date': '2019-09-27 11:42:10',
#    'changeDate': '2019-09-27 11:42:10',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0001-6500-8968'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/414b98caf7af02698dd5750d4ae4c524/dblp',
#    'tags': ['dblp'],
#    'intraHash': '414b98caf7af02698dd5750d4ae4c524',
#    'label': 'Home Page of Stephan Graf',
#    'user': 'dblp',
#    'description': 'homepages/36/2912-2,\nStephan Graf, Home Page, https://www.fz-juelich.de/SharedDocs/Personen/IAS/JSC/EN/staff/graf_st.html, Forschungszentrum Jülich, Germany',
#    'date': '2016-12-03 11:34:45',
#    'changeDate': '2016-12-03 11:34:45',
#    'count': 1,
#    'url': 'https://www.fz-juelich.de/SharedDocs/Personen/IAS/JSC/EN/staff/graf_st.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/3e60dcc512fc92b587799bd39ee70653/dblp',
#    'tags': ['dblp'],
#    'intraHash': '3e60dcc512fc92b587799bd39ee70653',
#    'label': 'Home Page of Piotr M. Kowalski',
#    'user': 'dblp',
#    'description': 'homepages/146/8462,\nPiotr M. Kowalski, Home Page, https://www.researcherid.com/rid/L-7411-2013, Forschungszentrum Jülich, Institute of Energy & Climate Research, Germany',
#    'date': '2020-05-20 11:55:31',
#    'changeDate': '2020-05-20 11:55:31',
#    'count': 1,
#    'url': 'https://www.researcherid.com/rid/L-7411-2013'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/2083ce92cb0db7037f5df57d2767c12e/dblp',
#    'tags': ['dblp'],
#    'intraHash': '2083ce92cb0db7037f5df57d2767c12e',
#    'label': 'Home Page of Andreas Bauer',
#    'user': 'dblp',
#    'description': 'homepages/116/1833-5,\nAndreas Bauer, Home Page, https://www.scopus.com/authid/detail.uri?authorId=56673523600, Research Centre Jülich, Institute of Neuroscience and Medicine, Germany',
#    'date': '2019-01-11 11:42:10',
#    'changeDate': '2019-01-11 11:42:10',
#    'count': 1,
#    'url': 'https://www.scopus.com/authid/detail.uri?authorId=56673523600'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/0b5472ce59e2f9a5e6919c0a0a8899a1/dblp',
#    'tags': ['dblp'],
#    'intraHash': '0b5472ce59e2f9a5e6919c0a0a8899a1',
#    'label': 'Home Page of Frank Boers and Franks Boers',
#    'user': 'dblp',
#    'description': 'homepages/37/11401,\nFrank Boers and Franks Boers, Home Page, http://www.fz-juelich.de/SharedDocs/Kontaktdaten/Mitarbeiter/B/Boers_f_boers_fz_juelich_de.html?nn=573170, Research Centre Jülich, Institute of Neuroscience and Medicine',
#    'date': '2017-01-07 11:39:11',
#    'changeDate': '2017-01-07 11:39:11',
#    'count': 1,
#    'url': 'http://www.fz-juelich.de/SharedDocs/Kontaktdaten/Mitarbeiter/B/Boers_f_boers_fz_juelich_de.html?nn=573170'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/7774ab21ecab00f03a8346e42b5b2bf0/calidius',
#    'tags': ['Zürich', 'Hotel'],
#    'intraHash': '7774ab21ecab00f03a8346e42b5b2bf0',
#    'label': 'Hotel Rex',
#    'user': 'calidius',
#    'description': 'Hotels in Zürich: Hotel Rex Zürich / Arte in Spreitenbach / Sonnental in Dübendorf',
#    'date': '2006-10-31 09:31:27',
#    'changeDate': '2013-03-02 20:19:46',
#    'count': 1,
#    'url': 'http://www.zuerich-hotels.ch/hotel_rex/hotel.php'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/afaa7dabf30f0d8b375f2f18fb4a0535/novaesium',
#    'tags': ['Museum', 'Zülpich', 'Thermen'],
#    'intraHash': 'afaa7dabf30f0d8b375f2f18fb4a0535',
#    'label': 'Römerthermen Zülpich',
#    'user': 'novaesium',
#    'description': 'Internetseiten der Römerthermen Zülpich - Museum der Badekultur.',
#    'date': '2009-05-14 23:44:11',
#    'changeDate': '2009-05-14 23:47:01',
#    'count': 1,
#    'url': 'http://www.zuelpich.de/index.php?option=com_content&view=article&id=437&Itemid=100068'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9b7b04c2547d0d5b6df63b0e4de9382f/ksteitz',
#    'tags': ['docendo', 'Zürich', 'ETH', 'KOM', 'WBT', 'elc', 'Tittel', 'Blog'],
#    'intraHash': '9b7b04c2547d0d5b6df63b0e4de9382f',
#    'label': 'docendo blog',
#    'user': 'ksteitz',
#    'description': 'Blog der ETH Zürich zu docendo',
#    'date': '2010-05-10 09:58:43',
#    'changeDate': '2011-01-31 15:25:50',
#    'count': 1,
#    'url': 'http://blogs.ethz.ch/docendo/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a4868b938c2f172eaac21c4702bca7e4/mauszfabrick',
#    'tags': ['ch', 'literatur', 'uschtrinneu', 'zürich'],
#    'intraHash': 'a4868b938c2f172eaac21c4702bca7e4',
#    'label': 'index wort und wirkung',
#    'user': 'mauszfabrick',
#    'description': 'ulrike ulrichs literatur/kulturgruppe, die vergeben auch stipendien in zürich',
#    'date': '2011-09-29 12:58:28',
#    'changeDate': '2011-09-29 12:58:28',
#    'count': 1,
#    'url': 'http://www.wortundwirkung.ch/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/6451c043c7bded740ef55b6ad44b6ff3/bibliothecaire',
#    'tags': ['illich'],
#    'intraHash': '6451c043c7bded740ef55b6ad44b6ff3',
#    'label': 'Alain Giffard: Lecture, mémoire, bibliothèque, lecture numérique',
#    'user': 'bibliothecaire',
#    'description': ' Une interprétation duDidascalicona été proposé récemment par Ivan Illich : «Du lisible au visible. Sur l’Art de lire de Hugues de Saint Victor ».   ',
#    'date': '2007-11-18 10:36:02',
#    'changeDate': '2007-11-29 18:19:12',
#    'count': 1,
#    'url': 'http://alaingiffard.blogs.com/culture/lecture_mmoire_bibliothque_lecture_numrique/page/2'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/c1b9cb7aa3cefb37e2c0dd1c47982d89/torstenschuenemann',
#    'tags': ['Hamburg/Lokal', 'Regionalfoerderung', 'Uni'],
#    'intraHash': 'c1b9cb7aa3cefb37e2c0dd1c47982d89',
#    'label': 'heise online - Deutsches Klimarechenzentrum investiert in neuen Supercomputer',
#    'user': 'torstenschuenemann',
#    'description': 'Um die Prognosen zukünftiger Klimaänderungen wesentlich genauer zu berechnen, investiert das Deutsche Klimarechenzentrum zu seinem 20-jährigen Bestehen in einen neuen Supercomputer. Er arbeitet mit Power6-Prozessoren von IBM und soll eine Spitzenleistung von 140 TFlop/s erreichen. Damit würde er sich in der Top500-Liste der Supercomputer auf Platz drei gleich hinter dem vom Forschungszentrum Jülich betriebenen JUGENE einreihen und zu den schnellsten zivil genutzten Supercomputern der Welt zählen.',
#    'date': '2007-12-16 18:14:08',
#    'changeDate': '2008-06-01 22:12:51',
#    'count': 1,
#    'url': 'http://www.heise.de/newsticker/meldung/100658/from/rss09'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9217a09989add6aeb29c1123b82e90c5/bibliothecaire',
#    'tags': ['illich'],
#    'intraHash': '9217a09989add6aeb29c1123b82e90c5',
#    'label': 'LISTSERV 15.0 - SHARP-L Archives',
#    'user': 'bibliothecaire',
#    'description': " My interest in the subject of books and print culture has beenguided largely by reading Ivan Illich, whose thinking I have beengrappling with for several years now. It was through him that Idiscovered Ong's Orality and Literacy, began to think about the",
#    'date': '2007-11-21 09:54:26',
#    'changeDate': '2007-11-29 18:19:10',
#    'count': 1,
#    'url': 'https://listserv.indiana.edu/cgi-bin/wa-iub.exe?A2=ind9408&L=SHARP-L&P=R2019'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/2cb76dc0ec5e842ce632174221b33bbb/novaesium',
#    'tags': ['Rheinland', 'Museum', 'Zülpich', 'Thermen', 'Landschaftsverband'],
#    'intraHash': '2cb76dc0ec5e842ce632174221b33bbb',
#    'label': 'Römerthermen Zülpich: LVR übernimmt Betriebsführung (Archäologie Online)',
#    'user': 'novaesium',
#    'description': 'Der Landschaftsverband Rheinland (LVR) wird zum 1. April die Betriebsführung in den Römerthermen Zülpich übernehmen. Im Museum unterzeichneten LVR-Direktor Harry K. Voigtsberger, der Zülpicher Bürgermeister Albert Bergmann sowie der Geschäftsführer des Fördervereins Zülpicher Geschichte und Kulturdenkmäler e.V., Helmut Limper nun den Kooperationsvertrag.',
#    'date': '2009-05-14 23:46:22',
#    'changeDate': '2009-05-14 23:46:22',
#    'count': 1,
#    'url': 'http://www.archaeologie-online.de/magazin/nachrichten/view/roemerthermen_zuelpich_lvr_uebernimmt_betriebsfuehrung/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/0f40018322eefae382a435db25b5f141/bibliothecaire',
#    'tags': ['content_management', 'illich'],
#    'intraHash': '0f40018322eefae382a435db25b5f141',
#    'label': 'LISTSERV 15.0 - SHARP-L Archives',
#    'user': 'bibliothecaire',
#    'description': ' "Media theorist Ivan Illich articulated an ideal\'conviviality\': the notion that it should be as easy to author in a mediumas it is to experience works created in it. I think we should keep thisideal at the front of our minds as we build the next generat',
#    'date': '2007-11-21 09:56:36',
#    'changeDate': '2007-11-29 18:19:10',
#    'count': 1,
#    'url': 'https://listserv.indiana.edu/cgi-bin/wa-iub.exe?A2=ind9312&L=SHARP-L&P=R1064'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f360dd91baa82aa4104526c87a0a0b76/danilola',
#    'tags': ['pdf',
#     'disziplin',
#     'transdisziplinarität',
#     'volltext',
#     'bericht',
#     'zürich',
#     'studium'],
#    'intraHash': 'f360dd91baa82aa4104526c87a0a0b76',
#    'label': 'tagensanzeiger zürich: Neuer Master in Transdiszipiinarität',
#    'user': 'danilola',
#    'description': 'Zürich. - Als sich vor einem guten Jahr die Hochschule für Gestaltung und Kunst und die Musikhochschule zur Zürcher Hochschule der Künste (ZHdK) zusammenschlossen, war viel von Transdisziplinarität die Rede, die man mit dieser Fusion fördern wolle. Was damit gemeint war, blieb einigermassen wolkig, und die Vermutung, dass das Schlagwort eines bleiben würde, lag nahe. Sie war falsch. Im nächsten Semester startet nun ein Master of Arts in Transdisziplinarität.',
#    'date': '2008-11-18 19:12:09',
#    'changeDate': '2009-07-16 18:15:24',
#    'count': 1,
#    'url': 'http://trans.zhdk.ch/fileadmin/data/trans/presse/ta_081027.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a14fe889223e4381e47a865899565977/kfutter',
#    'tags': ['Zürich', 'Lehrplan21'],
#    'intraHash': 'a14fe889223e4381e47a865899565977',
#    'label': '159 Lehrplan 21 - Bildungsdirektion - Internet Kanton Zürich',
#    'user': 'kfutter',
#    'description': 'er Bildungsrat des Kantons Zürich hat die Vernehmlassung zu den Grundlagen für den Lehrplan 21 der deutsch- und mehrsprachigen Kantone verabschiedet. Er unterstützt das Ziel eines gemeinsamen Lehrplans und befürwortet die in den Grundlagen vorgesehenen Fachbereiche. Hingegen erachtet er die Grundlagen noch als ungenügend für die Entwicklung eines direkt einführbaren Lehrplans.  Annotated link http://www.diigo.com/bookmark/http%3A%2F%2Fwww.bi.zh.ch%2Finternet%2Fbi%2Fde%2Faktuell%2Fnews09%2F159.html',
#    'date': '2009-07-03 13:29:03',
#    'changeDate': '2009-08-30 12:38:08',
#    'count': 1,
#    'url': 'http://www.bi.zh.ch/internet/bi/de/aktuell/news09/159.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/d4649ca9e301b8d744ee08d7cf805374/meneteqel',
#    'tags': ['army',
#     'warfare',
#     'terrorism',
#     'eth',
#     'nato',
#     'stay-behind',
#     'zürich',
#     'gladio'],
#    'intraHash': 'd4649ca9e301b8d744ee08d7cf805374',
#    'label': 'PHP – Secret Warfare: Operation Gladio and NATO’s Stay-Behind Armies',
#    'user': 'meneteqel',
#    'description': 'Das Parallel History Project on Cooperative Security (PHP, das ehemalige Parallel History Project on NATO and the Warsaw Pact), bietet eine neue wissenschaftliche Perspektive für die internationale Zeitgeschichte durch das Sammeln, die Publikation und Interpretation von ehemals geheimen Regierungsdokumenten. Das PHP wird vom Center for Security Studies (CSS) an der Eidgenössischen Technischen Hochschule (ETH Zürich) betrieben und ergänzt die Dienstleistungen des International Relations and Security Network (ISN).',
#    'date': '2013-02-17 18:55:04',
#    'changeDate': '2013-02-17 18:55:04',
#    'count': 1,
#    'url': 'http://www.php.isn.ethz.ch/collections/colltopic.cfm?lng=en&id=15301'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/df1cfc087e844a8edbfd07bd18e479c3/brenz',
#    'tags': ['pers', 'fnd.lfm'],
#    'intraHash': 'df1cfc087e844a8edbfd07bd18e479c3',
#    'label': 'Robert F. Stärk',
#    'user': 'brenz',
#    'description': 'ETH Zürich',
#    'date': '2006-07-25 16:45:59',
#    'changeDate': '2006-07-25 16:45:59',
#    'count': 1,
#    'url': 'http://www.inf.ethz.ch/personal/staerk/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/762de8578f73ff20ff68772ce5df8c23/brenz',
#    'tags': ['pers', 'swt'],
#    'intraHash': '762de8578f73ff20ff68772ce5df8c23',
#    'label': 'Martin Glinz',
#    'user': 'brenz',
#    'description': 'Uni Zürich',
#    'date': '2008-01-29 13:42:47',
#    'changeDate': '2008-01-29 13:42:47',
#    'count': 2,
#    'url': 'http://www.ifi.uzh.ch/rerg/people/glinz/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/7000f90d8cc07b73693486ba6e33aec9/filologanoga',
#    'tags': ['hrvlat-internet', 'dominis'],
#    'intraHash': '7000f90d8cc07b73693486ba6e33aec9',
#    'label': 'De radiis visus et lucis in vi... (Venetiis, 1611)',
#    'user': 'filologanoga',
#    'description': 'ETH-Bibliothek Zürich',
#    'date': '2010-04-26 10:27:00',
#    'changeDate': '2010-04-26 10:27:00',
#    'count': 1,
#    'url': 'http://www.e-rara.ch/zut/content/titleinfo/272855'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/8e5a340619f01530efe723028d67f192/filologanoga',
#    'tags': ['didacusPyrrhus', 'hrvlat-internet', 'didakPir'],
#    'intraHash': '8e5a340619f01530efe723028d67f192',
#    'label': '129 - Didaci Pyrrhi Lusitani carmen. - Page view - e-rara',
#    'user': 'filologanoga',
#    'description': 'ETH-Bibliothek Zürich (NEBIS); ;',
#    'date': '2012-04-26 21:30:39',
#    'changeDate': '2012-04-26 21:30:39',
#    'count': 1,
#    'url': 'http://www.e-rara.ch/zut/content/pageview/1107970'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/aaa8349c03990a030ef6ef655391ad7d/voss',
#    'tags': ['digitalscholarship'],
#    'intraHash': 'aaa8349c03990a030ef6ef655391ad7d',
#    'label': 'Digital Humanities Cooperation',
#    'user': 'voss',
#    'description': 'Darmstadt, Konstanz, ETH Zürich',
#    'date': '2019-05-10 15:11:09',
#    'changeDate': '2019-05-10 15:11:09',
#    'count': 1,
#    'url': 'https://www.digitalhumanitiescooperation.de/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/4ffb820f7d5042c67f564f2a1336a923/beat07',
#    'tags': ['bibliothek', 'schule'],
#    'intraHash': '4ffb820f7d5042c67f564f2a1336a923',
#    'label': 'Bischu - Bibliothek und Schule',
#    'user': 'beat07',
#    'description': 'Bildungsdirektion Kanton Zürich',
#    'date': '2018-06-18 10:44:49',
#    'changeDate': '2018-06-18 10:44:49',
#    'count': 2,
#    'url': 'http://www.bischu.zh.ch/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a928619e74050dc0dc128349c844d2f9/kooptech',
#    'tags': ['Reputation', 'Sozialkapital'],
#    'intraHash': 'a928619e74050dc0dc128349c844d2f9',
#    'label': 'Vortrag zu Sozialkapital',
#    'user': 'kooptech',
#    'description': 'von Andreas Diekman, ETH Zürich',
#    'date': '2007-10-18 10:21:10',
#    'changeDate': '2008-02-26 14:51:20',
#    'count': 1,
#    'url': 'http://www.socio.ethz.ch/modsim/tagungen/zuerich04/Andreas_Diekmann.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/ae2ce2334afac039446a3199c891b82e/juku',
#    'tags': ['maarb', '2d', 'generalization', 'quality', 'carthographic'],
#    'intraHash': 'ae2ce2334afac039446a3199c891b82e',
#    'label': '28 - Measures for the generalization of polygonal maps with categorical data',
#    'user': 'juku',
#    'description': 'Beat Peter, Zürich, 2001',
#    'date': '2010-11-01 10:08:07',
#    'changeDate': '2012-02-07 23:05:21',
#    'count': 1,
#    'url': 'http://www.geo.unizh.ch/ICA/docs/beijing2001/papers/Peter_v2.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/506eab3bc5b585df9ef2bc9e297eb70c/dblp',
#    'tags': ['dblp'],
#    'intraHash': '506eab3bc5b585df9ef2bc9e297eb70c',
#    'label': 'Home Page of István Erlich',
#    'user': 'dblp',
#    'description': 'homepages/21/11538,\nIstván Erlich, Home Page, http://www.uni-due.de/mvmo/erlich, University of Duisburg-Essen, Germany',
#    'date': '2016-02-10 11:57:08',
#    'changeDate': '2016-02-10 11:57:08',
#    'count': 1,
#    'url': 'http://www.uni-due.de/mvmo/erlich'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f0d0014497ed28986c3d4296484fba72/kfutter',
#    'tags': ['Dossier',
#     'Fachhochschule',
#     'Information',
#     'eLearning',
#     'Hochschuldidaktik'],
#    'intraHash': 'f0d0014497ed28986c3d4296484fba72',
#    'label': 'Dossier - Magazin - CSPC e-Learning - ZFH Zürcher Fachhochschule',
#    'user': 'kfutter',
#    'description': 'Dossierreihe der Fachhochschulen Zürich ZFH',
#    'date': '2009-02-28 09:25:07',
#    'changeDate': '2009-08-30 12:38:08',
#    'count': 1,
#    'url': 'http://www.elearning.zfh.ch/magazin/dossier/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/1efce5d82cc6f5de1020d40f79e3b8de/toennies',
#    'tags': ['PUMA'],
#    'intraHash': '1efce5d82cc6f5de1020d40f79e3b8de',
#    'label': 'Swistry',
#    'user': 'toennies',
#    'description': 'P2P Stremaing Solution der ETH Zürich',
#    'date': '2007-05-07 15:15:40',
#    'changeDate': '2007-05-07 15:15:40',
#    'count': 1,
#    'url': 'http://dcg.ethz.ch/projects/swistry/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/cfaec737ada1220a01b336dc49e30e7d/kfutter',
#    'tags': ['Lernziele', 'Unterricht', 'Lernzielgenerator'],
#    'intraHash': 'cfaec737ada1220a01b336dc49e30e7d',
#    'label': 'RadioJames Objectives Builder',
#    'user': 'kfutter',
#    'description': 'Lernzielgenerator entwickelt vom ELC UZH Zürich',
#    'date': '2008-12-12 17:46:06',
#    'changeDate': '2009-08-30 12:38:08',
#    'count': 1,
#    'url': 'http://www.radiojames.com/ObjectivesBuilder/German/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/28e164841f5fa2ed549a9e1ea5f85067/gender_h2stendal',
#    'tags': ['publikation', 'literatur', 'mentoring', 'peer-mentoring'],
#    'intraHash': '28e164841f5fa2ed549a9e1ea5f85067',
#    'label': 'UZH - Mentoring - Literatur',
#    'user': 'gender_h2stendal',
#    'description': 'Publikationen zum  Peer-Mentoring Universität Zürich ',
#    'date': '2010-01-26 11:05:17',
#    'changeDate': '2010-01-26 11:05:17',
#    'count': 1,
#    'url': 'http://www.mentoring.uzh.ch/literatur.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/24d8559616c7a53727003ff9641e2372/mdrechsler',
#    'tags': [],
#    'intraHash': '24d8559616c7a53727003ff9641e2372',
#    'label': 'Les Binbins - Accueil -',
#    'user': 'mdrechsler',
#    'description': 'des exercices sous JClic Syllabes, lecture, orthographe (tags: motscroisés logiciels libre jclic cycle2 cycle1 combinatoire)',
#    'date': '2008-08-02 19:04:23',
#    'changeDate': '2008-08-02 19:04:23',
#    'count': 1,
#    'url': 'http://www.lesbinbins.com'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/24cdab155ab204d1ac6d56f7d27407cc/dblp',
#    'tags': ['dblp'],
#    'intraHash': '24cdab155ab204d1ac6d56f7d27407cc',
#    'label': 'Home Page of Jim Reich and James Reich',
#    'user': 'dblp',
#    'description': 'homepages/p/JReich,\nJim Reich and James Reich, Home Page, http://www2.parc.com/spl/members/jreich/, Palo Alto Research Center Incorporated, PARC, California, USA',
#    'date': '2016-03-04 12:34:09',
#    'changeDate': '2016-03-04 12:34:09',
#    'count': 1,
#    'url': 'http://www2.parc.com/spl/members/jreich/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/6c20bf24b31ded06b31a3a76611732a1/julianausserhofer',
#    'tags': ['art', 'hom', 'switzerland', 'media-art', 'media'],
#    'intraHash': '6c20bf24b31ded06b31a3a76611732a1',
#    'label': 'Mediengruppe Bitnik',
#    'user': 'julianausserhofer',
#    'description': 'scheizer mediengruppe, aus zürich, sehr cool gestaltete homepage',
#    'date': '2006-09-24 22:15:06',
#    'changeDate': '2008-04-16 18:59:42',
#    'count': 1,
#    'url': 'http://www.bitnik.org/en/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a6602fe5bef2e1c06176959740c8687b/walterra',
#    'tags': ['e-learning', 'via:hannes'],
#    'intraHash': 'a6602fe5bef2e1c06176959740c8687b',
#    'label': 'NZZ Online: Vom E-Learning zum «Blended Learning»',
#    'user': 'walterra',
#    'description': 'Uni Zürich leistet mit Software-Eigenentwicklung Pionierarbeit',
#    'date': '2007-03-11 11:49:18',
#    'changeDate': '2007-09-04 13:19:14',
#    'count': 1,
#    'url': 'http://www.nzz.ch/2007/03/09/em/articleEZGNX.print.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/34f3872335f4a9cdfac26bd74b1b98d1/steffi.braeuning',
#    'tags': ['bibliothek', 'naturwissenschaften', 'recherche'],
#    'intraHash': '34f3872335f4a9cdfac26bd74b1b98d1',
#    'label': 'Informationszentrum Chemie Biologie Pharmazie',
#    'user': 'steffi.braeuning',
#    'description': 'Informationszentrum Chemie Biologie Pharmazie der ETH Zürich.',
#    'date': '2009-05-08 09:25:05',
#    'changeDate': '2009-05-08 09:25:05',
#    'count': 1,
#    'url': 'http://www.infochembio.ethz.ch/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/3549ba6f6d248fd1da99fc91de04b2fa/mdrechsler',
#    'tags': ['biographies'],
#    'intraHash': '3549ba6f6d248fd1da99fc91de04b2fa',
#    'label': 'Biographie de Ivan Illich',
#    'user': 'mdrechsler',
#    'description': 'Ivan illich, un homme fascinant par ses (tags: biographies)',
#    'date': '2008-08-02 19:04:23',
#    'changeDate': '2009-03-16 18:53:19',
#    'count': 1,
#    'url': 'http://savoirscdi.cndp.fr/culturepro/biographie/illich/illich.htm'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/16ba0b41a23bba329e5ea9eb2013de41/mdrechsler',
#    'tags': [],
#    'intraHash': '16ba0b41a23bba329e5ea9eb2013de41',
#    'label': "Le plus féroce des loups - JClic.Edu le portail des activités JClic pour l'école",
#    'user': 'mdrechsler',
#    'description': '(tags: logiciels libre jclic)',
#    'date': '2008-08-02 19:04:23',
#    'changeDate': '2008-08-02 19:04:23',
#    'count': 1,
#    'url': 'http://jclic.clicapplic.net/spip.php?article93'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/20a170ec30187fcd081ee9d855d97386/domwass',
#    'tags': ['landkarten'],
#    'intraHash': '20a170ec30187fcd081ee9d855d97386',
#    'label': 'Die Welt der Karten',
#    'user': 'domwass',
#    'description': 'Portal der Uni Zürich rund um das Kartenwesen',
#    'date': '2006-08-21 14:30:08',
#    'changeDate': '2007-03-15 12:53:32',
#    'count': 4,
#    'url': 'http://www.maps.ethz.ch/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/7f410414369640c4acf65383b289dd06/lysander07',
#    'tags': ['searchengine', 'annotation', 'presentation', '2007', 'mpeg-7'],
#    'intraHash': '7f410414369640c4acf65383b289dd06',
#    'label': 'H. Sack: Effiziente Suche in Multimediadaten durch automatische und kollaborative Annptation',
#    'user': 'lysander07',
#    'description': 'Präsentation an der ETH Zürich, 18. Oktober 2007\r\nin Deutsch',
#    'date': '2006-10-20 12:57:14',
#    'changeDate': '2009-01-28 19:07:51',
#    'count': 1,
#    'url': 'http://www.db-thueringen.de/servlets/DerivateServlet/Derivate-9872/osotis.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/47b688fe157f46d8991c2e7b0c51402b/zettel',
#    'tags': ['literatur', 'Dostojewskij'],
#    'intraHash': '47b688fe157f46d8991c2e7b0c51402b',
#    'label': 'Deutschlandradio Kultur - Kritik - Universum eines Schriftstellers',
#    'user': 'zettel',
#    'description': 'Fjodor Dostojewski: "Der Spieler", Ammann Verlag, Zürich 2009, 231 Seiten',
#    'date': '2010-08-12 17:16:12',
#    'changeDate': '2011-03-10 11:47:15',
#    'count': 1,
#    'url': 'http://www.dradio.de/dkultur/sendungen/kritik/1098607/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/b49c868398427b38519d434844575c71/mdrechsler',
#    'tags': [],
#    'intraHash': 'b49c868398427b38519d434844575c71',
#    'label': "ClicLire aide à l'apprentissage de la lecture",
#    'user': 'mdrechsler',
#    'description': "Exercices d'aide pour l'apprentissage à la lecture avec JCLIC (tags: prélecture logiciels libre lecture jclic cycle2 combinatoire)",
#    'date': '2008-08-02 19:04:23',
#    'changeDate': '2008-08-02 19:04:23',
#    'count': 1,
#    'url': 'http://cliclire.free.fr'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/5d918f870da047071f13461cda0182fe/robingarcia',
#    'tags': ['Weitere_Lesezeichen'],
#    'intraHash': '5d918f870da047071f13461cda0182fe',
#    'label': 'sayes, coaching, psychotherapie, schwerhörigkeit, auftrittskompetenz, kommunikation, Barbara Goossens, Zürich',
#    'user': 'robingarcia',
#    'description': 'sayes, coaching, psychotherapie, schwerhörigkeit, auftrittskompetenz, kommunikation, Barbara Goossens, Zürich',
#    'date': '2017-03-17 10:35:12',
#    'changeDate': '2017-04-13 10:01:45',
#    'count': 1,
#    'url': 'http://www.sayes.ch/ueber-mich.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9fa4ce5486e38e6edf29fadbc90053a4/mc.k',
#    'tags': ['resume', 'howto', 'application', 'google', 'job'],
#    'intraHash': '9fa4ce5486e38e6edf29fadbc90053a4',
#    'label': 'Google Job Opportunities: Zurich',
#    'user': 'mc.k',
#    'description': 'howto apply at google in Zürich, how to write a resume',
#    'date': '2006-06-04 18:47:51',
#    'changeDate': '2006-06-04 18:47:51',
#    'count': 2,
#    'url': 'http://www.google.ch/intl/en/jobs/#apply'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/79381e6bf408fb6a474d0379d5e9d856/hansgeorgbecker',
#    'tags': ['Ranking', 'Kriterien', '#inetbib10', 'Katalog', 'Suchmaschine'],
#    'intraHash': '79381e6bf408fb6a474d0379d5e9d856',
#    'label': 'Sortierung von Suchergebnissen',
#    'user': 'hansgeorgbecker',
#    'description': 'Kurzvortrag auf der Inetbib-Tagung 2010, Zürich, 16. April 2010',
#    'date': '2010-04-16 09:21:29',
#    'changeDate': '2011-04-26 10:30:38',
#    'count': 1,
#    'url': 'http://www.slideshare.net/tillk/lt-inetbib'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/23aa16d65f7bd8639926cab7c53374f4/mauszfabrick',
#    'tags': ['tv',
#     'vampire',
#     'fernsehserie',
#     'wiki',
#     'vampirkulturen',
#     'trueblood',
#     'fernsehen',
#     'serie'],
#    'intraHash': '23aa16d65f7bd8639926cab7c53374f4',
#    'label': 'True Blood Wiki',
#    'user': 'mauszfabrick',
#    'description': 'true blood fanwiki, wie üblich sehr gut mit episodeguide etc.pp.',
#    'date': '2011-09-29 12:56:41',
#    'changeDate': '2011-09-30 08:34:50',
#    'count': 1,
#    'url': 'http://trueblood.wikia.com/wiki/True_Blood_Wiki'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/52468c926f24061bddbb38f0fe20eef8/dblp',
#    'tags': ['dblp'],
#    'intraHash': '52468c926f24061bddbb38f0fe20eef8',
#    'label': 'Home Page of Massimiliano Nolich',
#    'user': 'dblp',
#    'description': 'homepages/41/191,\nMassimiliano Nolich, Home Page, https://www.wikidata.org/entity/Q92119302',
#    'date': '2020-05-13 12:36:45',
#    'changeDate': '2020-05-13 12:36:45',
#    'count': 1,
#    'url': 'https://www.wikidata.org/entity/Q92119302'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9e421b9c85a4b7d525c56b353f7841cd/textundblog',
#    'tags': ['css3', 'webdesign', 'farben', 'importmw'],
#    'intraHash': '9e421b9c85a4b7d525c56b353f7841cd',
#    'label': 'Farbverlufe (Gradients) mit CSS3 | WordPress & Webwork',
#    'user': 'textundblog',
#    'description': 'Das ist bei weitem nicht alles was mit CSS3 mglich ist, wie der Artikel CSS gradients for all web browsers und der Eintrag in der Mozilla-Dokumentation es deutlich zeigen. Es ist nicht nur mglich lineare sondern auch radiale Verlufe zu erzeugen.  Das ganze ist nicht nur in Firefox sondern auch in anderen Browser mglich.   (tags: webdesign css3 farben)',
#    'date': '2013-06-28 16:41:21',
#    'changeDate': '2013-06-28 16:41:21',
#    'count': 1,
#    'url': 'http://www.perun.net/2011/11/20/farbverlaeufe-gradients-mit-css3/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/0d0496471687d0f16f3b46685085b60b/blostben',
#    'tags': ['writing', 'Schreiben', 'wissenschaftliches-Arbeiten'],
#    'intraHash': '0d0496471687d0f16f3b46685085b60b',
#    'label': 'EDINGER Vom Datenmaterial zur Publikation. Wissenschaftliches Schreib…',
#    'user': 'blostben',
#    'description': 'Präsentation zum Vortrag am 24. November 2016, am Zentrum für Qualitiative Sozialforschung Zürich',
#    'date': '2018-05-08 15:37:49',
#    'changeDate': '2018-05-08 15:37:49',
#    'count': 1,
#    'url': 'https://www.slideshare.net/spacesofknowledge/edinger-wissenschaftliches-schreiben-in-der-qualitativen-sozialforschung?ref=https://spacesofknowledge.com/2016/11/28/vom-datenmaterial-zur-publikation/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/fa32af5a7f662723ef0e8f00a6a8b056/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'fa32af5a7f662723ef0e8f00a6a8b056',
#    'label': 'Home Page of Philipp Grohs',
# ...
#    'tags': ['cold-war', 'propaganda', 'turkey', 'film', 'united-states'],
#    'intraHash': 'e8552a4c7869c94e09f7ade15815596d',
#    'interHash': '24cffc0d74d085dfd3234a9fc38f5b8c',
#    'label': 'A Transnational Communication Network Promoting Film Diplomacy: The Case of Turkey and the USA, 1950–86',
#    'user': 'jpooley',
#    'description': '',
#    'date': '2021-09-25 18:31:58',
#    'changeDate': '2021-09-25 18:31:58',
#    'count': 1,
#    'pub-type': 'article',
#    'journal': 'Historical Journal of Film, Radio and Television',
#    'publisher': 'Routledge',
#    'year': '2021',
#    'url': 'https://doi.org/10.1080/01439685.2020.1857924',
#    'author': ['Aysehan Jülide Etem'],
#    'authors': [{'first': 'Aysehan Jülide', 'last': 'Etem'}],
#    'volume': '41',
#    'number': '2',
#    'pages': '292-316',
#    'abstract': 'This article identifies and analyzes the emergence of an educational film revolution in Turkey during the Cold War era as a result of a transnational communication network. This network of institutions including the United States Information Services (USIS) and the United Nations Educational Scientific and Cultural Organization (UNESCO) engaged in film diplomacy by influencing the government and ministries of Turkey to sponsor, produce, distribute and exhibit educational films. This study identifies key institutional agents and investigates how feedback-loops between institutions create asymmetrical power relations to shape culture, policy and public opinion through film technologies. This examination expands upon the existing historical knowledge about educational films by analyzing previously unexamined archival materials from the Turkish and American archives.',
#    'eprint': 'https://doi.org/10.1080/01439685.2020.1857924',
#    'doi': '10.1080/01439685.2020.1857924',
#    'bibtexKey': 'doi:10.1080/01439685.2020.1857924'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2dd3b66ff30b42a92b7b0d01fc9ff1e41/sieber',
#    'tags': ['myown', 'Eide'],
#    'intraHash': 'dd3b66ff30b42a92b7b0d01fc9ff1e41',
#    'interHash': '82c58606c97003007a27beee7a15734a',
#    'label': 'Eidleistungen und Schwörtage im spätmittelalterlichen Zürich',
#    'user': 'sieber',
#    'description': '',
#    'date': '2015-05-04 12:11:51',
#    'changeDate': '2015-05-04 12:14:08',
#    'count': 4,
#    'pub-type': 'incollection',
#    'booktitle': 'Zürich 650 Jahre eidgenössisch',
#    'address': 'Zürich',
#    'year': '2001',
#    'url': '',
#    'author': ['Christian Sieber'],
#    'authors': [{'first': 'Christian', 'last': 'Sieber'}],
#    'editor': ['Staatsarchiv des Kantons Zürich', 'Zentralbibliothek Zürich'],
#    'editors': [{'first': 'Staatsarchiv', 'last': 'des Kantons Zürich'},
#     {'first': 'Zentralbibliothek', 'last': 'Zürich'}],
#    'pages': '19-58',
#    'abstract': 'Sieber, Eidleistungen',
#    'bibtexKey': 'VuFind-193734400'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2c5811e416bda7a64a79ee8238ce83fc3/fbw_hannover',
#    'tags': ['Lagerplanung',
#     'Materialwirtschaft',
#     'Wechselbehälter',
#     'Güterverkehr',
#     'Kombinierter_Verkehr',
#     'Beschaffung'],
#    'intraHash': 'c5811e416bda7a64a79ee8238ce83fc3',
#    'interHash': '94ec9ce1a6d54832aac02474d199b031',
#    'label': 'Entlastung der Straße durch ein innovatives technisch-organisatorisches Gesamtkonzept mit Wechselbrücken, Phase 1: Machbarkeitsstudie',
#    'user': 'fbw_hannover',
#    'description': '',
#    'date': '2009-08-21 12:15:08',
#    'changeDate': '2009-08-21 12:15:30',
#    'count': 2,
#    'pub-type': 'online',
#    'address': 'Hannover',
#    'year': '2002',
#    'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+364076240&sourceid=fbw_bibsonomy',
#    'editor': ['Crispin Mühlich'],
#    'editors': [{'first': 'Crispin', 'last': 'Mühlich'}],
#    'subtitle': 'Abschlussbericht',
#    'pagetotal': 'Online-Ressource (60 p., 2,14 Mb.)',
#    'ppn_gvk': '364076240',
#    'bibtexKey': 'GVK364076240'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2e85d1969b9d07a3033b5421a41225ac1/antares',
#    'tags': ['urheberrecht', 'OpenAccess', 'schweiz'],
#    'intraHash': 'e85d1969b9d07a3033b5421a41225ac1',
#    'interHash': 'f9ed6212f87066c185a65584c056d84c',
#    'label': 'Open Access - Zugang zu wissenschaftlichen Publikationen im schweizerischen Recht',
#    'user': 'antares',
#    'description': '',
#    'date': '2010-04-07 09:52:23',
#    'changeDate': '2010-04-07 09:52:23',
#    'count': 1,
#    'pub-type': 'techreport',
#    'year': '2009',
#    'url': 'http://www.oai.uzh.ch/images/stories/oa_medien/oa_rechtsgutachten_hilty.pdf',
#    'author': ['Reto M. Hilty', 'Matthias Seemann'],
#    'authors': [{'first': 'Reto M.', 'last': 'Hilty'},
#     {'first': 'Matthias', 'last': 'Seemann'}],
#    'editor': ['Universität Zürich'],
#    'editors': [{'first': 'Universität', 'last': 'Zürich'}],
#    'bibtexKey': 'hilty2009access'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/24d655ae52d063f0fe684a6d59b42b7c7/genealogie',
#    'tags': ['dnb', 'Gesundheit', 'Biologie', 'Medizin'],
#    'intraHash': '4d655ae52d063f0fe684a6d59b42b7c7',
#    'interHash': '257f8b126732b29fb11dc447228af454',
#    'label': 'Einfluss des Tumorpromotors Phorbol-Myristat-Acetat auf die Aktivität des Plasminogen-Aktivators in Zellkulturen von Patienten mit Neurofibromatose (v. Recklinghausen)',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2015-09-09 08:31:36',
#    'changeDate': '2015-09-09 08:31:36',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '1989',
#    'url': '',
#    'author': ['Markus Sebastian Gulich'],
#    'authors': [{'first': 'Markus Sebastian', 'last': 'Gulich'}],
#    'dnbtitleid': '891600329',
#    'bibtexKey': 'gulich1989einfluss'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/201ffc0bf6a419250c7a2efa71ebfb3b8/genealogie',
#    'tags': ['dnb', 'Gesundheit', 'Medizin'],
#    'intraHash': '01ffc0bf6a419250c7a2efa71ebfb3b8',
#    'interHash': 'f08535dc5524cd4e44b9ae2a9897c272',
#    'label': 'Die Bedeutung der Matrix-Metalloproteinase-9 (MMP-9) für die Prognose von PatientInnen mit koronarer Herzkrankheit',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2015-09-09 21:11:03',
#    'changeDate': '2015-09-09 21:11:03',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '2003',
#    'url': '',
#    'author': ['Daniel Klaus Gütlich'],
#    'authors': [{'first': 'Daniel Klaus', 'last': 'Gütlich'}],
#    'dnbtitleid': '969845707',
#    'bibtexKey': 'gutlich2003bedeutung'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2fa076ceccf033083e3c8199fed42811c/genealogie',
#    'tags': ['dnb', 'Ingenieurbau_und_Umwelttechnik'],
#    'intraHash': 'fa076ceccf033083e3c8199fed42811c',
#    'interHash': 'cff4a7f6e9d7ec98e8f00c5b76c64f2f',
#    'label': '\x98Ein\x9c Beitrag zur allgemeinen Beschreibung des Tragverhaltens von schlanken Betondruckgliedern',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2016-05-30 21:01:57',
#    'changeDate': '2016-05-30 21:01:57',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '2015',
#    'url': '',
#    'author': ['Günther Werner Illich'],
#    'authors': [{'first': 'Günther Werner', 'last': 'Illich'}],
#    'dnbtitleid': '1073598039',
#    'bibtexKey': 'illich2015beitrag'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/26ddaab18c3d0d67c7e10a3194d6f866b/genealogie',
#    'tags': ['dnb'],
#    'intraHash': '6ddaab18c3d0d67c7e10a3194d6f866b',
#    'interHash': 'eb473a1c87fb4a286d100718b70aae5c',
#    'label': 'Direkte Steuern in Jugoslawien: Ihre Moral u. Technik',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2016-05-31 02:16:02',
#    'changeDate': '2016-05-31 02:16:02',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '1939',
#    'url': '',
#    'author': ['Dušan Jovanović-Jolić'],
#    'authors': [{'first': 'Dušan', 'last': 'Jovanović-Jolić'}],
#    'dnbtitleid': '570751616',
#    'bibtexKey': 'jovanovicjolic1939direkte'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/25608d112b1fa453a56b7a86d5d2d66e4/dblp',
#    'tags': ['dblp'],
#    'intraHash': '5608d112b1fa453a56b7a86d5d2d66e4',
#    'interHash': 'a73ec33f64c50c657474be2f47e8d5d0',
#    'label': 'On the Performance of COBOL Programs in Large vs. Mini Computers.',
#    'user': 'dblp',
#    'description': '',
#    'date': '2020-04-09 00:00:00',
#    'changeDate': '2020-04-10 11:53:29',
#    'count': 1,
#    'pub-type': 'article',
#    'journal': 'Softw. Pract. Exp.',
#    'year': '1982',
#    'url': 'http://dblp.uni-trier.de/db/journals/spe/spe12.html#Jalics82',
#    'author': ['Paul J. Jalics'],
#    'authors': [{'first': 'Paul J.', 'last': 'Jalics'}],
#    'volume': '12',
#    'number': '2',
#    'pages': '103-114',
#    'ee': 'https://doi.org/10.1002/spe.4380120202',
#    'bibtexKey': 'journals/spe/Jalics82'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2dd3b66ff30b42a92b7b0d01fc9ff1e41/mischaffner16',
#    'tags': ['Eid'],
#    'intraHash': 'dd3b66ff30b42a92b7b0d01fc9ff1e41',
#    'interHash': '82c58606c97003007a27beee7a15734a',
#    'label': 'Eidleistungen und Schwörtage im spätmittelalterlichen Zürich',
#    'user': 'mischaffner16',
#    'description': 'Behandelt die Bedeutung von Eidleistungen in den Bereichen Stadt (Schwörtag und Bürgereid), Landschaft (Untertaneneid), Reich (Huldigung), Herrschaft Österreich (Bündniseide) und Eidgenossenschaft (Neubeschwörungen der Bünde).',
#    'date': '2017-01-24 10:52:53',
#    'changeDate': '2017-01-24 16:08:48',
#    'count': 4,
#    'pub-type': 'incollection',
#    'booktitle': 'Zürich 650 Jahre eidgenössisch',
#    'address': 'Zürich',
#    'year': '2001',
#    'url': '',
#    'author': ['Christian Sieber'],
#    'authors': [{'first': 'Christian', 'last': 'Sieber'}],
#    'editor': ['Staatsarchiv des Kantons Zürich', 'Zentralbibliothek Zürich'],
#    'editors': [{'first': 'Staatsarchiv', 'last': 'des Kantons Zürich'},
#     {'first': 'Zentralbibliothek', 'last': 'Zürich'}],
#    'pages': '19-58',
#    'abstract': 'Sieber 2001',
#    'bibtexKey': 'VuFind-193734400'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/23321bbb339c0506d0ab0295f0c8c0c08/eladnoor',
#    'tags': ['imported'],
#    'intraHash': '3321bbb339c0506d0ab0295f0c8c0c08',
#    'interHash': '8a8943111c5578f483abee0261dee23e',
#    'label': 'SUMOFLUX: A Generalized Method for Targeted 13C Metabolic Flux Ratio Analysis',
#    'user': 'eladnoor',
#    'description': '',
#    'date': '2017-09-19 09:22:19',
#    'changeDate': '2017-09-19 09:22:19',
#    'count': 2,
#    'pub-type': 'article',
#    'journal': 'PLoS Comput. Biol.',
#    'year': '2016',
#    'url': '',
#    'author': ['Maria Kogadeeva', 'Nicola Zamboni'],
#    'authors': [{'first': 'Maria', 'last': 'Kogadeeva'},
#     {'first': 'Nicola', 'last': 'Zamboni'}],
#    'volume': '12',
#    'number': '9',
#    'pages': 'e1005109',
#    'affiliation': 'Institute of Molecular Systems Biology, ETH Zürich, Zürich, Switzerland. Life Science Zürich Graduate School, Zürich, Switzerland. Institute of Molecular Systems Biology, ETH Zürich, Zürich, Switzerland.',
#    'language': 'en',
#    'bibtexKey': 'Kogadeeva2016-yf'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2f6d8d90f390c958f12a08ec6e2a70d58/pedocs',
#    'tags': ['Weiterbildung',
#     'Integration',
#     'Lernen',
#     'Nordrhein-Westfalen',
#     'Bildungspolitik',
#     'Erwachsenenbildung',
#     'Ausländerpolitik',
#     'Netzwerk',
#     'Arbeitswelt',
#     'Deutschland',
#     'Bildungsangebot',
#     'Politische_Bildung',
#     'Region'],
#    'intraHash': 'f6d8d90f390c958f12a08ec6e2a70d58',
#    'interHash': '82c6a229a6eb303969ab28956abbf8b0',
#    'label': 'Netze und lose Fäden. Politische Bildung gegen gesellschaftliche Desintegration',
#    'user': 'pedocs',
#    'description': '',
#    'date': '2010-12-20 19:32:13',
#    'changeDate': '2010-12-20 19:32:17',
#    'count': 1,
#    'pub-type': 'book',
#    'publisher': 'Wochenschau-Verl.',
#    'address': 'Schwalbach, Taunus',
#    'year': '2002',
#    'url': 'http://www.pedocs.de/volltexte/2009/1880',
#    'editor': ['Günter Schneider', 'Franz-Josef Jelich'],
#    'editors': [{'first': 'Günter', 'last': 'Schneider'},
#     {'first': 'Franz-Josef', 'last': 'Jelich'}],
#    'abstract': 'Die Begriffe "Netz" und "Netzwerk" bestimmen allerorten den Diskurs - von der Biologie bis zur Philosophie, von der Politik bis zur Ökonomie und nicht zuletzt auch im Bereich von Bildung und Weiterbildung. Offensichtlich eignet sich der Terminus "Netzwerk" für Gestaltungsansätze in Ökonomie, Politik und Kultur, mit denen aktiv Prozessen der Desintegration und Entgrenzung entgegengearbeitet wird, wie sie mit den Schlagworten Individualisierung, Flexibilisierung, Deregulierung, Globalisierung... benannt werden. Eine reflektierte Auseinandersetzung mit veränderten Anforderungen an Gesellschaft und Kultur, an Bildung und Weiterbildung im gegenwärtigen gesellschaftlichen Transformationsprozess soll mit dem vorliegenden Band geleistet werden. Darüber hinaus werden Projektzusammenhänge gegenwärtiger Bildungsarbeit von Arbeit und Leben unter der Perspektive von Netzwerkgründungen vor- und dargestellt. Der Band enthält Beiträge zur Bedeutung von Netzwerken für die Veränderung von Ökonomie, Politik und Kultur, die Veränderung von Bildung und Weiterbildung, die Veränderung von Bildungsorganisation und Weiterbildungsangeboten. (DIPF/Orig.).',
#    'isbn': '3-87920-086-6',
#    'bibtexKey': 'Schneider.2002'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2443b0a2ebc5646ccf6f0908431dbf55f/dblp',
#    'tags': ['dblp'],
#    'intraHash': '443b0a2ebc5646ccf6f0908431dbf55f',
#    'interHash': '5977153e76ccd32ce64f7d9dc388e9ba',
#    'label': 'Gaining an Awareness of the Performance of COBOL Programs.',
#    'user': 'dblp',
#    'description': '',
#    'date': '2019-07-17 00:00:00',
#    'changeDate': '2019-07-18 11:45:58',
#    'count': 1,
#    'pub-type': 'inproceedings',
#    'booktitle': 'Int. CMG Conference',
#    'publisher': 'Computer Measurement Group',
#    'year': '1978',
#    'url': 'http://dblp.uni-trier.de/db/conf/cmg/cmg1978.html#Jalics78',
#    'author': ['Paul J. Jalics'],
#    'authors': [{'first': 'Paul J.', 'last': 'Jalics'}],
#    'editor': ['Linda S. Wright', 'Jeffrey P. Buzen'],
#    'editors': [{'first': 'Linda S.', 'last': 'Wright'},
#     {'first': 'Jeffrey P.', 'last': 'Buzen'}],
#    'pages': '61-65',
#    'ee': 'http://www.cmg.org/?s2member_file_download=/proceedings/1978/78INT007.pdf',
#    'bibtexKey': 'conf/cmg/Jalics78'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/234304faf36a39859473c75e06d6f1e48/dblp',
#    'tags': ['dblp'],
#    'intraHash': '34304faf36a39859473c75e06d6f1e48',
#    'interHash': '3b65b979e7fa810f946ae06984ec8481',
#    'label': 'Cobol on a PC: A New Perspective on a Language and its Performance.',
#    'user': 'dblp',
#    'description': '',
#    'date': '2018-11-06 00:00:00',
#    'changeDate': '2018-11-07 11:52:53',
#    'count': 1,
#    'pub-type': 'article',
#    'journal': 'Commun. ACM',
#    'year': '1987',
#    'url': 'http://dblp.uni-trier.de/db/journals/cacm/cacm30.html#Jalics87',
#    'author': ['Paul J. Jalics'],
#    'authors': [{'first': 'Paul J.', 'last': 'Jalics'}],
#    'volume': '30',
#    'number': '2',
#    'pages': '142-154',
#    'ee': 'https://doi.org/10.1145/12527.12530',
#    'bibtexKey': 'journals/cacm/Jalics87'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/20ff26b73d317f68417e10cde0fa48cb7/dblp',
#    'tags': ['dblp'],
#    'intraHash': '0ff26b73d317f68417e10cde0fa48cb7',
#    'interHash': 'dfeb7d9f78527dca0387a00cd4dd93e9',
#    'label': 'COBOL vs. PL/1: Some Performance Comparisons.',
#    'user': 'dblp',
#    'description': '',
#    'date': '2018-11-06 00:00:00',
#    'changeDate': '2018-11-07 11:52:07',
#    'count': 1,
#    'pub-type': 'article',
#    'journal': 'Commun. ACM',
#    'year': '1984',
#    'url': 'http://dblp.uni-trier.de/db/journals/cacm/cacm27.html#Jalics84',
#    'author': ['Paul J. Jalics'],
#    'authors': [{'first': 'Paul J.', 'last': 'Jalics'}],
#    'volume': '27',
#    'number': '3',
#    'pages': '216-221',
#    'ee': 'https://doi.org/10.1145/357994.358019',
#    'bibtexKey': 'journals/cacm/Jalics84'},
#   ...]}

# %%
df_ai = pd.DataFrame(data["items"])
df_ai = df_ai[df_ai["type"] == "Publication"]

# %%
df_ai_filtered = df_ai.dropna(axis=1, thresh=len(df_ai)*0.5)

# %%
df_ai_filtered.head(10)
# Out:
#             type                                                 id  \
# 323  Publication  https://www.bibsonomy.org/bibtex/2bdae1e1df978...
# 324  Publication  https://www.bibsonomy.org/bibtex/229373b9b1243...
# 325  Publication  https://www.bibsonomy.org/bibtex/2e08a1c00674b...
# 326  Publication  https://www.bibsonomy.org/bibtex/29d59b136207d...
# 327  Publication  https://www.bibsonomy.org/bibtex/2e08a1c00674b...
# 328  Publication  https://www.bibsonomy.org/bibtex/29e3592cb6e14...
# 329  Publication  https://www.bibsonomy.org/bibtex/28d8ba6c97154...
# 330  Publication  https://www.bibsonomy.org/bibtex/242c29a065ee5...
# 331  Publication  https://www.bibsonomy.org/bibtex/2879c972e2240...
# 332  Publication  https://www.bibsonomy.org/bibtex/27f26b46919b0...
#
#                                                   tags  \
# 323                          [scholarly_communication]
# 324                     [forschungsdaten, proceedings]
# 325                    [bibliometrics, scientometrics]
# 326                   [Niedergermanien, Ubier, Jülich]
# 327                                     [bibliometrie]
# 328               [linkeddata, myown, phresnel, lobid]
# 329                                         [imported]
# 330  [bibliothekswesen, openaccess, bibliothekswiss...
# 331                                         [imported]
# 332  [Datenmanagement, pöppel, lv_wisskomm, practic...
#
#                             intraHash  \
# 323  bdae1e1df978095e1597b14122974d9c
# 324  29373b9b1243c4dec5e9fa4d7105bc20
# 325  e08a1c00674b99dfd038acd7d858a08a
# 326  9d59b136207d578324fd81a54bda0370
# 327  e08a1c00674b99dfd038acd7d858a08a
# 328  9e3592cb6e1497d8021e67cdb50d8d8f
# 329  8d8ba6c971543729dbdac4223c2e9689
# 330  42c29a065ee5d48220fa97bd65b53a4b
# 331  879c972e22403a15e9b77f58b6a2e36f
# 332  7f26b46919b08a1bf4409a33f76217a1
#
#                                                  label          user  \
# 323             Wissenschaftskommunikation der Zukunft        acka47
# 324  Forschungsdaten - Sammeln, sichern, strukturie...         wdees
# 325  Qualität und Quantität wissenschaftlicher Verö...          urhe
# 326  Jülich:  Stadt - Territorium - Geschichte:  Fe...     novaesium
# 327  Qualität und Quantität wissenschaftlicher Verö...  bibliometrie
# 328  Zur Entwicklung eines Linked-Open-Data-Dienste...        acka47
# 329  Entlastung der Rohstoff- und Primärenergiebila...  fbw_hannover
# 330  Der Schritt zurück als Schritt nach vorn – Mac...          voss
# 331  Anwendung von FFT Ewald Gitter-Methoden in Sim...      kaigrass
# 332  WissKom 2007: Wissenschaftskommunikation der Z...      mm051052
#
#                                            description                 date  \
# 323  4. Konferenz der Zentralbibliothek Forschungsz...  2009-06-08 11:42:22
# 324  Forschungsdaten - Sammeln, sichern, strukturie...  2019-08-06 14:45:34
# 325                                                     2015-02-20 13:30:54
# 326                                                     2008-11-26 16:30:25
# 327                                                     2010-11-24 15:02:02
# 328                                                     2013-01-07 11:58:11
# 329                                                     2009-08-21 09:46:50
# 330                             ISBN 978-3-95806-146-0  2016-06-14 13:46:42
# 331                                                     2007-06-15 17:33:15
# 332  Amazon.de: WissKom 2007: Wissenschaftskommunik...  2008-03-06 18:55:46
#
#               changeDate  count  \
# 323  2009-06-08 11:42:22      1
# 324  2019-08-06 14:45:34      1
# 325  2015-02-20 13:30:54      6
# 326  2008-11-26 16:30:30      1
# 327  2010-11-24 15:02:02      6
# 328  2013-01-07 11:58:11      1
# 329  2009-08-21 09:46:53      2
# 330  2016-06-14 13:46:42      1
# 331  2007-06-15 17:33:19      1
# 332  2011-11-11 09:07:43      3
#
#                                                    url  \
# 323  http://juwel.fz-juelich.de:8080/dspace/bitstre...
# 324           http://juser.fz-juelich.de/record/863008
# 325
# 326  \url{http://katalog.ub.uni-heidelberg.de/cgi-b...
# 327                http://epub.uni-regensburg.de/4914/
# 328                    http://hdl.handle.net/2128/4699
# 329  http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP...
# 330                   http://hdl.handle.net/2128/11435
# 331
# 332  http://www.amazon.de/gp/redirect.html%3FASIN=3...
#
#                             interHash       pub-type  year  \
# 323  1742fc85a1bfb71a1c9ba26c50fe05e4           book  2007
# 324  5ae37b89357daf1836757213f03ec8e0           book  2019
# 325  ca255a86a8d865dbbf94ee49cd58c30e           book  2006
# 326  94e556f1537e361b1ca4c6b2b1fbb8ca           book  2000
# 327  ca255a86a8d865dbbf94ee49cd58c30e           book  2006
# 328  b8056f67cc86d2234d8d4a2da8fe4044  inproceedings  2012
# 329  52ba970db263ba645b5f3c057c0d0731      phdthesis  1977
# 330  005183a83ccfa7b6b7f7520edb8b763f    proceedings  2016
# 331  21ed808570f18573adf2f7466f6e29e2         inbook  1998
# 332  3a5dae0f8e60eecabaa15db8346e803c           book  2007
#
#                bibtexKey                          author  \
# 323    Ball_2007_Wisskom                             NaN
# 324  2019forschungsdaten                             NaN
# 325           Jokic.2006       [Maja Jokic, Rafael Ball]
# 326           Buren.2000                             NaN
# 327             epub4914       [Maja Jokic, Rafael Ball]
# 328  ostrowski-pohl_2012  [Felix Ostrowski, Adrian Pohl]
# 329         GVK010967400               [Roland Turowski]
# 330     noauthororeditor                             NaN
# 331              holm98a                       [C. Holm]
# 332           3893364595                            [ ?]
#
#                                                authors
# 323                                                NaN
# 324                                                NaN
# 325  [{'first': 'Maja', 'last': 'Jokic'}, {'first':...
# 326                                                NaN
# 327  [{'first': 'Maja', 'last': 'Jokic'}, {'first':...
# 328  [{'first': 'Felix', 'last': 'Ostrowski'}, {'fi...
# 329          [{'first': 'Roland', 'last': 'Turowski'}]
# 330                                                NaN
# 331                  [{'first': 'C.', 'last': 'Holm'}]
# 332                       [{'first': '', 'last': '?'}]

# %%
df_ai_filtered.columns
# Out:
# Index(['type', 'id', 'tags', 'intraHash', 'label', 'user', 'description',
#        'date', 'changeDate', 'count', 'url', 'interHash', 'pub-type', 'year',
#        'bibtexKey', 'author', 'authors'],
#       dtype='object')

# %%
useful_columns = ['id', 'tags', 'label', 'description', 'date', 'changeDate', 'url', 'pub-type', 'year',
       'author', 'authors', ]
df_ai_filtered = df_ai_filtered[useful_columns]

# %%
if not pt.started():
    pt.init()
# Out:
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %%
df_ai_filtered['docno'] = df_ai_filtered['id']
df_ai_filtered['text'] = df_ai_filtered['label']
# Out:
# /tmp/ipykernel_21120/766803032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ai_filtered['docno'] = df_ai_filtered['id']
# /tmp/ipykernel_21120/766803032.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ai_filtered['text'] = df_ai_filtered['label']

# %%
index_folder ="./ai_index"

indexer = pt.DFIndexer(index_folder, overwrite=True)
index_ref =   indexer.index(df_ai_filtered['text'], df_ai_filtered['docno'])
print(f"path to our index: {index_ref.toString()}")
# Out:
# 14:28:05.667 [main] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (https://www.bibsonomy.org/bibtex/2061c3f3ebb93c1e28d9aa86e2d790595/fbw_hannover) - further warnings are suppressed
# 14:28:18.673 [main] WARN org.terrier.structures.indexing.Indexer - Indexed 2 empty documents
# path to our index: ./ai_index/data.properties

# %%
index = pt.IndexFactory.of(index_ref)

# %%
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 1000
# Number of terms: 3843
# Number of postings: 8833
# Number of fields: 0
# Number of tokens: 9180
# Field names: []
# Positions:   false

# %%
for kv in index.getLexicon():
    print(f"{kv.getKey()} -> {kv.getValue().toString()}")
# Out:
# 0 -> term1687 Nt=3 TF=3 maxTF=1 @{0 0 0}
# 01 -> term941 Nt=2 TF=2 maxTF=1 @{0 6 2}
# 08 -> term940 Nt=2 TF=2 maxTF=1 @{0 8 4}
# 1 -> term366 Nt=9 TF=11 maxTF=3 @{0 10 6}
# 10 -> term937 Nt=7 TF=8 maxTF=2 @{0 25 6}
# 100 -> term895 Nt=2 TF=2 maxTF=1 @{0 35 3}
# 1000 -> term1994 Nt=1 TF=1 maxTF=1 @{0 39 7}
# 11 -> term936 Nt=4 TF=4 maxTF=1 @{0 42 1}
# 12 -> term303 Nt=6 TF=6 maxTF=1 @{0 48 5}
# 1207 -> term468 Nt=1 TF=1 maxTF=1 @{0 57 5}
# 1225 -> term1223 Nt=5 TF=5 maxTF=1 @{0 59 3}
# 13 -> term1001 Nt=4 TF=4 maxTF=1 @{0 67 7}
# 1361 -> term473 Nt=1 TF=1 maxTF=1 @{0 75 3}
# 13c -> term2266 Nt=3 TF=3 maxTF=1 @{0 77 1}
# 14 -> term1000 Nt=4 TF=4 maxTF=1 @{0 82 3}
# 1402 -> term882 Nt=1 TF=1 maxTF=1 @{0 89 7}
# 142 -> term316 Nt=1 TF=1 maxTF=1 @{0 91 7}
# 1423 -> term889 Nt=1 TF=1 maxTF=1 @{0 93 3}
# 15 -> term3114 Nt=1 TF=1 maxTF=1 @{0 95 3}
# 1518 -> term1112 Nt=1 TF=1 maxTF=1 @{0 97 7}
# 1530 -> term544 Nt=1 TF=1 maxTF=1 @{0 99 7}
# 1533 -> term1199 Nt=1 TF=1 maxTF=1 @{0 101 5}
# 1534 -> term925 Nt=1 TF=1 maxTF=1 @{0 103 5}
# 1537 -> term655 Nt=2 TF=3 maxTF=2 @{0 105 5}
# 1540 -> term846 Nt=1 TF=1 maxTF=1 @{0 109 0}
# 1547 -> term965 Nt=1 TF=1 maxTF=1 @{0 111 0}
# 1552 -> term541 Nt=1 TF=1 maxTF=1 @{0 113 0}
# 1554 -> term1052 Nt=1 TF=1 maxTF=1 @{0 114 6}
# 1555 -> term641 Nt=6 TF=7 maxTF=2 @{0 116 6}
# 1567 -> term1115 Nt=1 TF=1 maxTF=1 @{0 123 5}
# 1571 -> term1114 Nt=1 TF=1 maxTF=1 @{0 125 5}
# 1598 -> term1127 Nt=1 TF=1 maxTF=1 @{0 127 5}
# 16 -> term646 Nt=7 TF=7 maxTF=1 @{0 129 5}
# 1601 -> term513 Nt=3 TF=3 maxTF=1 @{0 139 3}
# 1609 -> term674 Nt=2 TF=2 maxTF=1 @{0 142 7}
# 1614 -> term1119 Nt=1 TF=1 maxTF=1 @{0 146 3}
# 1616 -> term1103 Nt=1 TF=1 maxTF=1 @{0 148 3}
# 1619 -> term963 Nt=1 TF=1 maxTF=1 @{0 150 3}
# 1620 -> term1116 Nt=1 TF=1 maxTF=1 @{0 152 3}
# 1636 -> term789 Nt=2 TF=2 maxTF=1 @{0 154 3}
# 1643 -> term788 Nt=2 TF=2 maxTF=1 @{0 157 1}
# 1653 -> term677 Nt=1 TF=1 maxTF=1 @{0 159 7}
# 1659 -> term1126 Nt=1 TF=1 maxTF=1 @{0 161 5}
# 1668 -> term1079 Nt=1 TF=1 maxTF=1 @{0 163 5}
# 1673 -> term1076 Nt=1 TF=1 maxTF=1 @{0 165 5}
# 1674 -> term1075 Nt=1 TF=1 maxTF=1 @{0 167 5}
# 1688 -> term1205 Nt=1 TF=1 maxTF=1 @{0 169 5}
# 1692 -> term830 Nt=1 TF=1 maxTF=1 @{0 171 5}
# 17 -> term420 Nt=7 TF=7 maxTF=1 @{0 173 5}
# 1700 -> term3008 Nt=1 TF=1 maxTF=1 @{0 184 5}
# 1711 -> term995 Nt=1 TF=1 maxTF=1 @{0 187 1}
# 1716 -> term437 Nt=1 TF=1 maxTF=1 @{0 189 1}
# 1742 -> term832 Nt=1 TF=1 maxTF=1 @{0 190 7}
# 1744 -> term847 Nt=1 TF=1 maxTF=1 @{0 192 7}
# 175 -> term2867 Nt=1 TF=1 maxTF=1 @{0 194 7}
# 1769 -> term377 Nt=2 TF=2 maxTF=1 @{0 197 3}
# 1770 -> term3011 Nt=1 TF=1 maxTF=1 @{0 200 5}
# 1777 -> term694 Nt=1 TF=1 maxTF=1 @{0 203 1}
# 1794 -> term879 Nt=1 TF=1 maxTF=1 @{0 204 7}
# 1798 -> term1221 Nt=5 TF=5 maxTF=1 @{0 206 7}
# 1799 -> term736 Nt=1 TF=1 maxTF=1 @{0 215 3}
# 18 -> term419 Nt=6 TF=6 maxTF=1 @{0 217 3}
# 1806 -> term874 Nt=1 TF=1 maxTF=1 @{0 226 3}
# 1810 -> term642 Nt=2 TF=2 maxTF=1 @{0 228 3}
# 1815 -> term954 Nt=1 TF=1 maxTF=1 @{0 231 7}
# 1816 -> term480 Nt=2 TF=2 maxTF=1 @{0 233 7}
# 1817 -> term512 Nt=3 TF=3 maxTF=1 @{0 236 5}
# 1822 -> term479 Nt=2 TF=2 maxTF=1 @{0 240 1}
# 1834 -> term961 Nt=1 TF=2 maxTF=2 @{0 242 7}
# 1857 -> term1655 Nt=1 TF=1 maxTF=1 @{0 245 0}
# 1867 -> term2471 Nt=1 TF=1 maxTF=1 @{0 247 2}
# 1870 -> term2729 Nt=1 TF=1 maxTF=1 @{0 249 6}
# 1875 -> term733 Nt=1 TF=1 maxTF=1 @{0 252 2}
# 19 -> term556 Nt=3 TF=3 maxTF=1 @{0 254 2}
# 1900 -> term1096 Nt=1 TF=1 maxTF=1 @{0 260 4}
# 1905 -> term3250 Nt=1 TF=1 maxTF=1 @{0 262 4}
# 1914 -> term2196 Nt=1 TF=1 maxTF=1 @{0 265 0}
# 1917 -> term2540 Nt=1 TF=1 maxTF=1 @{0 267 2}
# 1918 -> term2539 Nt=1 TF=1 maxTF=1 @{0 269 6}
# 1923 -> term23 Nt=2 TF=2 maxTF=1 @{0 272 2}
# 193 -> term1907 Nt=1 TF=1 maxTF=1 @{0 275 2}
# 1930 -> term2469 Nt=1 TF=1 maxTF=1 @{0 277 4}
# 1950 -> term3016 Nt=1 TF=1 maxTF=1 @{0 280 0}
# 1970 -> term2971 Nt=2 TF=2 maxTF=1 @{0 282 4}
# 1972 -> term2961 Nt=1 TF=1 maxTF=1 @{0 286 6}
# 1977 -> term1207 Nt=1 TF=1 maxTF=1 @{0 289 2}
# 1980 -> term3208 Nt=1 TF=1 maxTF=1 @{0 291 2}
# 1981 -> term703 Nt=1 TF=1 maxTF=1 @{0 293 6}
# 1h -> term2264 Nt=2 TF=2 maxTF=1 @{0 295 4}
# 1hn1 -> term2346 Nt=2 TF=3 maxTF=2 @{0 299 6}
# 1hn1h -> term2347 Nt=1 TF=1 maxTF=1 @{0 303 1}
# 1hn3 -> term2384 Nt=1 TF=1 maxTF=1 @{0 305 3}
# 1hn3c -> term2345 Nt=1 TF=1 maxTF=1 @{0 307 5}
# 1tn -> term2259 Nt=2 TF=2 maxTF=1 @{0 309 7}
# 1tn2 -> term816 Nt=6 TF=6 maxTF=1 @{0 312 7}
# 1tn2f -> term2066 Nt=1 TF=1 maxTF=1 @{0 321 5}
# 1tn2o -> term1153 Nt=1 TF=1 maxTF=1 @{0 323 7}
# 1tn2xy -> term2073 Nt=1 TF=2 maxTF=2 @{0 325 7}
# 1tn3 -> term1152 Nt=2 TF=3 maxTF=2 @{0 328 2}
# 1tn4 -> term815 Nt=2 TF=2 maxTF=1 @{0 332 5}
# 1tn5al -> term828 Nt=1 TF=1 maxTF=1 @{0 336 1}
# 1tn7 -> term814 Nt=1 TF=1 maxTF=1 @{0 338 1}
# 1tni -> term2257 Nt=2 TF=2 maxTF=1 @{0 340 1}
# 1y -> term2872 Nt=1 TF=1 maxTF=1 @{0 343 1}
# 2 -> term233 Nt=14 TF=18 maxTF=2 @{0 345 5}
# 2003 -> term2339 Nt=2 TF=2 maxTF=1 @{0 366 5}
# 2005 -> term1436 Nt=2 TF=4 maxTF=2 @{0 371 1}
# 2007 -> term67 Nt=6 TF=10 maxTF=2 @{0 376 1}
# 2008 -> term942 Nt=5 TF=8 maxTF=2 @{0 381 3}
# 2013 -> term3347 Nt=1 TF=1 maxTF=1 @{0 390 0}
# 2018 -> term1888 Nt=2 TF=2 maxTF=1 @{0 392 4}
# 21 -> term117 Nt=2 TF=2 maxTF=1 @{0 397 0}
# 23 -> term699 Nt=1 TF=1 maxTF=1 @{0 398 6}
# 25 -> term698 Nt=2 TF=2 maxTF=1 @{0 400 4}
# 27 -> term3441 Nt=1 TF=1 maxTF=1 @{0 404 0}
# 278 -> term2304 Nt=1 TF=1 maxTF=1 @{0 406 4}
# 2d -> term3508 Nt=1 TF=1 maxTF=1 @{0 408 6}
# 2o -> term3331 Nt=1 TF=1 maxTF=1 @{0 411 2}
# 3 -> term1571 Nt=7 TF=8 maxTF=2 @{0 413 6}
# 348 -> term224 Nt=1 TF=1 maxTF=1 @{0 425 3}
# 372pp -> term1210 Nt=1 TF=1 maxTF=1 @{0 426 7}
# 38 -> term2093 Nt=1 TF=2 maxTF=2 @{0 428 7}
# 3d -> term1251 Nt=4 TF=4 maxTF=1 @{0 431 2}
# 3p14 -> term2459 Nt=1 TF=1 maxTF=1 @{0 438 4}
# 4 -> term73 Nt=8 TF=9 maxTF=2 @{0 440 6}
# 5 -> term1674 Nt=3 TF=3 maxTF=1 @{0 450 7}
# 50 -> term3195 Nt=1 TF=1 maxTF=1 @{0 456 7}
# 52 -> term2319 Nt=1 TF=1 maxTF=1 @{0 459 3}
# 533 -> term1939 Nt=1 TF=1 maxTF=1 @{0 461 5}
# 6 -> term72 Nt=5 TF=5 maxTF=1 @{0 463 7}
# 68 -> term2316 Nt=1 TF=1 maxTF=1 @{0 469 3}
# 7 -> term752 Nt=2 TF=2 maxTF=1 @{0 471 5}
# 71 -> term2730 Nt=1 TF=1 maxTF=1 @{0 476 1}
# 75j -> term27 Nt=1 TF=1 maxTF=1 @{0 478 5}
# 8 -> term71 Nt=5 TF=5 maxTF=1 @{0 479 3}
# 801 -> term1098 Nt=1 TF=1 maxTF=1 @{0 485 1}
# 804 -> term2302 Nt=1 TF=1 maxTF=1 @{0 487 1}
# 86 -> term3020 Nt=1 TF=1 maxTF=1 @{0 489 3}
# 860 -> term586 Nt=1 TF=1 maxTF=1 @{0 491 7}
# 9 -> term2317 Nt=2 TF=3 maxTF=2 @{0 493 5}
# 91 -> term2955 Nt=1 TF=1 maxTF=1 @{0 498 0}
# 939 -> term2311 Nt=1 TF=1 maxTF=1 @{0 500 4}
# 94 -> term327 Nt=1 TF=1 maxTF=1 @{0 502 6}
# 978 -> term2320 Nt=1 TF=1 maxTF=1 @{0 504 2}
# aachen -> term511 Nt=6 TF=6 maxTF=1 @{0 506 4}
# ab -> term232 Nt=1 TF=1 maxTF=1 @{0 513 0}
# abb -> term3305 Nt=1 TF=1 maxTF=1 @{0 514 4}
# abdomen -> term1996 Nt=1 TF=1 maxTF=1 @{0 517 0}
# abdominalen -> term1781 Nt=1 TF=1 maxTF=1 @{0 519 2}
# abfragen -> term3542 Nt=1 TF=1 maxTF=1 @{0 521 4}
# abh -> term626 Nt=4 TF=4 maxTF=1 @{0 524 0}
# abhandlung -> term1163 Nt=1 TF=1 maxTF=1 @{0 531 2}
# abil -> term3498 Nt=1 TF=1 maxTF=1 @{0 533 2}
# abmelkbetrieb -> term2135 Nt=1 TF=1 maxTF=1 @{0 535 6}
# absolutismu -> term834 Nt=1 TF=1 maxTF=1 @{0 538 0}
# academ -> term3201 Nt=2 TF=2 maxTF=1 @{0 540 0}
# acceler -> term864 Nt=1 TF=1 maxTF=1 @{0 543 6}
# accept -> term680 Nt=1 TF=1 maxTF=1 @{0 545 6}
# access -> term56 Nt=8 TF=8 maxTF=1 @{0 547 4}
# accord -> term3302 Nt=1 TF=1 maxTF=1 @{0 558 6}
# accuraci -> term1456 Nt=3 TF=3 maxTF=1 @{0 561 2}
# acetat -> term3039 Nt=1 TF=1 maxTF=1 @{0 567 2}
# acetoxi -> term2845 Nt=1 TF=2 maxTF=2 @{0 569 6}
# acetyl -> term2891 Nt=1 TF=1 maxTF=1 @{0 572 3}
# acetylcholin -> term2897 Nt=1 TF=1 maxTF=1 @{0 574 7}
# achiev -> term1540 Nt=1 TF=1 maxTF=1 @{0 577 3}
# acid -> term1217 Nt=1 TF=1 maxTF=1 @{0 579 5}
# acoust -> term1566 Nt=1 TF=1 maxTF=1 @{0 581 5}
# across -> term3623 Nt=1 TF=1 maxTF=1 @{0 583 7}
# action -> term3086 Nt=2 TF=2 maxTF=1 @{0 586 3}
# activ -> term3209 Nt=3 TF=3 maxTF=1 @{0 591 1}
# actual -> term1184 Nt=2 TF=2 maxTF=1 @{0 596 7}
# acusi -> term3254 Nt=2 TF=2 maxTF=1 @{0 599 3}
# acycl -> term3448 Nt=1 TF=1 maxTF=1 @{0 603 5}
# ad -> term2063 Nt=5 TF=5 maxTF=1 @{0 606 1}
# adapt -> term1276 Nt=17 TF=17 maxTF=1 @{0 613 7}
# adaptierbar -> term3724 Nt=1 TF=1 maxTF=1 @{0 634 1}
# adaptinol -> term2139 Nt=1 TF=1 maxTF=1 @{0 636 5}
# adsorb -> term2895 Nt=1 TF=1 maxTF=1 @{0 638 7}
# advanc -> term1264 Nt=5 TF=5 maxTF=1 @{0 641 3}
# aeorphil -> term2167 Nt=1 TF=1 maxTF=1 @{0 650 7}
# afford -> term3755 Nt=1 TF=1 maxTF=1 @{0 653 1}
# agent -> term3468 Nt=2 TF=2 maxTF=1 @{0 655 5}
# agentensimulationen -> term1808 Nt=1 TF=1 maxTF=1 @{0 659 5}
# agil -> term681 Nt=1 TF=1 maxTF=1 @{0 661 7}
# agonalen -> term2397 Nt=1 TF=1 maxTF=1 @{0 663 5}
# agrarkolonis -> term314 Nt=1 TF=1 maxTF=1 @{0 665 7}
# agrarwirtschaftsraum -> term164 Nt=1 TF=1 maxTF=1 @{0 667 3}
# agreement -> term1225 Nt=2 TF=2 maxTF=1 @{0 668 7}
# agroti -> term2889 Nt=1 TF=1 maxTF=1 @{0 673 3}
# air -> term1361 Nt=2 TF=2 maxTF=1 @{0 675 7}
# aktiv -> term3036 Nt=1 TF=1 maxTF=1 @{0 679 1}
# aktivit -> term3035 Nt=1 TF=1 maxTF=1 @{0 681 5}
# aktuel -> term2340 Nt=1 TF=1 maxTF=1 @{0 684 1}
# akuten -> term1998 Nt=1 TF=1 maxTF=1 @{0 686 3}
# akzeptanz -> term90 Nt=2 TF=2 maxTF=1 @{0 688 5}
# al -> term52 Nt=21 TF=21 maxTF=1 @{0 692 1}
# alarm -> term1884 Nt=5 TF=6 maxTF=2 @{0 716 5}
# alberti -> term688 Nt=1 TF=1 maxTF=1 @{0 725 2}
# aldehyd -> term1005 Nt=1 TF=1 maxTF=1 @{0 727 0}
# alexand -> term2314 Nt=1 TF=1 maxTF=1 @{0 729 0}
# alexandreia -> term2696 Nt=1 TF=1 maxTF=1 @{0 731 2}
# algebra -> term1409 Nt=2 TF=3 maxTF=2 @{0 733 6}
# algen -> term2168 Nt=1 TF=1 maxTF=1 @{0 737 3}
# algorithm -> term748 Nt=24 TF=24 maxTF=1 @{0 739 5}
# algorithmen -> term3482 Nt=1 TF=1 maxTF=1 @{0 765 1}
# alkali -> term2199 Nt=1 TF=1 maxTF=1 @{0 767 5}
# allergischen -> term3068 Nt=1 TF=1 maxTF=1 @{0 769 7}
# allg -> term1094 Nt=1 TF=1 maxTF=1 @{0 772 3}
# allgemeinen -> term2526 Nt=3 TF=3 maxTF=1 @{0 774 3}
# alloc -> term1552 Nt=1 TF=1 maxTF=1 @{0 780 1}
# alloplastisch -> term190 Nt=1 TF=1 maxTF=1 @{0 782 3}
# alpha -> term1834 Nt=4 TF=5 maxTF=2 @{0 783 7}
# alt -> term640 Nt=1 TF=1 maxTF=1 @{0 790 6}
# alten -> term441 Nt=2 TF=2 maxTF=1 @{0 792 4}
# alternativen -> term2590 Nt=1 TF=1 maxTF=1 @{0 796 0}
# alum -> term1048 Nt=1 TF=1 maxTF=1 @{0 798 4}
# am -> term292 Nt=13 TF=13 maxTF=1 @{0 800 4}
# ambigu -> term3501 Nt=1 TF=1 maxTF=1 @{0 817 4}
# amerikanischen -> term2056 Nt=2 TF=2 maxTF=1 @{0 820 0}
# amino -> term2892 Nt=1 TF=1 maxTF=1 @{0 824 4}
# ammonium -> term1027 Nt=1 TF=1 maxTF=1 @{0 827 0}
# amplifik -> term1635 Nt=1 TF=1 maxTF=1 @{0 829 0}
# an -> term3828 Nt=1 TF=1 maxTF=1 @{0 831 2}
# analys -> term331 Nt=11 TF=11 maxTF=1 @{0 833 6}
# analysen -> term109 Nt=1 TF=1 maxTF=1 @{0 850 4}
# analysi -> term81 Nt=30 TF=30 maxTF=1 @{0 851 6}
# analyt -> term1237 Nt=5 TF=5 maxTF=1 @{0 886 2}
# analytik -> term1629 Nt=1 TF=1 maxTF=1 @{0 895 2}
# analytisch -> term894 Nt=1 TF=1 maxTF=1 @{0 897 4}
# analytischen -> term3541 Nt=1 TF=1 maxTF=1 @{0 899 4}
# analyz -> term3521 Nt=2 TF=2 maxTF=1 @{0 902 0}
# anatomisch -> term1792 Nt=1 TF=1 maxTF=1 @{0 905 4}
# anatomischen -> term2551 Nt=1 TF=1 maxTF=1 @{0 907 6}
# anbaugebiet -> term624 Nt=1 TF=1 maxTF=1 @{0 910 2}
# andrea -> term897 Nt=1 TF=1 maxTF=1 @{0 912 0}
# anf -> term880 Nt=2 TF=2 maxTF=1 @{0 914 0}
# anfechtung -> term2155 Nt=1 TF=1 maxTF=1 @{0 918 2}
# anforderungen -> term1975 Nt=2 TF=2 maxTF=1 @{0 920 4}
# angaben -> term1097 Nt=1 TF=1 maxTF=1 @{0 924 4}
# angelegenheit -> term3164 Nt=1 TF=1 maxTF=1 @{0 926 4}
# angestellten -> term416 Nt=1 TF=1 maxTF=1 @{0 929 0}
# angewendet -> term3713 Nt=1 TF=1 maxTF=1 @{0 930 6}
# angiogen -> term1843 Nt=1 TF=1 maxTF=1 @{0 933 2}
# angiogenes -> term2268 Nt=1 TF=1 maxTF=1 @{0 935 4}
# angioplasti -> term1664 Nt=1 TF=1 maxTF=1 @{0 937 6}
# anhand -> term329 Nt=2 TF=2 maxTF=1 @{0 940 0}
# anisotrop -> term1467 Nt=1 TF=1 maxTF=1 @{0 944 0}
# ank -> term489 Nt=2 TF=2 maxTF=1 @{0 946 2}
# anl -> term947 Nt=2 TF=2 maxTF=1 @{0 948 6}
# anlieferungsmilch -> term1989 Nt=1 TF=1 maxTF=1 @{0 951 0}
# anna -> term1124 Nt=1 TF=1 maxTF=1 @{0 953 2}
# annual -> term323 Nt=1 TF=1 maxTF=1 @{0 955 2}
# anreicherung -> term290 Nt=1 TF=1 maxTF=1 @{0 956 6}
# ansatz -> term3819 Nt=1 TF=1 maxTF=1 @{0 958 2}
# anspr -> term2405 Nt=1 TF=1 maxTF=1 @{0 960 6}
# ant -> term1589 Nt=1 TF=1 maxTF=1 @{0 963 0}
# anteil -> term402 Nt=1 TF=1 maxTF=1 @{0 965 2}
# anti -> term2713 Nt=1 TF=1 maxTF=1 @{0 967 0}
# antibiot -> term3751 Nt=1 TF=1 maxTF=1 @{0 969 4}
# antoniu -> term1212 Nt=1 TF=1 maxTF=1 @{0 972 0}
# anwendbarkeit -> term2057 Nt=1 TF=1 maxTF=1 @{0 974 0}
# anwendung -> term60 Nt=5 TF=5 maxTF=1 @{0 976 2}
# aorta -> term2362 Nt=1 TF=1 maxTF=1 @{0 984 2}
# aortenmedia -> term2365 Nt=1 TF=1 maxTF=1 @{0 986 4}
# apologetischen -> term1797 Nt=1 TF=1 maxTF=1 @{0 988 6}
# apomorphin -> term2125 Nt=1 TF=1 maxTF=1 @{0 991 0}
# apparatur -> term1138 Nt=1 TF=1 maxTF=1 @{0 993 2}
# append -> term1966 Nt=1 TF=1 maxTF=1 @{0 995 2}
# appli -> term1578 Nt=5 TF=5 maxTF=1 @{0 997 4}
# applic -> term747 Nt=29 TF=29 maxTF=1 @{0 1007 2}
# approach -> term451 Nt=14 TF=14 maxTF=1 @{0 1039 0}
# april -> term2161 Nt=1 TF=1 maxTF=1 @{0 1059 4}
# aqueou -> term370 Nt=1 TF=1 maxTF=1 @{0 1061 6}
# arbeit -> term1059 Nt=3 TF=3 maxTF=1 @{0 1063 4}
# arbeiten -> term3065 Nt=1 TF=1 maxTF=1 @{0 1069 0}
# arbeitnehmerpolitik -> term3138 Nt=1 TF=1 maxTF=1 @{0 1071 4}
# arbeitsabl -> term3801 Nt=1 TF=1 maxTF=1 @{0 1074 0}
# arbeitsgestaltung -> term1766 Nt=3 TF=3 maxTF=1 @{0 1076 4}
# arbeitslo -> term53 Nt=1 TF=1 maxTF=1 @{0 1081 6}
# arbeitspsychologi -> term3418 Nt=1 TF=1 maxTF=1 @{0 1082 6}
# arbeitswelt -> term3726 Nt=1 TF=1 maxTF=1 @{0 1085 2}
# arbeitszufriedenheit -> term3369 Nt=1 TF=1 maxTF=1 @{0 1087 6}
# arbitrari -> term1292 Nt=1 TF=1 maxTF=1 @{0 1090 2}
# arch -> term950 Nt=2 TF=4 maxTF=2 @{0 1092 2}
# architect -> term3738 Nt=1 TF=1 maxTF=1 @{0 1094 6}
# architectur -> term535 Nt=12 TF=12 maxTF=1 @{0 1097 2}
# architektur -> term3721 Nt=2 TF=2 maxTF=1 @{0 1114 4}
# area -> term742 Nt=3 TF=3 maxTF=1 @{0 1118 4}
# argument -> term3663 Nt=1 TF=1 maxTF=1 @{0 1124 0}
# armut -> term1014 Nt=1 TF=1 maxTF=1 @{0 1126 4}
# arrai -> term1398 Nt=2 TF=2 maxTF=1 @{0 1128 4}
# art -> term3648 Nt=2 TF=2 maxTF=1 @{0 1133 0}
# arteriel -> term2858 Nt=1 TF=1 maxTF=1 @{0 1136 4}
# arterien -> term2857 Nt=1 TF=1 maxTF=1 @{0 1139 0}
# arthritismodel -> term3069 Nt=1 TF=1 maxTF=1 @{0 1141 4}
# articl -> term3253 Nt=1 TF=1 maxTF=1 @{0 1144 0}
# artifici -> term3267 Nt=2 TF=2 maxTF=1 @{0 1146 4}
# artist -> term3685 Nt=1 TF=1 maxTF=1 @{0 1151 0}
# artwork -> term3563 Nt=3 TF=3 maxTF=1 @{0 1153 4}
# aryl -> term2764 Nt=1 TF=1 maxTF=1 @{0 1159 0}
# arzt -> term964 Nt=1 TF=1 maxTF=1 @{0 1161 4}
# ascaridenerkrankung -> term2357 Nt=1 TF=1 maxTF=1 @{0 1163 4}
# ascit -> term2909 Nt=1 TF=1 maxTF=1 @{0 1165 6}
# asia -> term1191 Nt=2 TF=2 maxTF=1 @{0 1168 2}
# aspect -> term3505 Nt=1 TF=1 maxTF=1 @{0 1170 6}
# aspekt -> term11 Nt=8 TF=8 maxTF=1 @{0 1173 2}
# assembl -> term3493 Nt=1 TF=1 maxTF=1 @{0 1182 0}
# assess -> term3097 Nt=3 TF=3 maxTF=1 @{0 1184 4}
# assign -> term3586 Nt=1 TF=1 maxTF=1 @{0 1190 4}
# assist -> term1453 Nt=1 TF=1 maxTF=1 @{0 1193 0}
# asthmakranken -> term2104 Nt=1 TF=1 maxTF=1 @{0 1195 2}
# asynchron -> term1352 Nt=1 TF=1 maxTF=1 @{0 1197 4}
# atheliea -> term350 Nt=2 TF=2 maxTF=1 @{0 1199 4}
# atmosph -> term3641 Nt=1 TF=1 maxTF=1 @{0 1203 4}
# atmospher -> term1007 Nt=1 TF=1 maxTF=1 @{0 1206 0}
# atom -> term2335 Nt=1 TF=1 maxTF=1 @{0 1208 0}
# atomi -> term1627 Nt=1 TF=1 maxTF=1 @{0 1210 2}
# atomkernen -> term572 Nt=2 TF=2 maxTF=1 @{0 1212 4}
# atopiebedingt -> term2107 Nt=1 TF=1 maxTF=1 @{0 1215 6}
# attack -> term1366 Nt=5 TF=5 maxTF=1 @{0 1218 0}
# attraktivit -> term719 Nt=1 TF=1 maxTF=1 @{0 1225 4}
# attribut -> term3595 Nt=2 TF=2 maxTF=1 @{0 1227 4}
# atypisch -> term2137 Nt=1 TF=1 maxTF=1 @{0 1231 2}
# au -> term268 Nt=26 TF=27 maxTF=2 @{0 1233 4}
# auditor -> term3740 Nt=1 TF=1 maxTF=1 @{0 1263 1}
# auf -> term122 Nt=35 TF=36 maxTF=2 @{0 1265 5}
# aufbau -> term795 Nt=3 TF=3 maxTF=1 @{0 1303 4}
# auff -> term1649 Nt=1 TF=1 maxTF=1 @{0 1307 2}
# auffanggesellschaft -> term2285 Nt=1 TF=1 maxTF=1 @{0 1309 4}
# aufgaben -> term3277 Nt=2 TF=2 maxTF=1 @{0 1311 6}
# aufkl -> term849 Nt=1 TF=1 maxTF=1 @{0 1316 0}
# aufl -> term873 Nt=1 TF=1 maxTF=1 @{0 1318 0}
# aufrechnungsbefugni -> term2760 Nt=1 TF=1 maxTF=1 @{0 1320 0}
# auftreten -> term2575 Nt=1 TF=1 maxTF=1 @{0 1322 4}
# aufwand -> term234 Nt=1 TF=1 maxTF=1 @{0 1325 0}
# aug -> term2393 Nt=1 TF=1 maxTF=1 @{0 1326 4}
# ausblick -> term3779 Nt=1 TF=1 maxTF=1 @{0 1328 6}
# ausdruck -> term2249 Nt=1 TF=1 maxTF=1 @{0 1331 2}
# auseinandersetzung -> term2592 Nt=1 TF=1 maxTF=1 @{0 1333 4}
# ausgab -> term2337 Nt=1 TF=1 maxTF=1 @{0 1336 0}
# ausgang -> term1750 Nt=1 TF=1 maxTF=1 @{0 1338 2}
# ausgangsr -> term1608 Nt=2 TF=2 maxTF=1 @{0 1340 4}
# ausgestaltung -> term2273 Nt=1 TF=1 maxTF=1 @{0 1343 6}
# ausgew -> term2205 Nt=1 TF=1 maxTF=1 @{0 1346 0}
# ausgleichsvorg -> term2569 Nt=1 TF=1 maxTF=1 @{0 1348 2}
# ausgleichsvorga -> term2765 Nt=1 TF=1 maxTF=1 @{0 1350 6}
# ausgrabung -> term951 Nt=2 TF=2 maxTF=1 @{0 1353 2}
# aushandlungen -> term1809 Nt=1 TF=1 maxTF=1 @{0 1355 4}
# auslobung -> term1915 Nt=1 TF=1 maxTF=1 @{0 1357 6}
# ausr -> term3120 Nt=1 TF=1 maxTF=1 @{0 1360 0}
# aussenbeziehungen -> term469 Nt=1 TF=1 maxTF=1 @{0 1362 4}
# aussenstel -> term773 Nt=3 TF=3 maxTF=1 @{0 1364 2}
# ausstellung -> term935 Nt=2 TF=2 maxTF=1 @{0 1368 6}
# austauschtransfus -> term2878 Nt=1 TF=1 maxTF=1 @{0 1371 0}
# austria -> term3604 Nt=1 TF=1 maxTF=1 @{0 1373 4}
# auswahl -> term1494 Nt=3 TF=3 maxTF=1 @{0 1376 0}
# auswirkungen -> term124 Nt=2 TF=2 maxTF=1 @{0 1382 0}
# authent -> term3146 Nt=1 TF=1 maxTF=1 @{0 1385 0}
# auto -> term1413 Nt=1 TF=1 maxTF=1 @{0 1387 4}
# autom -> term1280 Nt=5 TF=5 maxTF=1 @{0 1389 6}
# automat -> term3547 Nt=2 TF=2 maxTF=1 @{0 1398 0}
# automatisierung -> term3220 Nt=1 TF=1 maxTF=1 @{0 1402 0}
# automobilindustri -> term1933 Nt=1 TF=1 maxTF=1 @{0 1404 4}
# automot -> term2411 Nt=1 TF=1 maxTF=1 @{0 1406 6}
# autonom -> term3447 Nt=3 TF=3 maxTF=1 @{0 1409 0}
# autoren -> term2497 Nt=1 TF=1 maxTF=1 @{0 1414 4}
# autorenfreundlich -> term3831 Nt=1 TF=1 maxTF=1 @{0 1417 0}
# autorit -> term738 Nt=1 TF=1 maxTF=1 @{0 1419 4}
# avoid -> term3432 Nt=2 TF=2 maxTF=1 @{0 1421 4}
# awar -> term1273 Nt=4 TF=4 maxTF=1 @{0 1425 6}
# b2b -> term2965 Nt=1 TF=1 maxTF=1 @{0 1432 6}
# backbon -> term3513 Nt=1 TF=1 maxTF=1 @{0 1435 2}
# baden -> term3071 Nt=1 TF=1 maxTF=1 @{0 1437 6}
# bagchi -> term1394 Nt=1 TF=1 maxTF=1 @{0 1440 2}
# balanc -> term1489 Nt=2 TF=2 maxTF=1 @{0 1442 2}
# bandwidth -> term3212 Nt=1 TF=1 maxTF=1 @{0 1447 0}
# bankdienstleistungen -> term1814 Nt=1 TF=1 maxTF=1 @{0 1449 4}
# bariumsulfat -> term2533 Nt=1 TF=1 maxTF=1 @{0 1451 6}
# barrier -> term1403 Nt=1 TF=1 maxTF=1 @{0 1454 2}
# baryon -> term920 Nt=1 TF=1 maxTF=1 @{0 1456 4}
# base -> term373 Nt=37 TF=39 maxTF=2 @{0 1458 4}
# baselin -> term1314 Nt=1 TF=1 maxTF=1 @{0 1494 2}
# basi -> term613 Nt=5 TF=5 maxTF=1 @{0 1496 2}
# basic -> term3474 Nt=1 TF=1 maxTF=1 @{0 1505 4}
# basidiomycet -> term349 Nt=2 TF=2 maxTF=1 @{0 1508 0}
# basiert -> term1632 Nt=3 TF=3 maxTF=1 @{0 1512 0}
# basileio -> term1206 Nt=1 TF=1 maxTF=1 @{0 1517 2}
# batteri -> term3677 Nt=1 TF=1 maxTF=1 @{0 1519 2}
# bau -> term727 Nt=2 TF=2 maxTF=1 @{0 1521 6}
# bauchh -> term1700 Nt=1 TF=1 maxTF=1 @{0 1526 0}
# baugewerk -> term1737 Nt=1 TF=1 maxTF=1 @{0 1528 2}
# baulastpflichtig -> term993 Nt=1 TF=1 maxTF=1 @{0 1530 4}
# bayer -> term1106 Nt=2 TF=2 maxTF=1 @{0 1532 4}
# bayern -> term460 Nt=2 TF=2 maxTF=1 @{0 1536 4}
# bcl -> term2453 Nt=1 TF=1 maxTF=1 @{0 1540 4}
# bdd -> term683 Nt=1 TF=1 maxTF=1 @{0 1542 6}
# be -> term633 Nt=3 TF=3 maxTF=1 @{0 1544 4}
# beam -> term2676 Nt=1 TF=1 maxTF=1 @{0 1549 6}
# beck -> term2321 Nt=1 TF=1 maxTF=1 @{0 1552 2}
# becken -> term1663 Nt=1 TF=1 maxTF=1 @{0 1554 4}
# bed -> term3437 Nt=2 TF=2 maxTF=1 @{0 1556 6}
# bedeutung -> term1491 Nt=8 TF=8 maxTF=1 @{0 1561 2}
# beeinflussung -> term638 Nt=1 TF=1 maxTF=1 @{0 1573 4}
# beeinflussungsm -> term2887 Nt=1 TF=1 maxTF=1 @{0 1575 2}
# befo -> term2944 Nt=1 TF=1 maxTF=1 @{0 1577 6}
# befragung -> term3552 Nt=1 TF=2 maxTF=2 @{0 1580 2}
# befunden -> term2363 Nt=1 TF=1 maxTF=1 @{0 1582 7}
# beg -> term2786 Nt=1 TF=1 maxTF=1 @{0 1585 1}
# beginnenden -> term1011 Nt=1 TF=1 maxTF=1 @{0 1587 5}
# begleitforschung -> term1638 Nt=1 TF=1 maxTF=1 @{0 1589 5}
# begrenzt -> term3714 Nt=1 TF=1 maxTF=1 @{0 1591 7}
# begriff -> term997 Nt=2 TF=2 maxTF=1 @{0 1594 3}
# begriffsfestlegung -> term2632 Nt=1 TF=1 maxTF=1 @{0 1598 3}
# behandlung -> term208 Nt=3 TF=3 maxTF=1 @{0 1600 7}
# beharrung -> term553 Nt=1 TF=1 maxTF=1 @{0 1605 1}
# behaviour -> term1344 Nt=2 TF=2 maxTF=1 @{0 1606 7}
# beherrschten -> term2983 Nt=1 TF=1 maxTF=1 @{0 1611 3}
# bei -> term156 Nt=55 TF=60 maxTF=2 @{0 1613 7}
# beim -> term409 Nt=6 TF=6 maxTF=1 @{0 1664 4}
# beinbereich -> term1662 Nt=1 TF=1 maxTF=1 @{0 1674 0}
# beispiel -> term295 Nt=6 TF=6 maxTF=1 @{0 1676 2}
# beispielen -> term3279 Nt=2 TF=2 maxTF=1 @{0 1686 0}
# beispielpr -> term3773 Nt=1 TF=1 maxTF=1 @{0 1690 4}
# beitr -> term74 Nt=12 TF=12 maxTF=1 @{0 1693 0}
# beitrag -> term207 Nt=16 TF=16 maxTF=1 @{0 1707 4}
# bek -> term2579 Nt=1 TF=1 maxTF=1 @{0 1727 6}
# belief -> term2647 Nt=6 TF=6 maxTF=1 @{0 1730 2}
# bemerkungen -> term3787 Nt=1 TF=1 maxTF=1 @{0 1740 4}
# ben -> term630 Nt=3 TF=3 maxTF=1 @{0 1743 0}
# benachbarten -> term843 Nt=1 TF=1 maxTF=1 @{0 1749 0}
# bench -> term1396 Nt=1 TF=1 maxTF=1 @{0 1751 0}
# benchit -> term1541 Nt=1 TF=1 maxTF=1 @{0 1753 0}
# benchmark -> term3104 Nt=4 TF=4 maxTF=1 @{0 1755 2}
# benefit -> term3566 Nt=1 TF=1 maxTF=1 @{0 1762 6}
# benomyl -> term196 Nt=1 TF=1 maxTF=1 @{0 1765 2}
# benutzerbeteiligung -> term3718 Nt=3 TF=3 maxTF=1 @{0 1766 6}
# benutzerorientiert -> term2957 Nt=1 TF=1 maxTF=1 @{0 1771 4}
# benutzt -> term2023 Nt=1 TF=1 maxTF=1 @{0 1774 0}
# benutzung -> term3719 Nt=1 TF=1 maxTF=1 @{0 1776 2}
# benwirtschaft -> term759 Nt=1 TF=1 maxTF=1 @{0 1778 6}
# benz -> term2358 Nt=1 TF=1 maxTF=1 @{0 1780 6}
# benzodiazepin -> term2773 Nt=1 TF=1 maxTF=1 @{0 1783 0}
# ber -> term174 Nt=45 TF=48 maxTF=2 @{0 1785 4}
# berechnung -> term3183 Nt=1 TF=1 maxTF=1 @{0 1829 5}
# berechtigt -> term1906 Nt=1 TF=1 maxTF=1 @{0 1832 1}
# beredsamkeit -> term517 Nt=1 TF=1 maxTF=1 @{0 1834 3}
# berfeld -> term382 Nt=1 TF=1 maxTF=1 @{0 1836 1}
# berg -> term445 Nt=27 TF=27 maxTF=1 @{0 1837 7}
# bergang -> term2733 Nt=1 TF=1 maxTF=1 @{0 1854 3}
# bergangsmetallen -> term2743 Nt=1 TF=1 maxTF=1 @{0 1856 7}
# bergisch -> term378 Nt=5 TF=6 maxTF=2 @{0 1859 3}
# bergischem -> term988 Nt=1 TF=1 maxTF=1 @{0 1866 0}
# bergischen -> term672 Nt=4 TF=6 maxTF=3 @{0 1868 0}
# berh -> term1876 Nt=1 TF=1 maxTF=1 @{0 1872 4}
# bericht -> term1194 Nt=1 TF=1 maxTF=1 @{0 1874 6}
# berkonfidenz -> term2945 Nt=1 TF=1 maxTF=1 @{0 1876 6}
# berlin -> term2132 Nt=3 TF=4 maxTF=2 @{0 1879 2}
# berschreitend -> term2215 Nt=1 TF=1 maxTF=1 @{0 1885 3}
# berschu -> term2804 Nt=1 TF=1 maxTF=1 @{0 1887 5}
# bersetzungen -> term1597 Nt=1 TF=1 maxTF=1 @{0 1890 1}
# bersichtsstudi -> term1780 Nt=1 TF=1 maxTF=1 @{0 1892 3}
# bertragern -> term3185 Nt=1 TF=1 maxTF=1 @{0 1894 5}
# bertragung -> term2060 Nt=3 TF=3 maxTF=1 @{0 1897 1}
# bertragungsnetzen -> term3364 Nt=1 TF=1 maxTF=1 @{0 1901 1}
# beruflich -> term2255 Nt=1 TF=1 maxTF=1 @{0 1903 5}
# beruflichen -> term2589 Nt=1 TF=1 maxTF=1 @{0 1905 7}
# berufsentscheidung -> term2591 Nt=1 TF=1 maxTF=1 @{0 1908 3}
# berufsgenossenschaft -> term1734 Nt=1 TF=1 maxTF=1 @{0 1910 7}
# beschaffungsmarkt -> term3075 Nt=1 TF=1 maxTF=1 @{0 1913 1}
# beschreibung -> term3048 Nt=1 TF=1 maxTF=1 @{0 1915 5}
# beschreibungen -> term3822 Nt=1 TF=1 maxTF=1 @{0 1918 1}
# beschu -> term798 Nt=1 TF=1 maxTF=1 @{0 1920 5}
# besond -> term422 Nt=2 TF=2 maxTF=1 @{0 1922 5}
# besonder -> term1760 Nt=6 TF=6 maxTF=1 @{0 1926 5}
# bestandsaufnahm -> term2824 Nt=1 TF=1 maxTF=1 @{0 1936 7}
# bestechlichkeit -> term417 Nt=1 TF=1 maxTF=1 @{0 1939 3}
# bestechung -> term418 Nt=1 TF=1 maxTF=1 @{0 1941 1}
# bestimmung -> term772 Nt=6 TF=6 maxTF=1 @{0 1942 7}
# bestimmungen -> term2693 Nt=1 TF=1 maxTF=1 @{0 1951 5}
# bet -> term2825 Nt=2 TF=2 maxTF=1 @{0 1954 1}
# beta -> term2754 Nt=2 TF=2 maxTF=1 @{0 1957 5}
# betondruckgliedern -> term3047 Nt=1 TF=1 maxTF=1 @{0 1961 3}
# betrieb -> term2984 Nt=1 TF=1 maxTF=1 @{0 1963 7}
# betrieben -> term1968 Nt=1 TF=1 maxTF=1 @{0 1966 3}
# betrieblich -> term3804 Nt=1 TF=1 maxTF=1 @{0 1968 5}
# betriebskennlinien -> term3786 Nt=1 TF=1 maxTF=1 @{0 1971 1}
# beurteilung -> term1988 Nt=4 TF=4 maxTF=1 @{0 1973 5}
# bewegungsst -> term2144 Nt=1 TF=1 maxTF=1 @{0 1980 5}
# bewei -> term2114 Nt=2 TF=2 maxTF=1 @{0 1982 7}
# bewertung -> term696 Nt=4 TF=4 maxTF=1 @{0 1987 1}
# bewertungsmethoden -> term3382 Nt=2 TF=2 maxTF=1 @{0 1994 1}
# bewusst -> term2612 Nt=1 TF=1 maxTF=1 @{0 1998 1}
# beziehung -> term1930 Nt=1 TF=1 maxTF=1 @{0 2000 5}
# bgb -> term3248 Nt=1 TF=1 maxTF=1 @{0 2002 7}
# bi -> term305 Nt=20 TF=21 maxTF=2 @{0 2005 3}
# bibliogr -> term1593 Nt=1 TF=1 maxTF=1 @{0 2031 0}
# bibliometr -> term739 Nt=2 TF=2 maxTF=1 @{0 2033 2}
# bibliometri -> term107 Nt=1 TF=1 maxTF=1 @{0 2036 2}
# bibliometrisch -> term8 Nt=9 TF=9 maxTF=1 @{0 2037 4}
# bibliotheken -> term49 Nt=1 TF=1 maxTF=1 @{0 2045 4}
# bibliotheksdaten -> term35 Nt=1 TF=1 maxTF=1 @{0 2046 4}
# bieten -> term2766 Nt=1 TF=1 maxTF=1 @{0 2047 2}
# big -> term3145 Nt=1 TF=1 maxTF=1 @{0 2049 6}
# bilan -> term3297 Nt=1 TF=1 maxTF=1 @{0 2052 2}
# bildung -> term1139 Nt=3 TF=3 maxTF=1 @{0 2054 6}
# bildungsangebot -> term3139 Nt=1 TF=1 maxTF=1 @{0 2060 6}
# bin -> term2767 Nt=1 TF=1 maxTF=1 @{0 2063 2}
# bina -> term2109 Nt=1 TF=1 maxTF=1 @{0 2065 6}
# binari -> term3540 Nt=1 TF=1 maxTF=1 @{0 2068 0}
# bind -> term602 Nt=2 TF=2 maxTF=1 @{0 2070 4}
# bindenden -> term2096 Nt=1 TF=1 maxTF=1 @{0 2074 6}
# bio -> term2979 Nt=2 TF=2 maxTF=1 @{0 2077 0}
# biochemi -> term2099 Nt=1 TF=1 maxTF=1 @{0 2080 6}
# biogasreaktoren -> term1058 Nt=1 TF=1 maxTF=1 @{0 2083 0}
# biographi -> term2975 Nt=1 TF=1 maxTF=1 @{0 2085 0}
# bioinformat -> term1430 Nt=1 TF=1 maxTF=1 @{0 2087 4}
# biologi -> term1468 Nt=1 TF=1 maxTF=1 @{0 2089 6}
# biologisch -> term2659 Nt=1 TF=1 maxTF=1 @{0 2092 0}
# biomass -> term1060 Nt=1 TF=1 maxTF=1 @{0 2094 4}
# biomechanisch -> term2464 Nt=1 TF=1 maxTF=1 @{0 2096 4}
# biomed -> term1253 Nt=1 TF=1 maxTF=1 @{0 2098 6}
# biorobot -> term3674 Nt=1 TF=1 maxTF=1 @{0 2100 6}
# biotechnisch -> term2028 Nt=2 TF=2 maxTF=1 @{0 2103 2}
# biotechnologi -> term1068 Nt=1 TF=1 maxTF=1 @{0 2107 4}
# biotransform -> term806 Nt=1 TF=1 maxTF=1 @{0 2109 4}
# biped -> term3671 Nt=2 TF=2 maxTF=1 @{0 2111 4}
# bisherig -> term326 Nt=1 TF=1 maxTF=1 @{0 2115 2}
# bitcoin -> term3690 Nt=1 TF=1 maxTF=1 @{0 2116 6}
# bl -> term2353 Nt=2 TF=2 maxTF=1 @{0 2119 2}
# bla -> term2118 Nt=2 TF=2 maxTF=1 @{0 2122 2}
# blac -> term1478 Nt=1 TF=1 maxTF=1 @{0 2126 4}
# blasenfeldl -> term1761 Nt=1 TF=1 maxTF=1 @{0 2128 6}
# blast -> term1660 Nt=1 TF=1 maxTF=1 @{0 2131 0}
# blaster -> term3516 Nt=1 TF=1 maxTF=1 @{0 2133 2}
# blei -> term1036 Nt=1 TF=1 maxTF=1 @{0 2135 6}
# blend -> term3293 Nt=1 TF=1 maxTF=1 @{0 2137 6}
# blinder -> term3746 Nt=1 TF=1 maxTF=1 @{0 2140 2}
# blindversuch -> term2990 Nt=1 TF=1 maxTF=1 @{0 2142 6}
# block -> term3149 Nt=2 TF=2 maxTF=1 @{0 2145 2}
# blut -> term2370 Nt=2 TF=2 maxTF=1 @{0 2149 0}
# blutalkoholwerten -> term230 Nt=1 TF=1 maxTF=1 @{0 2153 0}
# blutdrucken -> term2382 Nt=1 TF=1 maxTF=1 @{0 2154 4}
# blute -> term1964 Nt=1 TF=1 maxTF=1 @{0 2156 6}
# blutegelmuskulatur -> term2893 Nt=1 TF=1 maxTF=1 @{0 2159 0}
# blutentnahmebefund -> term226 Nt=1 TF=1 maxTF=1 @{0 2161 4}
# blutlipiden -> term2559 Nt=1 TF=1 maxTF=1 @{0 2163 0}
# blutzuck -> term2557 Nt=1 TF=1 maxTF=1 @{0 2165 4}
# bmbf -> term136 Nt=1 TF=1 maxTF=1 @{0 2168 0}
# bodenextrakten -> term2628 Nt=1 TF=1 maxTF=1 @{0 2169 2}
# bodentyp -> term631 Nt=1 TF=1 maxTF=1 @{0 2171 6}
# bodi -> term1555 Nt=3 TF=3 maxTF=1 @{0 2173 4}
# bonn -> term338 Nt=6 TF=6 maxTF=1 @{0 2179 4}
# book -> term93 Nt=1 TF=1 maxTF=1 @{0 2186 4}
# bound -> term3340 Nt=2 TF=2 maxTF=1 @{0 2187 6}
# bourgeoi -> term3316 Nt=1 TF=1 maxTF=1 @{0 2192 2}
# br -> term423 Nt=1 TF=1 maxTF=1 @{0 2194 6}
# brandenburg -> term459 Nt=3 TF=3 maxTF=1 @{0 2196 4}
# braunschweig -> term1063 Nt=1 TF=1 maxTF=1 @{0 2200 6}
# breach -> term3258 Nt=1 TF=1 maxTF=1 @{0 2202 6}
# break -> term916 Nt=1 TF=1 maxTF=1 @{0 2205 2}
# bridg -> term3739 Nt=1 TF=1 maxTF=1 @{0 2207 2}
# brot -> term1020 Nt=1 TF=1 maxTF=1 @{0 2209 6}
# bruchmechanisch -> term2600 Nt=1 TF=1 maxTF=1 @{0 2211 6}
# buch -> term960 Nt=1 TF=1 maxTF=1 @{0 2214 2}
# buchbesprechung -> term3130 Nt=1 TF=1 maxTF=1 @{0 2216 2}
# buddhistischen -> term1799 Nt=1 TF=1 maxTF=1 @{0 2218 6}
# build -> term1452 Nt=5 TF=5 maxTF=1 @{0 2221 0}
# bullensperma -> term2523 Nt=1 TF=1 maxTF=1 @{0 2230 2}
# bundesbeschluss -> term1657 Nt=1 TF=1 maxTF=1 @{0 2232 6}
# bundesforschungsanst -> term1065 Nt=1 TF=1 maxTF=1 @{0 2235 0}
# bundesgesetz -> term321 Nt=1 TF=1 maxTF=1 @{0 2237 0}
# bundesliga -> term3479 Nt=1 TF=1 maxTF=1 @{0 2238 4}
# bundesmin -> term1141 Nt=1 TF=1 maxTF=1 @{0 2241 0}
# bundesminist -> term767 Nt=1 TF=1 maxTF=1 @{0 2243 0}
# bundesministerium -> term1155 Nt=1 TF=1 maxTF=1 @{0 2245 0}
# bundesrepublik -> term47 Nt=1 TF=1 maxTF=1 @{0 2247 0}
# burnout -> term2247 Nt=1 TF=1 maxTF=1 @{0 2247 6}
# busi -> term740 Nt=4 TF=4 maxTF=1 @{0 2250 0}
# bypass -> term3703 Nt=1 TF=1 maxTF=1 @{0 2257 2}
# cach -> term1304 Nt=4 TF=4 maxTF=1 @{0 2259 6}
# cadavera -> term670 Nt=2 TF=2 maxTF=1 @{0 2266 2}
# cadmium -> term1031 Nt=1 TF=1 maxTF=1 @{0 2268 4}
# cadmiumsalzen -> term2206 Nt=1 TF=1 maxTF=1 @{0 2270 4}
# caesarea -> term2815 Nt=1 TF=1 maxTF=1 @{0 2272 6}
# calcium -> term2694 Nt=1 TF=1 maxTF=1 @{0 2275 2}
# calcul -> term2669 Nt=2 TF=2 maxTF=1 @{0 2277 6}
# can -> term3562 Nt=2 TF=2 maxTF=1 @{0 2282 2}
# candid -> term3148 Nt=2 TF=2 maxTF=1 @{0 2286 4}
# canicola -> term2643 Nt=1 TF=1 maxTF=1 @{0 2291 0}
# captur -> term1533 Nt=3 TF=3 maxTF=1 @{0 2293 4}
# car -> term3352 Nt=1 TF=1 maxTF=1 @{0 2299 4}
# carbon -> term1642 Nt=3 TF=3 maxTF=1 @{0 2302 0}
# carl -> term2662 Nt=1 TF=1 maxTF=1 @{0 2308 4}
# carlo -> term1520 Nt=1 TF=1 maxTF=1 @{0 2311 0}
# carnitinstoffwechsel -> term2444 Nt=1 TF=1 maxTF=1 @{0 2313 2}
# carpio -> term206 Nt=1 TF=1 maxTF=1 @{0 2315 4}
# casablanca -> term3295 Nt=1 TF=1 maxTF=1 @{0 2317 0}
# case -> term1354 Nt=11 TF=11 maxTF=1 @{0 2319 4}
# cash -> term1753 Nt=1 TF=1 maxTF=1 @{0 2335 4}
# categor -> term3614 Nt=1 TF=1 maxTF=1 @{0 2337 6}
# cation -> term1046 Nt=1 TF=1 maxTF=1 @{0 2340 2}
# caus -> term1887 Nt=3 TF=3 maxTF=1 @{0 2342 2}
# caylei -> term1692 Nt=1 TF=1 maxTF=1 @{0 2348 0}
# cc -> term1640 Nt=1 TF=1 maxTF=1 @{0 2350 2}
# ceacam1 -> term2475 Nt=1 TF=1 maxTF=1 @{0 2352 4}
# cec -> term3351 Nt=2 TF=2 maxTF=1 @{0 2355 0}
# cec2018 -> term3321 Nt=1 TF=1 maxTF=1 @{0 2359 0}
# cell -> term1868 Nt=3 TF=3 maxTF=1 @{0 2361 4}
# centimet -> term3494 Nt=1 TF=1 maxTF=1 @{0 2368 0}
# central -> term3157 Nt=2 TF=2 maxTF=1 @{0 2370 4}
# centuri -> term3232 Nt=1 TF=1 maxTF=1 @{0 2375 0}
# certif -> term3300 Nt=1 TF=1 maxTF=1 @{0 2377 4}
# certifi -> term3307 Nt=1 TF=1 maxTF=1 @{0 2380 0}
# cf -> term2072 Nt=2 TF=2 maxTF=1 @{0 2382 4}
# cfd -> term1324 Nt=1 TF=1 maxTF=1 @{0 2386 6}
# chain -> term2508 Nt=2 TF=2 maxTF=1 @{0 2388 6}
# challeng -> term1864 Nt=2 TF=2 maxTF=1 @{0 2393 2}
# chamber -> term1003 Nt=1 TF=1 maxTF=1 @{0 2397 4}
# chancengleichheit -> term279 Nt=2 TF=2 maxTF=1 @{0 2399 4}
# chandigarh -> term3296 Nt=1 TF=1 maxTF=1 @{0 2402 0}
# chang -> term3780 Nt=2 TF=2 maxTF=1 @{0 2404 4}
# channel -> term3590 Nt=1 TF=1 maxTF=1 @{0 2408 2}
# character -> term594 Nt=3 TF=3 maxTF=1 @{0 2410 6}
# characterist -> term1530 Nt=1 TF=1 maxTF=1 @{0 2416 2}
# charakterisierung -> term1849 Nt=5 TF=5 maxTF=1 @{0 2418 4}
# charakterologisch -> term2807 Nt=1 TF=1 maxTF=1 @{0 2427 6}
# charg -> term160 Nt=1 TF=1 maxTF=1 @{0 2430 2}
# charm -> term917 Nt=1 TF=1 maxTF=1 @{0 2431 6}
# chasm -> term3737 Nt=1 TF=1 maxTF=1 @{0 2433 6}
# check -> term3602 Nt=1 TF=1 maxTF=1 @{0 2436 2}
# checker -> term1574 Nt=1 TF=1 maxTF=1 @{0 2438 6}
# chemi -> term1712 Nt=1 TF=1 maxTF=1 @{0 2441 0}
# chemistri -> term1004 Nt=1 TF=1 maxTF=1 @{0 2443 2}
# chen -> term2403 Nt=1 TF=1 maxTF=1 @{0 2445 2}
# chenbestimmungen -> term2534 Nt=1 TF=1 maxTF=1 @{0 2447 4}
# chenreflektivit -> term608 Nt=1 TF=1 maxTF=1 @{0 2450 0}
# chines -> term2969 Nt=1 TF=1 maxTF=1 @{0 2451 6}
# chinoid -> term281 Nt=1 TF=1 maxTF=1 @{0 2454 2}
# chip -> term1461 Nt=4 TF=4 maxTF=1 @{0 2455 6}
# chir -> term341 Nt=1 TF=1 maxTF=1 @{0 2461 2}
# chiral -> term2998 Nt=1 TF=1 maxTF=1 @{0 2462 6}
# chirurgi -> term1722 Nt=1 TF=1 maxTF=1 @{0 2465 2}
# chirurgisch -> term2487 Nt=2 TF=2 maxTF=1 @{0 2467 4}
# chlorid -> term1021 Nt=1 TF=1 maxTF=1 @{0 2471 6}
# chlorochinsch -> term2394 Nt=1 TF=1 maxTF=1 @{0 2473 6}
# cho -> term2755 Nt=1 TF=1 maxTF=1 @{0 2476 0}
# cholanthren -> term2360 Nt=1 TF=1 maxTF=1 @{0 2478 4}
# choleski -> term1412 Nt=1 TF=1 maxTF=1 @{0 2480 6}
# cholezystographi -> term1723 Nt=1 TF=1 maxTF=1 @{0 2483 0}
# choos -> term3214 Nt=1 TF=1 maxTF=1 @{0 2485 2}
# christentum -> term2149 Nt=2 TF=2 maxTF=1 @{0 2487 6}
# chromatin -> term2745 Nt=1 TF=1 maxTF=1 @{0 2492 0}
# chromodynam -> term910 Nt=1 TF=1 maxTF=1 @{0 2494 4}
# chronic -> term2942 Nt=1 TF=1 maxTF=1 @{0 2496 4}
# chspsychotherapi -> term1719 Nt=1 TF=1 maxTF=1 @{0 2499 0}
# chsten -> term2407 Nt=1 TF=1 maxTF=1 @{0 2501 2}
# chternen -> term1956 Nt=1 TF=1 maxTF=1 @{0 2503 4}
# chtigkeit -> term627 Nt=1 TF=1 maxTF=1 @{0 2505 6}
# chtlichen -> term2938 Nt=1 TF=1 maxTF=1 @{0 2507 4}
# chtung -> term952 Nt=2 TF=2 maxTF=1 @{0 2510 0}
# citizen -> term3268 Nt=1 TF=1 maxTF=1 @{0 2512 2}
# civil -> term1254 Nt=1 TF=1 maxTF=1 @{0 2514 6}
# ck -> term50 Nt=6 TF=6 maxTF=1 @{0 2516 6}
# cken -> term428 Nt=3 TF=3 maxTF=1 @{0 2525 6}
# ckf -> term1605 Nt=2 TF=2 maxTF=1 @{0 2531 4}
# cksichtigung -> term1755 Nt=7 TF=7 maxTF=1 @{0 2534 6}
# cksspiela -> term2653 Nt=1 TF=1 maxTF=1 @{0 2546 6}
# classif -> term1576 Nt=3 TF=3 maxTF=1 @{0 2549 2}
# cleve -> term620 Nt=1 TF=1 maxTF=1 @{0 2554 4}
# clevischen -> term1120 Nt=1 TF=1 maxTF=1 @{0 2556 2}
# client -> term3490 Nt=1 TF=1 maxTF=1 @{0 2558 2}
# clone -> term598 Nt=1 TF=1 maxTF=1 @{0 2560 6}
# close -> term918 Nt=1 TF=1 maxTF=1 @{0 2562 4}
# cloud -> term3137 Nt=1 TF=1 maxTF=1 @{0 2564 4}
# cluster -> term1243 Nt=15 TF=15 maxTF=1 @{0 2567 0}
# cmc -> term2506 Nt=1 TF=1 maxTF=1 @{0 2584 6}
# coal -> term112 Nt=1 TF=1 maxTF=1 @{0 2587 2}
# cobol -> term2915 Nt=5 TF=5 maxTF=1 @{0 2588 4}
# cocon -> term3556 Nt=1 TF=1 maxTF=1 @{0 2593 6}
# code -> term563 Nt=4 TF=4 maxTF=1 @{0 2596 2}
# coenzym -> term1064 Nt=1 TF=1 maxTF=1 @{0 2604 2}
# coexist -> term1537 Nt=1 TF=1 maxTF=1 @{0 2606 2}
# cognit -> term2648 Nt=3 TF=3 maxTF=1 @{0 2608 4}
# cohes -> term3568 Nt=2 TF=2 maxTF=1 @{0 2614 6}
# coli -> term590 Nt=4 TF=4 maxTF=1 @{0 2618 2}
# collabor -> term903 Nt=3 TF=4 maxTF=2 @{0 2625 4}
# collect -> term1275 Nt=2 TF=2 maxTF=1 @{0 2632 1}
# collector -> term1404 Nt=1 TF=1 maxTF=1 @{0 2635 7}
# collis -> term922 Nt=1 TF=1 maxTF=1 @{0 2638 1}
# color -> term3082 Nt=1 TF=1 maxTF=1 @{0 2640 1}
# colour -> term1335 Nt=2 TF=2 maxTF=1 @{0 2642 5}
# combin -> term3770 Nt=1 TF=1 maxTF=1 @{0 2647 1}
# common -> term1560 Nt=3 TF=3 maxTF=1 @{0 2649 5}
# commun -> term986 Nt=15 TF=15 maxTF=1 @{0 2654 5}
# compar -> term1307 Nt=5 TF=5 maxTF=1 @{0 2675 5}
# comparison -> term1542 Nt=8 TF=8 maxTF=1 @{0 2684 7}
# compass -> term3492 Nt=1 TF=1 maxTF=1 @{0 2697 1}
# compet -> term3551 Nt=1 TF=1 maxTF=1 @{0 2699 5}
# competit -> term3348 Nt=1 TF=1 maxTF=1 @{0 2702 1}
# compil -> term3450 Nt=2 TF=2 maxTF=1 @{0 2704 5}
# complet -> term2709 Nt=2 TF=2 maxTF=1 @{0 2708 3}
# complex -> term1256 Nt=2 TF=2 maxTF=1 @{0 2713 1}
# complianc -> term1880 Nt=2 TF=2 maxTF=1 @{0 2717 5}
# compon -> term1301 Nt=3 TF=3 maxTF=1 @{0 2722 3}
# composit -> term1399 Nt=1 TF=1 maxTF=1 @{0 2727 1}
# compress -> term1249 Nt=1 TF=1 maxTF=1 @{0 2729 3}
# comput -> term161 Nt=31 TF=33 maxTF=3 @{0 2731 3}
# computation -> term3325 Nt=2 TF=2 maxTF=1 @{0 2762 7}
# computerunterst -> term3666 Nt=1 TF=1 maxTF=1 @{0 2766 1}
# concept -> term3475 Nt=2 TF=2 maxTF=1 @{0 2768 5}
# concern -> term3620 Nt=1 TF=1 maxTF=1 @{0 2772 7}
# conclus -> term3664 Nt=1 TF=1 maxTF=1 @{0 2775 3}
# concurr -> term1286 Nt=1 TF=1 maxTF=1 @{0 2777 7}
# condit -> term2509 Nt=1 TF=1 maxTF=1 @{0 2779 7}
# confer -> term1432 Nt=3 TF=3 maxTF=1 @{0 2782 3}
# configur -> term2288 Nt=1 TF=1 maxTF=1 @{0 2788 5}
# conflict -> term3626 Nt=1 TF=1 maxTF=1 @{0 2790 7}
# congest -> term1586 Nt=1 TF=1 maxTF=1 @{0 2793 3}
# congress -> term318 Nt=1 TF=1 maxTF=1 @{0 2795 5}
# consist -> term3343 Nt=2 TF=3 maxTF=2 @{0 2797 1}
# constrain -> term3339 Nt=1 TF=1 maxTF=1 @{0 2800 2}
# constraint -> term3749 Nt=1 TF=1 maxTF=1 @{0 2802 6}
# construct -> term3060 Nt=3 TF=3 maxTF=1 @{0 2805 2}
# consum -> term3084 Nt=2 TF=2 maxTF=1 @{0 2810 2}
# content -> term3099 Nt=1 TF=1 maxTF=1 @{0 2813 4}
# context -> term3408 Nt=2 TF=2 maxTF=1 @{0 2816 0}
# continu -> term3560 Nt=2 TF=2 maxTF=1 @{0 2820 2}
# contour -> term3511 Nt=1 TF=1 maxTF=1 @{0 2824 4}
# control -> term213 Nt=14 TF=16 maxTF=2 @{0 2827 0}
# converg -> term3150 Nt=2 TF=2 maxTF=1 @{0 2846 6}
# convert -> term3422 Nt=2 TF=2 maxTF=1 @{0 2850 4}
# convex -> term1516 Nt=1 TF=1 maxTF=1 @{0 2853 2}
# convivi -> term2243 Nt=2 TF=2 maxTF=1 @{0 2855 4}
# cooler -> term581 Nt=2 TF=2 maxTF=1 @{0 2859 4}
# cooper -> term2005 Nt=1 TF=1 maxTF=1 @{0 2862 6}
# coordin -> term1341 Nt=7 TF=7 maxTF=1 @{0 2865 0}
# core -> term3125 Nt=1 TF=1 maxTF=1 @{0 2876 4}
# correct -> term1575 Nt=2 TF=2 maxTF=1 @{0 2879 0}
# correl -> term566 Nt=3 TF=3 maxTF=1 @{0 2883 6}
# corticiacea -> term348 Nt=2 TF=2 maxTF=1 @{0 2889 6}
# corticosteroid -> term2371 Nt=1 TF=1 maxTF=1 @{0 2893 6}
# cosi -> term391 Nt=10 TF=10 maxTF=1 @{0 2896 0}
# cosmic -> term1521 Nt=1 TF=1 maxTF=1 @{0 2905 4}
# cost -> term3585 Nt=3 TF=3 maxTF=1 @{0 2907 6}
# cotton -> term1185 Nt=2 TF=2 maxTF=1 @{0 2913 0}
# counter -> term1346 Nt=2 TF=2 maxTF=1 @{0 2915 4}
# coupl -> term3673 Nt=1 TF=1 maxTF=1 @{0 2918 4}
# cours -> term2505 Nt=1 TF=1 maxTF=1 @{0 2921 0}
# cov -> term3577 Nt=1 TF=1 maxTF=1 @{0 2923 4}
# covid -> term3576 Nt=1 TF=1 maxTF=1 @{0 2926 0}
# cpux -> term3777 Nt=1 TF=1 maxTF=1 @{0 2928 4}
# crawler -> term3101 Nt=1 TF=1 maxTF=1 @{0 2931 0}
# credenti -> term3384 Nt=1 TF=1 maxTF=1 @{0 2933 4}
# critic -> term1383 Nt=3 TF=3 maxTF=1 @{0 2936 0}
# cross -> term1870 Nt=5 TF=5 maxTF=1 @{0 2942 0}
# cryptograph -> term3548 Nt=1 TF=1 maxTF=1 @{0 2951 4}
# cryptosystem -> term1367 Nt=1 TF=1 maxTF=1 @{0 2954 0}
# crystal -> term1044 Nt=1 TF=1 maxTF=1 @{0 2956 0}
# cscl -> term3567 Nt=2 TF=2 maxTF=1 @{0 2958 0}
# cst -> term2578 Nt=1 TF=1 maxTF=1 @{0 2961 4}
# cue -> term3311 Nt=1 TF=1 maxTF=1 @{0 2964 0}
# cultur -> term2036 Nt=4 TF=4 maxTF=1 @{0 2966 4}
# current -> term1435 Nt=2 TF=2 maxTF=1 @{0 2974 4}
# curricula -> term3246 Nt=1 TF=1 maxTF=1 @{0 2979 2}
# custom -> term1550 Nt=2 TF=2 maxTF=1 @{0 2981 6}
# cut -> term1390 Nt=1 TF=1 maxTF=1 @{0 2986 4}
# cyber -> term2714 Nt=1 TF=1 maxTF=1 @{0 2988 4}
# cycliz -> term810 Nt=1 TF=1 maxTF=1 @{0 2991 0}
# cyclohexadiyl -> term1709 Nt=1 TF=1 maxTF=1 @{0 2993 0}
# cyclohydrolas -> term2228 Nt=1 TF=1 maxTF=1 @{0 2995 2}
# cyprinu -> term193 Nt=1 TF=1 maxTF=1 @{0 2997 4}
# cystisch -> term2445 Nt=1 TF=1 maxTF=1 @{0 2999 0}
# czech -> term3756 Nt=1 TF=1 maxTF=1 @{0 3001 2}
# da -> term246 Nt=28 TF=30 maxTF=2 @{0 3003 6}
# dagogik -> term2275 Nt=1 TF=1 maxTF=1 @{0 3033 4}
# dagogisch -> term2224 Nt=1 TF=1 maxTF=1 @{0 3035 6}
# damp -> term3161 Nt=2 TF=2 maxTF=1 @{0 3038 0}
# danio -> term218 Nt=1 TF=1 maxTF=1 @{0 3042 0}
# dargestellt -> term289 Nt=3 TF=3 maxTF=1 @{0 3043 4}
# darstellung -> term2074 Nt=5 TF=5 maxTF=1 @{0 3047 4}
# dash -> term3527 Nt=2 TF=2 maxTF=1 @{0 3056 4}
# data -> term31 Nt=14 TF=15 maxTF=2 @{0 3060 0}
# databas -> term1376 Nt=6 TF=6 maxTF=1 @{0 3077 3}
# dataset -> term1356 Nt=2 TF=2 maxTF=1 @{0 3086 5}
# dateitransf -> term3192 Nt=1 TF=1 maxTF=1 @{0 3091 1}
# daten -> term106 Nt=3 TF=3 maxTF=1 @{0 3093 5}
# datenbanken -> term1684 Nt=2 TF=2 maxTF=1 @{0 3098 7}
# datenerfassung -> term2404 Nt=1 TF=1 maxTF=1 @{0 3103 5}
# datenintegrit -> term2408 Nt=1 TF=1 maxTF=1 @{0 3105 7}
# david -> term1690 Nt=1 TF=1 maxTF=1 @{0 3108 1}
# db4o -> term3129 Nt=3 TF=3 maxTF=1 @{0 3110 3}
# dbm -> term3700 Nt=1 TF=1 maxTF=1 @{0 3116 1}
# dchen -> term2480 Nt=1 TF=1 maxTF=1 @{0 3118 5}
# de -> term20 Nt=104 TF=119 maxTF=3 @{0 3121 1}
# debat -> term2924 Nt=1 TF=1 maxTF=1 @{0 3196 4}
# debug -> term3144 Nt=3 TF=3 maxTF=1 @{0 3199 0}
# decentr -> term3330 Nt=1 TF=1 maxTF=1 @{0 3204 4}
# decid -> term3243 Nt=1 TF=1 maxTF=1 @{0 3207 0}
# decis -> term3271 Nt=1 TF=1 maxTF=1 @{0 3209 4}
# decomposit -> term1364 Nt=6 TF=6 maxTF=1 @{0 3212 0}
# defin -> term2710 Nt=2 TF=2 maxTF=1 @{0 3220 6}
# deform -> term3767 Nt=1 TF=1 maxTF=1 @{0 3225 4}
# deikt -> term2174 Nt=1 TF=1 maxTF=1 @{0 3228 0}
# deixi -> term2172 Nt=1 TF=1 maxTF=1 @{0 3230 2}
# delai -> term1388 Nt=3 TF=3 maxTF=1 @{0 3232 4}
# delhirntrauma -> term2899 Nt=1 TF=1 maxTF=1 @{0 3238 2}
# deliv -> term1514 Nt=1 TF=1 maxTF=1 @{0 3240 6}
# dem -> term98 Nt=16 TF=17 maxTF=2 @{0 3243 0}
# demand -> term150 Nt=3 TF=3 maxTF=1 @{0 3264 3}
# demo -> term3533 Nt=1 TF=1 maxTF=1 @{0 3269 1}
# demokrati -> term2680 Nt=1 TF=1 maxTF=1 @{0 3271 5}
# demokratischen -> term1898 Nt=1 TF=1 maxTF=1 @{0 3274 1}
# demonstr -> term133 Nt=3 TF=3 maxTF=1 @{0 3276 3}
# den -> term237 Nt=35 TF=36 maxTF=2 @{0 3282 1}
# dendrit -> term1867 Nt=2 TF=2 maxTF=1 @{0 3315 6}
# denken -> term2686 Nt=1 TF=1 maxTF=1 @{0 3320 0}
# dens -> term3385 Nt=2 TF=2 maxTF=1 @{0 3322 4}
# dentin -> term1728 Nt=1 TF=1 maxTF=1 @{0 3326 0}
# depart -> term1438 Nt=1 TF=1 maxTF=1 @{0 3328 2}
# depend -> term3559 Nt=1 TF=1 maxTF=1 @{0 3330 4}
# der -> term0 Nt=222 TF=287 maxTF=3 @{0 3333 0}
# deren -> term253 Nt=6 TF=6 maxTF=1 @{0 3454 7}
# deriv -> term3579 Nt=1 TF=1 maxTF=1 @{0 3463 3}
# dern -> term2563 Nt=1 TF=1 maxTF=1 @{0 3465 7}
# deschool -> term2414 Nt=1 TF=1 maxTF=1 @{0 3468 3}
# descriptor -> term3676 Nt=1 TF=1 maxTF=1 @{0 3470 5}
# design -> term536 Nt=9 TF=9 maxTF=1 @{0 3473 1}
# designteam -> term3809 Nt=1 TF=1 maxTF=1 @{0 3487 5}
# desintegr -> term3056 Nt=1 TF=1 maxTF=1 @{0 3490 1}
# deskew -> term3083 Nt=1 TF=1 maxTF=1 @{0 3492 5}
# dessen -> term998 Nt=1 TF=1 maxTF=1 @{0 3495 1}
# detect -> term1885 Nt=16 TF=16 maxTF=1 @{0 3497 1}
# detector -> term1517 Nt=1 TF=1 maxTF=1 @{0 3514 7}
# detekt -> term1630 Nt=1 TF=1 maxTF=1 @{0 3517 1}
# detektionssystem -> term519 Nt=1 TF=1 maxTF=1 @{0 3519 3}
# determin -> term3147 Nt=2 TF=2 maxTF=1 @{0 3521 1}
# deuterierten -> term2422 Nt=1 TF=1 maxTF=1 @{0 3525 5}
# deuteronen -> term856 Nt=1 TF=1 maxTF=1 @{0 3527 7}
# deutsch -> term2217 Nt=4 TF=4 maxTF=1 @{0 3529 7}
# deutschen -> term1102 Nt=8 TF=9 maxTF=2 @{0 3536 7}
# deutschland -> term43 Nt=3 TF=3 maxTF=1 @{0 3548 4}
# develop -> term352 Nt=9 TF=9 maxTF=1 @{0 3553 0}
# devianz -> term868 Nt=1 TF=1 maxTF=1 @{0 3566 0}
# devic -> term148 Nt=4 TF=4 maxTF=1 @{0 3568 0}
# dexter -> term3765 Nt=1 TF=1 maxTF=1 @{0 3575 4}
# df -> term567 Nt=1 TF=1 maxTF=1 @{0 3578 0}
# dfig -> term3419 Nt=2 TF=2 maxTF=1 @{0 3579 6}
# dh -> term2918 Nt=1 TF=1 maxTF=1 @{0 3582 4}
# di -> term2159 Nt=1 TF=1 maxTF=1 @{0 3585 0}
# diagnos -> term2000 Nt=3 TF=3 maxTF=1 @{0 3587 2}
# diagnostik -> term1500 Nt=2 TF=2 maxTF=1 @{0 3592 6}
# diagnostisch -> term1721 Nt=1 TF=1 maxTF=1 @{0 3596 6}
# dialogablauf -> term3821 Nt=1 TF=1 maxTF=1 @{0 3599 0}
# dialogu -> term3151 Nt=1 TF=1 maxTF=1 @{0 3601 4}
# diamet -> term2329 Nt=1 TF=1 maxTF=1 @{0 3604 0}
# didymu -> term2695 Nt=1 TF=1 maxTF=1 @{0 3606 2}
# die -> term159 Nt=122 TF=135 maxTF=3 @{0 3608 6}
# dielektrischen -> term2430 Nt=1 TF=1 maxTF=1 @{0 3695 3}
# dienst -> term33 Nt=1 TF=1 maxTF=1 @{0 3697 5}
# diesbez -> term2670 Nt=1 TF=1 maxTF=1 @{0 3698 3}
# dieser -> term2500 Nt=1 TF=1 maxTF=1 @{0 3700 7}
# differ -> term215 Nt=1 TF=1 maxTF=1 @{0 3703 3}
# differenten -> term1962 Nt=1 TF=1 maxTF=1 @{0 3704 7}
# differentialdiagnos -> term2147 Nt=1 TF=1 maxTF=1 @{0 3707 1}
# differentiellen -> term1773 Nt=1 TF=1 maxTF=1 @{0 3709 3}
# differenzierung -> term1844 Nt=2 TF=2 maxTF=1 @{0 3711 5}
# diffract -> term1049 Nt=1 TF=1 maxTF=1 @{0 3715 7}
# diffus -> term1466 Nt=2 TF=2 maxTF=1 @{0 3717 7}
# difunktionellen -> term2083 Nt=1 TF=1 maxTF=1 @{0 3722 3}
# digit -> term3155 Nt=2 TF=2 maxTF=1 @{0 3724 5}
# dihydrobenzol -> term2351 Nt=1 TF=1 maxTF=1 @{0 3728 3}
# dihydropyrrol -> term2763 Nt=1 TF=1 maxTF=1 @{0 3730 5}
# diktion -> term1718 Nt=1 TF=1 maxTF=1 @{0 3733 1}
# dimens -> term3838 Nt=1 TF=1 maxTF=1 @{0 3735 3}
# dimension -> term1391 Nt=1 TF=1 maxTF=1 @{0 3737 7}
# dimensionen -> term3312 Nt=1 TF=1 maxTF=1 @{0 3739 7}
# dimeren -> term3199 Nt=1 TF=1 maxTF=1 @{0 3742 3}
# dimerisierung -> term2999 Nt=1 TF=1 maxTF=1 @{0 3744 7}
# dimethylen -> term1711 Nt=1 TF=1 maxTF=1 @{0 3747 3}
# dimva -> term3606 Nt=1 TF=1 maxTF=1 @{0 3749 5}
# diplomaci -> term3018 Nt=1 TF=1 maxTF=1 @{0 3752 1}
# diradik -> term1710 Nt=1 TF=2 maxTF=2 @{0 3754 5}
# direkt -> term3051 Nt=2 TF=2 maxTF=1 @{0 3757 0}
# direkten -> term3716 Nt=1 TF=1 maxTF=1 @{0 3761 6}
# disast -> term361 Nt=4 TF=4 maxTF=1 @{0 3764 2}
# disciplin -> term3426 Nt=1 TF=1 maxTF=1 @{0 3772 2}
# discours -> term3689 Nt=1 TF=1 maxTF=1 @{0 3774 6}
# discoveri -> term3675 Nt=1 TF=1 maxTF=1 @{0 3777 2}
# discret -> term3377 Nt=2 TF=2 maxTF=1 @{0 3779 6}
# disk -> term3581 Nt=1 TF=1 maxTF=1 @{0 3784 0}
# diskuss -> term1035 Nt=1 TF=1 maxTF=1 @{0 3786 4}
# diskussionsgrupp -> term3730 Nt=1 TF=1 maxTF=1 @{0 3788 4}
# dispar -> term3656 Nt=1 TF=1 maxTF=1 @{0 3791 0}
# dispatch -> term3435 Nt=1 TF=1 maxTF=1 @{0 3793 4}
# dissen -> term1923 Nt=1 TF=1 maxTF=1 @{0 3796 0}
# dissip -> term80 Nt=2 TF=2 maxTF=1 @{0 3798 2}
# distanc -> term3217 Nt=2 TF=2 maxTF=1 @{0 3801 4}
# distanzm -> term2664 Nt=1 TF=1 maxTF=1 @{0 3806 0}
# distribut -> term1239 Nt=15 TF=15 maxTF=1 @{0 3808 4}
# distrito -> term3152 Nt=1 TF=1 maxTF=1 @{0 3826 2}
# disziplinen -> term1178 Nt=1 TF=1 maxTF=1 @{0 3828 6}
# dithmarsch -> term1108 Nt=1 TF=1 maxTF=1 @{0 3830 6}
# divid -> term2511 Nt=1 TF=1 maxTF=1 @{0 3832 6}
# dix -> term2318 Nt=1 TF=1 maxTF=1 @{0 3835 2}
# dlichen -> term1916 Nt=1 TF=1 maxTF=1 @{0 3837 4}
# dlicher -> term2861 Nt=1 TF=1 maxTF=1 @{0 3839 6}
# dna -> term371 Nt=4 TF=4 maxTF=1 @{0 3842 2}
# document -> term3202 Nt=2 TF=2 maxTF=1 @{0 3850 0}
# doi -> term1803 Nt=1 TF=1 maxTF=1 @{0 3853 6}
# dom -> term2473 Nt=1 TF=1 maxTF=1 @{0 3856 0}
# domain -> term1363 Nt=6 TF=6 maxTF=1 @{0 3858 4}
# domatol -> term195 Nt=1 TF=1 maxTF=1 @{0 3869 0}
# don -> term3538 Nt=1 TF=1 maxTF=1 @{0 3870 4}
# donor -> term2623 Nt=1 TF=1 maxTF=1 @{0 3873 0}
# down -> term2334 Nt=1 TF=1 maxTF=1 @{0 3875 4}
# download -> term3105 Nt=1 TF=1 maxTF=1 @{0 3877 6}
# dp -> term3473 Nt=1 TF=1 maxTF=1 @{0 3880 2}
# dr -> term657 Nt=1 TF=1 maxTF=1 @{0 3882 6}
# drama -> term3062 Nt=1 TF=1 maxTF=1 @{0 3884 4}
# dramatisch -> term1659 Nt=1 TF=1 maxTF=1 @{0 3887 0}
# drei -> term2994 Nt=1 TF=1 maxTF=1 @{0 3889 2}
# drive -> term3353 Nt=2 TF=2 maxTF=1 @{0 3891 6}
# driven -> term3098 Nt=1 TF=1 maxTF=1 @{0 3895 0}
# drop -> term1528 Nt=1 TF=1 maxTF=1 @{0 3897 4}
# drought -> term353 Nt=1 TF=1 maxTF=1 @{0 3899 6}
# drown -> term3627 Nt=1 TF=1 maxTF=1 @{0 3901 4}
# druck -> term1784 Nt=1 TF=1 maxTF=1 @{0 3904 0}
# druckaufnehm -> term1952 Nt=1 TF=1 maxTF=1 @{0 3906 2}
# druckmess -> term1951 Nt=1 TF=1 maxTF=1 @{0 3908 4}
# dsm -> term3356 Nt=1 TF=1 maxTF=1 @{0 3910 6}
# dt -> term2702 Nt=1 TF=1 maxTF=1 @{0 3913 2}
# dte -> term2341 Nt=1 TF=1 maxTF=1 @{0 3915 6}
# dten -> term720 Nt=1 TF=1 maxTF=1 @{0 3918 0}
# dtischen -> term558 Nt=2 TF=2 maxTF=1 @{0 3920 0}
# dunklen -> term2919 Nt=1 TF=1 maxTF=1 @{0 3924 0}
# durch -> term44 Nt=15 TF=15 maxTF=1 @{0 3926 4}
# durkheim -> term1622 Nt=1 TF=1 maxTF=1 @{0 3949 2}
# dv -> term3530 Nt=2 TF=2 maxTF=1 @{0 3951 4}
# dwestlichen -> term1733 Nt=1 TF=1 maxTF=1 @{0 3956 0}
# dynam -> term1247 Nt=11 TF=11 maxTF=1 @{0 3958 2}
# dynamami -> term1765 Nt=1 TF=1 maxTF=1 @{0 3974 2}
# dynamisch -> term3742 Nt=1 TF=1 maxTF=1 @{0 3976 4}
# dynamischen -> term1840 Nt=2 TF=2 maxTF=1 @{0 3979 0}
# dyspno -> term1669 Nt=1 TF=1 maxTF=1 @{0 3983 0}
# dyxo -> term1137 Nt=1 TF=1 maxTF=1 @{0 3985 2}
# dyxoxpva -> term1135 Nt=1 TF=1 maxTF=1 @{0 3987 2}
# earli -> term3205 Nt=1 TF=1 maxTF=1 @{0 3989 2}
# eas -> term1479 Nt=1 TF=1 maxTF=1 @{0 3991 6}
# eben -> term1618 Nt=2 TF=2 maxTF=1 @{0 3994 0}
# ecommerc -> term2967 Nt=1 TF=1 maxTF=1 @{0 3997 0}
# economi -> term3631 Nt=1 TF=1 maxTF=1 @{0 3999 4}
# ecosystem -> term1188 Nt=3 TF=3 maxTF=1 @{0 4002 0}
# edda -> term579 Nt=2 TF=2 maxTF=1 @{0 4007 0}
# edelsteinbesatz -> term301 Nt=3 TF=3 maxTF=1 @{0 4010 0}
# eden -> term1289 Nt=2 TF=2 maxTF=1 @{0 4014 6}
# edikt -> term990 Nt=1 TF=1 maxTF=1 @{0 4018 2}
# edit -> term2324 Nt=1 TF=1 maxTF=1 @{0 4020 2}
# edx -> term3645 Nt=1 TF=1 maxTF=1 @{0 4022 4}
# effect -> term500 Nt=6 TF=6 maxTF=1 @{0 4025 0}
# effekt -> term411 Nt=2 TF=2 maxTF=1 @{0 4036 0}
# effici -> term982 Nt=10 TF=10 maxTF=1 @{0 4040 0}
# effizient -> term3478 Nt=1 TF=1 maxTF=1 @{0 4056 6}
# effort -> term3386 Nt=1 TF=1 maxTF=1 @{0 4059 2}
# efllex -> term3093 Nt=1 TF=1 maxTF=1 @{0 4061 6}
# ehelich -> term238 Nt=1 TF=1 maxTF=1 @{0 4064 2}
# ehemaligen -> term1167 Nt=1 TF=2 maxTF=2 @{0 4065 6}
# ...
# unsteadi -> term1261 Nt=1 TF=1 maxTF=1 @{0 13080 0}
# unstructur -> term1246 Nt=1 TF=1 maxTF=1 @{0 13082 0}
# unter -> term173 Nt=19 TF=20 maxTF=2 @{0 13084 0}
# untergerichtsordnung -> term928 Nt=1 TF=2 maxTF=2 @{0 13108 5}
# unterhaltsnormen -> term243 Nt=1 TF=1 maxTF=1 @{0 13110 6}
# unterlassen -> term2785 Nt=1 TF=2 maxTF=2 @{0 13112 2}
# unternehmenskultur -> term2291 Nt=2 TF=2 maxTF=1 @{0 13114 7}
# unterschi -> term1171 Nt=1 TF=1 maxTF=1 @{0 13118 7}
# unterst -> term1828 Nt=6 TF=6 maxTF=1 @{0 13120 7}
# untersuchung -> term574 Nt=12 TF=12 maxTF=1 @{0 13131 1}
# untersuchungen -> term172 Nt=29 TF=29 maxTF=1 @{0 13148 3}
# unterzogen -> term2876 Nt=1 TF=1 maxTF=1 @{0 13180 3}
# unus -> term3502 Nt=1 TF=1 maxTF=1 @{0 13182 7}
# unzerlegbar -> term1617 Nt=1 TF=1 maxTF=1 @{0 13185 3}
# updat -> term3635 Nt=1 TF=1 maxTF=1 @{0 13187 5}
# upper -> term3630 Nt=1 TF=1 maxTF=1 @{0 13190 1}
# ur -> term1631 Nt=5 TF=5 maxTF=1 @{0 13192 5}
# urederiv -> term2997 Nt=1 TF=1 maxTF=1 @{0 13200 7}
# uren -> term2896 Nt=1 TF=1 maxTF=1 @{0 13203 3}
# urkundensprach -> term221 Nt=1 TF=1 maxTF=1 @{0 13205 7}
# urodynamik -> term2177 Nt=1 TF=1 maxTF=1 @{0 13207 3}
# ursach -> term2020 Nt=3 TF=3 maxTF=1 @{0 13209 5}
# ursachen -> term761 Nt=2 TF=2 maxTF=1 @{0 13214 5}
# urteil -> term2788 Nt=1 TF=1 maxTF=1 @{0 13218 1}
# us -> term1245 Nt=26 TF=26 maxTF=1 @{0 13220 5}
# usa -> term330 Nt=3 TF=3 maxTF=1 @{0 13251 1}
# usabl -> term3165 Nt=8 TF=8 maxTF=1 @{0 13256 7}
# usasg -> term3753 Nt=1 TF=1 maxTF=1 @{0 13267 7}
# user -> term2330 Nt=4 TF=4 maxTF=1 @{0 13270 3}
# ut -> term3776 Nt=1 TF=1 maxTF=1 @{0 13278 3}
# uteroglobin -> term2594 Nt=1 TF=1 maxTF=1 @{0 13280 7}
# uterustumoren -> term300 Nt=1 TF=1 maxTF=1 @{0 13283 3}
# uwg -> term1875 Nt=1 TF=1 maxTF=1 @{0 13284 7}
# ux -> term2717 Nt=1 TF=2 maxTF=2 @{0 13287 1}
# valid -> term1190 Nt=5 TF=5 maxTF=1 @{0 13289 6}
# valu -> term2966 Nt=3 TF=3 maxTF=1 @{0 13298 2}
# varianc -> term3350 Nt=3 TF=3 maxTF=1 @{0 13303 2}
# variant -> term1407 Nt=1 TF=1 maxTF=1 @{0 13309 2}
# varikozelen -> term2744 Nt=1 TF=1 maxTF=1 @{0 13311 4}
# vc -> term3836 Nt=1 TF=1 maxTF=1 @{0 13314 0}
# vdw -> term571 Nt=1 TF=1 maxTF=1 @{0 13316 4}
# veb -> term2668 Nt=1 TF=1 maxTF=1 @{0 13318 2}
# vehicl -> term3398 Nt=2 TF=2 maxTF=1 @{0 13320 6}
# vektorraumb -> term1612 Nt=2 TF=2 maxTF=1 @{0 13325 0}
# ventriculi -> term255 Nt=2 TF=2 maxTF=1 @{0 13329 2}
# ventrikelmyokard -> term2620 Nt=1 TF=1 maxTF=1 @{0 13333 0}
# ventrikul -> term2905 Nt=1 TF=1 maxTF=1 @{0 13335 4}
# ver -> term13 Nt=12 TF=12 maxTF=1 @{0 13338 0}
# vera -> term2121 Nt=2 TF=2 maxTF=1 @{0 13352 2}
# verbesserung -> term524 Nt=1 TF=1 maxTF=1 @{0 13356 4}
# verbindungen -> term827 Nt=1 TF=1 maxTF=1 @{0 13358 2}
# verbot -> term3249 Nt=1 TF=1 maxTF=1 @{0 13360 2}
# verbotsstandard -> term1873 Nt=1 TF=1 maxTF=1 @{0 13362 6}
# verbrauch -> term3073 Nt=1 TF=1 maxTF=1 @{0 13365 0}
# verbreitung -> term151 Nt=1 TF=1 maxTF=1 @{0 13367 4}
# verbrennungen -> term2374 Nt=1 TF=1 maxTF=1 @{0 13369 0}
# verbrennungsabgasen -> term2209 Nt=1 TF=1 maxTF=1 @{0 13371 2}
# verbrennungsmotoren -> term1950 Nt=1 TF=1 maxTF=1 @{0 13373 4}
# verein -> term560 Nt=2 TF=2 maxTF=1 @{0 13375 6}
# vereinbarungen -> term2981 Nt=1 TF=1 maxTF=1 @{0 13379 6}
# vereinigten -> term883 Nt=1 TF=1 maxTF=1 @{0 13382 2}
# verfahren -> term2046 Nt=6 TF=6 maxTF=1 @{0 13384 2}
# verfangenschaftrecht -> term508 Nt=1 TF=1 maxTF=1 @{0 13393 0}
# verfassung -> term623 Nt=1 TF=1 maxTF=1 @{0 13394 6}
# verfassungen -> term1172 Nt=1 TF=1 maxTF=1 @{0 13396 4}
# verfassungsm -> term2616 Nt=1 TF=1 maxTF=1 @{0 13398 4}
# vergesellschaftung -> term559 Nt=1 TF=1 maxTF=1 @{0 13401 0}
# vergiftgn -> term2949 Nt=1 TF=1 maxTF=1 @{0 13402 6}
# vergiftung -> term2726 Nt=1 TF=1 maxTF=1 @{0 13405 2}
# vergl -> term2368 Nt=1 TF=1 maxTF=1 @{0 13407 6}
# vergleich -> term1030 Nt=4 TF=4 maxTF=1 @{0 13410 0}
# vergleichungen -> term1169 Nt=1 TF=1 maxTF=1 @{0 13417 2}
# verh -> term241 Nt=5 TF=5 maxTF=1 @{0 13419 2}
# verhalten -> term1841 Nt=5 TF=5 maxTF=1 @{0 13428 2}
# verif -> term1547 Nt=1 TF=1 maxTF=1 @{0 13437 4}
# verkaufen -> term1812 Nt=1 TF=1 maxTF=1 @{0 13439 6}
# verko -> term2636 Nt=1 TF=1 maxTF=1 @{0 13442 0}
# verlag -> term2312 Nt=1 TF=1 maxTF=1 @{0 13444 4}
# verlauf -> term2837 Nt=1 TF=1 maxTF=1 @{0 13446 6}
# verletzungen -> term2398 Nt=1 TF=1 maxTF=1 @{0 13449 2}
# verm -> term1128 Nt=1 TF=1 maxTF=1 @{0 13451 4}
# vermeidung -> term1603 Nt=2 TF=2 maxTF=1 @{0 13453 4}
# vermittlung -> term1074 Nt=1 TF=1 maxTF=1 @{0 13456 6}
# versatil -> term1504 Nt=1 TF=1 maxTF=1 @{0 13458 6}
# verschieden -> term2385 Nt=5 TF=5 maxTF=1 @{0 13461 0}
# verschiedenen -> term1744 Nt=1 TF=1 maxTF=1 @{0 13468 0}
# versorgung -> term1088 Nt=1 TF=1 maxTF=1 @{0 13470 2}
# verst -> term1927 Nt=1 TF=1 maxTF=1 @{0 13472 2}
# versuch -> term3284 Nt=1 TF=1 maxTF=1 @{0 13474 4}
# versucht -> term976 Nt=1 TF=1 maxTF=1 @{0 13477 0}
# vertebraten -> term2226 Nt=1 TF=1 maxTF=1 @{0 13479 0}
# verteilt -> term2599 Nt=2 TF=2 maxTF=1 @{0 13481 2}
# verteilung -> term1724 Nt=1 TF=1 maxTF=1 @{0 13486 0}
# vertragsverh -> term1924 Nt=1 TF=1 maxTF=1 @{0 13488 2}
# vertreten -> term3142 Nt=1 TF=1 maxTF=1 @{0 13490 4}
# verwaltung -> term676 Nt=2 TF=2 maxTF=1 @{0 13493 0}
# verwendung -> term186 Nt=3 TF=3 maxTF=1 @{0 13496 6}
# verwendungen -> term2171 Nt=1 TF=1 maxTF=1 @{0 13501 4}
# verzahnungsprozessen -> term2566 Nt=1 TF=1 maxTF=1 @{0 13503 6}
# vesikeln -> term2452 Nt=1 TF=1 maxTF=1 @{0 13506 2}
# vienna -> term3603 Nt=1 TF=1 maxTF=1 @{0 13508 4}
# vier -> term924 Nt=1 TF=1 maxTF=1 @{0 13511 0}
# vierzigj -> term1980 Nt=1 TF=1 maxTF=1 @{0 13513 0}
# view -> term3637 Nt=1 TF=1 maxTF=1 @{0 13515 2}
# virtual -> term3372 Nt=1 TF=1 maxTF=1 @{0 13517 6}
# virtualisierung -> term126 Nt=2 TF=2 maxTF=1 @{0 13520 2}
# viscoelast -> term3782 Nt=1 TF=1 maxTF=1 @{0 13523 2}
# vision -> term1311 Nt=3 TF=3 maxTF=1 @{0 13525 6}
# viskosit -> term1965 Nt=1 TF=1 maxTF=1 @{0 13532 2}
# visual -> term1250 Nt=3 TF=3 maxTF=1 @{0 13534 4}
# visualisierung -> term610 Nt=3 TF=3 maxTF=1 @{0 13539 4}
# visualiz -> term3696 Nt=1 TF=1 maxTF=1 @{0 13545 4}
# viswanathan -> term1395 Nt=1 TF=1 maxTF=1 @{0 13548 0}
# vitamin -> term2182 Nt=1 TF=1 maxTF=1 @{0 13550 0}
# vitro -> term408 Nt=4 TF=4 maxTF=1 @{0 13552 2}
# vivo -> term1846 Nt=5 TF=5 maxTF=1 @{0 13559 6}
# vizekanzl -> term1072 Nt=1 TF=1 maxTF=1 @{0 13568 2}
# vocal -> term2929 Nt=1 TF=1 maxTF=1 @{0 13570 2}
# vogelsang -> term157 Nt=1 TF=1 maxTF=1 @{0 13572 6}
# volkszeitung -> term2538 Nt=1 TF=1 maxTF=1 @{0 13574 2}
# voltag -> term3079 Nt=4 TF=4 maxTF=1 @{0 13576 6}
# volum -> term1337 Nt=1 TF=1 maxTF=1 @{0 13583 6}
# volumenhologrammen -> term1745 Nt=1 TF=1 maxTF=1 @{0 13585 6}
# vom -> term949 Nt=5 TF=6 maxTF=2 @{0 13588 0}
# von -> term45 Nt=153 TF=176 maxTF=4 @{0 13593 7}
# vor -> term2750 Nt=1 TF=1 maxTF=1 @{0 13694 2}
# vorausabtretung -> term2761 Nt=1 TF=1 maxTF=1 @{0 13696 6}
# vorbestrahlung -> term298 Nt=1 TF=1 maxTF=1 @{0 13699 2}
# vorg -> term474 Nt=1 TF=1 maxTF=1 @{0 13700 6}
# vorgehen -> term3810 Nt=1 TF=1 maxTF=1 @{0 13702 4}
# vorgenommen -> term1791 Nt=1 TF=1 maxTF=1 @{0 13705 0}
# vorkommen -> term1954 Nt=3 TF=3 maxTF=1 @{0 13707 2}
# vorl -> term1842 Nt=1 TF=1 maxTF=1 @{0 13713 0}
# vorlagen -> term838 Nt=1 TF=1 maxTF=1 @{0 13715 2}
# vorn -> term57 Nt=1 TF=1 maxTF=1 @{0 13717 2}
# vornehmlich -> term446 Nt=2 TF=2 maxTF=1 @{0 13718 2}
# vorschl -> term2157 Nt=1 TF=1 maxTF=1 @{0 13721 6}
# vorstellungen -> term2499 Nt=1 TF=1 maxTF=1 @{0 13724 0}
# vorz -> term1177 Nt=1 TF=1 maxTF=1 @{0 13726 4}
# vossem -> term1081 Nt=1 TF=1 maxTF=1 @{0 13728 4}
# vsc -> term3588 Nt=2 TF=2 maxTF=1 @{0 13730 4}
# vtln -> term3608 Nt=1 TF=1 maxTF=1 @{0 13734 4}
# vulner -> term3519 Nt=2 TF=2 maxTF=1 @{0 13737 0}
# wachstumsbremsung -> term2479 Nt=1 TF=1 maxTF=1 @{0 13741 0}
# wachstumsst -> term2105 Nt=1 TF=1 maxTF=1 @{0 13743 4}
# wahrnehmung -> term1905 Nt=1 TF=1 maxTF=1 @{0 13745 6}
# walram -> term387 Nt=1 TF=1 maxTF=1 @{0 13748 0}
# wandel -> term551 Nt=2 TF=2 maxTF=1 @{0 13749 6}
# wandlungen -> term166 Nt=1 TF=1 maxTF=1 @{0 13754 0}
# warehous -> term3486 Nt=2 TF=2 maxTF=1 @{0 13755 4}
# warp -> term3607 Nt=1 TF=1 maxTF=1 @{0 13758 6}
# warum -> term3711 Nt=1 TF=1 maxTF=1 @{0 13761 2}
# wasser -> term1646 Nt=3 TF=3 maxTF=1 @{0 13763 6}
# wasserbau -> term724 Nt=1 TF=1 maxTF=1 @{0 13770 0}
# wasserm -> term721 Nt=1 TF=1 maxTF=1 @{0 13772 0}
# wea -> term3257 Nt=1 TF=1 maxTF=1 @{0 13774 0}
# weak -> term2507 Nt=1 TF=1 maxTF=1 @{0 13776 4}
# weakli -> term2711 Nt=1 TF=1 maxTF=1 @{0 13779 0}
# web -> term1228 Nt=7 TF=7 maxTF=1 @{0 13781 4}
# webservic -> term1454 Nt=1 TF=1 maxTF=1 @{0 13793 4}
# wechselbr -> term3024 Nt=2 TF=2 maxTF=1 @{0 13795 6}
# wechselwirkung -> term1752 Nt=2 TF=2 maxTF=1 @{0 13799 6}
# weg -> term1654 Nt=1 TF=1 maxTF=1 @{0 13804 0}
# wege -> term545 Nt=1 TF=1 maxTF=1 @{0 13806 2}
# weiblich -> term2180 Nt=1 TF=1 maxTF=1 @{0 13808 0}
# weight -> term3597 Nt=1 TF=1 maxTF=1 @{0 13810 2}
# wein -> term1009 Nt=1 TF=1 maxTF=1 @{0 13812 6}
# weinberg -> term2011 Nt=2 TF=2 maxTF=1 @{0 13814 6}
# weiterbildung -> term2252 Nt=1 TF=1 maxTF=1 @{0 13818 6}
# well -> term2064 Nt=2 TF=2 maxTF=1 @{0 13821 0}
# wellenl -> term1746 Nt=1 TF=1 maxTF=1 @{0 13825 2}
# welt -> term1686 Nt=2 TF=2 maxTF=1 @{0 13827 4}
# wem -> term2803 Nt=1 TF=1 maxTF=1 @{0 13832 2}
# werden -> term143 Nt=2 TF=2 maxTF=1 @{0 13834 6}
# werk -> term1650 Nt=1 TF=1 maxTF=1 @{0 13838 4}
# werkstoffkennwert -> term2601 Nt=1 TF=1 maxTF=1 @{0 13840 6}
# werkzeug -> term3790 Nt=1 TF=1 maxTF=1 @{0 13843 2}
# werkzeugsatz -> term2606 Nt=2 TF=2 maxTF=1 @{0 13845 6}
# wertsch -> term2008 Nt=1 TF=1 maxTF=1 @{0 13849 6}
# werzeug -> term3820 Nt=1 TF=1 maxTF=1 @{0 13852 0}
# werzeugvermittelt -> term3792 Nt=1 TF=1 maxTF=1 @{0 13854 4}
# westf -> term953 Nt=2 TF=2 maxTF=1 @{0 13857 0}
# westfalen -> term2614 Nt=1 TF=1 maxTF=1 @{0 13859 2}
# wettbew -> term414 Nt=1 TF=1 maxTF=1 @{0 13861 6}
# weyer -> term971 Nt=1 TF=1 maxTF=1 @{0 13863 4}
# wi3bon -> term824 Nt=1 TF=1 maxTF=1 @{0 13865 4}
# wide -> term3159 Nt=1 TF=1 maxTF=1 @{0 13867 4}
# wideband -> term2978 Nt=2 TF=2 maxTF=1 @{0 13870 0}
# wie -> term140 Nt=5 TF=5 maxTF=1 @{0 13873 6}
# wiedereintritt -> term1729 Nt=1 TF=1 maxTF=1 @{0 13879 6}
# wiedervereinigung -> term2615 Nt=1 TF=1 maxTF=1 @{0 13882 0}
# wilhelm -> term434 Nt=10 TF=12 maxTF=2 @{0 13884 4}
# willk -> term2792 Nt=1 TF=1 maxTF=1 @{0 13893 6}
# wimpfen -> term1749 Nt=1 TF=1 maxTF=1 @{0 13896 2}
# windkraftanlagen -> term132 Nt=1 TF=1 maxTF=1 @{0 13898 4}
# window -> term1543 Nt=1 TF=1 maxTF=1 @{0 13899 6}
# wir -> term403 Nt=1 TF=1 maxTF=1 @{0 13902 0}
# wird -> term3710 Nt=1 TF=1 maxTF=1 @{0 13903 6}
# wireless -> term3772 Nt=1 TF=1 maxTF=1 @{0 13906 2}
# wirken -> term972 Nt=1 TF=1 maxTF=1 @{0 13908 6}
# wirkg -> term2771 Nt=1 TF=1 maxTF=1 @{0 13910 6}
# wirklichkeit -> term2290 Nt=2 TF=2 maxTF=1 @{0 13913 2}
# wirkmechanismu -> term1742 Nt=1 TF=1 maxTF=1 @{0 13917 2}
# wirksamkeit -> term890 Nt=2 TF=2 maxTF=1 @{0 13919 4}
# wirkstoff -> term286 Nt=1 TF=1 maxTF=1 @{0 13923 6}
# wirkung -> term2138 Nt=4 TF=4 maxTF=1 @{0 13925 2}
# wirkungen -> term2627 Nt=1 TF=1 maxTF=1 @{0 13931 2}
# wirtschaftlich -> term758 Nt=1 TF=1 maxTF=1 @{0 13933 6}
# wirtschaftskr -> term1012 Nt=1 TF=1 maxTF=1 @{0 13935 6}
# wirtschaftsplatz -> term1751 Nt=1 TF=1 maxTF=1 @{0 13937 6}
# wirtschaftspolitik -> term421 Nt=2 TF=2 maxTF=1 @{0 13940 0}
# wirtschaftswerbung -> term1990 Nt=1 TF=1 maxTF=1 @{0 13943 6}
# wiss -> term1133 Nt=1 TF=1 maxTF=1 @{0 13946 0}
# wissen -> term144 Nt=1 TF=1 maxTF=1 @{0 13948 0}
# wissenschaft -> term1991 Nt=3 TF=3 maxTF=1 @{0 13949 2}
# wissenschaftl -> term105 Nt=1 TF=1 maxTF=1 @{0 13954 2}
# wissenschaftlich -> term7 Nt=10 TF=10 maxTF=1 @{0 13955 4}
# wissenschaftlichen -> term526 Nt=3 TF=3 maxTF=1 @{0 13966 0}
# wissenschaftsmanag -> term103 Nt=1 TF=1 maxTF=1 @{0 13971 4}
# wissenschaftstheori -> term2237 Nt=1 TF=1 maxTF=1 @{0 13972 6}
# wissensmodel -> term1825 Nt=2 TF=2 maxTF=1 @{0 13975 0}
# wisskom -> term66 Nt=3 TF=3 maxTF=1 @{0 13978 6}
# wolfgang -> term678 Nt=4 TF=4 maxTF=1 @{0 13980 2}
# wollen -> term3171 Nt=1 TF=1 maxTF=1 @{0 13985 4}
# word -> term1293 Nt=2 TF=2 maxTF=1 @{0 13988 0}
# work -> term2002 Nt=4 TF=4 maxTF=1 @{0 13992 4}
# worker -> term1387 Nt=1 TF=1 maxTF=1 @{0 14000 6}
# workshop -> term498 Nt=1 TF=1 maxTF=1 @{0 14002 6}
# workstat -> term1238 Nt=1 TF=1 maxTF=1 @{0 14004 4}
# worm -> term3514 Nt=2 TF=2 maxTF=1 @{0 14006 4}
# wort -> term3826 Nt=1 TF=1 maxTF=1 @{0 14009 6}
# wortweis -> term3825 Nt=1 TF=1 maxTF=1 @{0 14012 2}
# wozu -> term2657 Nt=1 TF=1 maxTF=1 @{0 14014 6}
# wrapper -> term3688 Nt=1 TF=1 maxTF=1 @{0 14017 2}
# wsi -> term2962 Nt=1 TF=1 maxTF=1 @{0 14019 6}
# wurden -> term2877 Nt=1 TF=1 maxTF=1 @{0 14022 2}
# wurzelgallen -> term2572 Nt=1 TF=1 maxTF=1 @{0 14024 6}
# x86 -> term3550 Nt=1 TF=1 maxTF=1 @{0 14027 2}
# xiv -> term1077 Nt=1 TF=1 maxTF=1 @{0 14029 6}
# xy -> term2065 Nt=1 TF=1 maxTF=1 @{0 14031 6}
# yac -> term2461 Nt=1 TF=1 maxTF=1 @{0 14034 0}
# yee -> term1397 Nt=1 TF=1 maxTF=1 @{0 14036 2}
# yield -> term804 Nt=1 TF=1 maxTF=1 @{0 14038 2}
# zahn -> term1091 Nt=2 TF=2 maxTF=1 @{0 14040 2}
# zahnbehandlung -> term1679 Nt=1 TF=1 maxTF=1 @{0 14044 2}
# zahnkrankheiten -> term1677 Nt=1 TF=1 maxTF=1 @{0 14046 4}
# zebrafish -> term211 Nt=1 TF=1 maxTF=1 @{0 14048 6}
# zeichnungen -> term3317 Nt=1 TF=1 maxTF=1 @{0 14050 2}
# zeiss -> term2665 Nt=1 TF=1 maxTF=1 @{0 14052 6}
# zeit -> term643 Nt=5 TF=5 maxTF=1 @{0 14055 2}
# zeitalt -> term833 Nt=1 TF=1 maxTF=1 @{0 14062 4}
# zeitg -> term1093 Nt=1 TF=1 maxTF=1 @{0 14064 4}
# zeitgeschichtl -> term712 Nt=1 TF=1 maxTF=1 @{0 14066 4}
# zeitraum -> term3000 Nt=1 TF=1 maxTF=1 @{0 14068 4}
# zeitwahrnehmung -> term3078 Nt=1 TF=1 maxTF=1 @{0 14071 0}
# zelladh -> term2478 Nt=1 TF=1 maxTF=1 @{0 14073 4}
# zellen -> term1957 Nt=1 TF=1 maxTF=1 @{0 14076 0}
# zellentwicklung -> term2597 Nt=1 TF=1 maxTF=1 @{0 14078 2}
# zellinfiltr -> term2013 Nt=2 TF=2 maxTF=1 @{0 14080 6}
# zellkulturen -> term3032 Nt=1 TF=1 maxTF=1 @{0 14084 6}
# zellmodellen -> term2757 Nt=1 TF=1 maxTF=1 @{0 14087 2}
# zentralbibliothek -> term75 Nt=3 TF=3 maxTF=1 @{0 14089 6}
# zentralinst -> term1136 Nt=1 TF=1 maxTF=1 @{0 14091 2}
# zentrifug -> term1985 Nt=1 TF=1 maxTF=1 @{0 14093 2}
# zentrumspress -> term2536 Nt=1 TF=1 maxTF=1 @{0 14095 4}
# zerfal -> term908 Nt=1 TF=1 maxTF=1 @{0 14098 0}
# zero -> term3421 Nt=1 TF=1 maxTF=1 @{0 14100 0}
# zertifizierung -> term3778 Nt=1 TF=1 maxTF=1 @{0 14102 4}
# zfk -> term781 Nt=1 TF=1 maxTF=1 @{0 14105 0}
# zielgruppenad -> term2282 Nt=1 TF=1 maxTF=1 @{0 14107 0}
# zink -> term1023 Nt=1 TF=1 maxTF=1 @{0 14109 2}
# zitierf -> term1805 Nt=1 TF=1 maxTF=1 @{0 14111 2}
# zivilgesellschaft -> term2679 Nt=1 TF=1 maxTF=1 @{0 14113 4}
# zivilprozess -> term653 Nt=1 TF=1 maxTF=1 @{0 14116 0}
# zu -> term242 Nt=15 TF=15 maxTF=1 @{0 14117 6}
# zuchttieren -> term1790 Nt=1 TF=1 maxTF=1 @{0 14137 6}
# zuckerr -> term625 Nt=3 TF=3 maxTF=1 @{0 14140 0}
# zuckerru -> term2029 Nt=1 TF=1 maxTF=1 @{0 14145 2}
# zufuhr -> term2846 Nt=2 TF=2 maxTF=1 @{0 14147 4}
# zugang -> term3030 Nt=1 TF=1 maxTF=1 @{0 14150 6}
# zugangsweg -> term1497 Nt=1 TF=1 maxTF=1 @{0 14153 2}
# zugeh -> term756 Nt=1 TF=1 maxTF=1 @{0 14155 4}
# zugversuchen -> term2438 Nt=1 TF=1 maxTF=1 @{0 14157 4}
# zukunft -> term1 Nt=5 TF=5 maxTF=1 @{0 14159 6}
# zum -> term17 Nt=33 TF=34 maxTF=2 @{0 14163 6}
# zur -> term30 Nt=79 TF=81 maxTF=2 @{0 14195 7}
# zusammenarb -> term1039 Nt=2 TF=2 maxTF=1 @{0 14257 5}
# zusammenarbeit -> term766 Nt=2 TF=2 maxTF=1 @{0 14260 5}
# zusammenh -> term1026 Nt=1 TF=1 maxTF=1 @{0 14263 5}
# zusammenhang -> term2117 Nt=6 TF=6 maxTF=1 @{0 14265 5}
# zusammenrechnung -> term2236 Nt=1 TF=1 maxTF=1 @{0 14275 1}
# zusammensetzung -> term2067 Nt=1 TF=1 maxTF=1 @{0 14277 3}
# zustand -> term1606 Nt=4 TF=4 maxTF=1 @{0 14279 5}
# zustandekommen -> term250 Nt=2 TF=2 maxTF=1 @{0 14286 7}
# zustandsform -> term2570 Nt=2 TF=2 maxTF=1 @{0 14290 5}
# zwangssterilis -> term3251 Nt=1 TF=1 maxTF=1 @{0 14294 5}
# zwangsversteigerung -> term2805 Nt=1 TF=1 maxTF=1 @{0 14297 1}
# zwei -> term1613 Nt=3 TF=3 maxTF=1 @{0 14299 5}
# zweigniederlassung -> term2873 Nt=1 TF=1 maxTF=1 @{0 14305 7}
# zweit -> term886 Nt=1 TF=1 maxTF=1 @{0 14308 3}
# zweiten -> term1857 Nt=1 TF=1 maxTF=1 @{0 14310 3}
# zwischen -> term453 Nt=10 TF=10 maxTF=1 @{0 14312 5}
# zyklu -> term261 Nt=1 TF=1 maxTF=1 @{0 14326 7}
# zytodiagnostik -> term1953 Nt=1 TF=1 maxTF=1 @{0 14328 3}
# zytologischen -> term2811 Nt=1 TF=1 maxTF=1 @{0 14330 5}

# %%
term = "apparatur"
index.getLexicon()[term].toString()
# Out:
# 'term1138 Nt=1 TF=1 maxTF=1 @{0 993 2}'

# %%
term_freq_dict = {}

for kv in index.getLexicon():
    term_freq_dict[kv.getKey()] = kv.getValue().frequency

# %%
term_freq_dict_sorted = sorted(term_freq_dict.items(), key=lambda x: x[1], reverse=True)

# %%
top_k = 30
term_freq_dict_sorted[:top_k]
# Out:
# [('und', 300),
#  ('der', 287),
#  ('von', 176),
#  ('die', 135),
#  ('de', 119),
#  ('lich', 99),
#  ('ein', 82),
#  ('zur', 81),
#  ('im', 73),
#  ('parallel', 63),
#  ('bei', 60),
#  ('mit', 55),
#  ('ber', 48),
#  ('base', 39),
#  ('system', 37),
#  ('auf', 36),
#  ('den', 36),
#  ('zum', 34),
#  ('comput', 33),
#  ('analysi', 30),
#  ('da', 30),
#  ('applic', 29),
#  ('untersuchungen', 29),
#  ('model', 28),
#  ('robot', 28),
#  ('au', 27),
#  ('berg', 27),
#  ('us', 26),
#  ('simul', 25),
#  ('algorithm', 24)]

# %%
search_engine = pt.BatchRetrieve(index, wmodel="Tf")

# %%
search_engine.search("system")
# Out:
#    qid  docid                                              docno  rank  score  \
# 0    1    148  https://www.bibsonomy.org/bibtex/2b66b881320fe...     0    1.0
# 1    1    187  https://www.bibsonomy.org/bibtex/2a6e5824738eb...     1    1.0
# 2    1    214  https://www.bibsonomy.org/bibtex/273b25bf91b8a...     2    1.0
# 3    1    215  https://www.bibsonomy.org/bibtex/274fe3ad80ab5...     3    1.0
# 4    1    227  https://www.bibsonomy.org/bibtex/20b6cbcf70a61...     4    1.0
# 5    1    249  https://www.bibsonomy.org/bibtex/2d78b8aa0425f...     5    1.0
# 6    1    264  https://www.bibsonomy.org/bibtex/2ee077f2f7135...     6    1.0
# 7    1    273  https://www.bibsonomy.org/bibtex/25ad03ed16e1d...     7    1.0
# 8    1    286  https://www.bibsonomy.org/bibtex/2d91484c0b949...     8    1.0
# 9    1    287  https://www.bibsonomy.org/bibtex/2bb17499a6032...     9    1.0
# 10   1    288  https://www.bibsonomy.org/bibtex/2c601899556d5...    10    1.0
# 11   1    324  https://www.bibsonomy.org/bibtex/2efdfef0850ef...    11    1.0
# 12   1    330  https://www.bibsonomy.org/bibtex/28cff113a2e1b...    12    1.0
# 13   1    336  https://www.bibsonomy.org/bibtex/233138c724f62...    13    1.0
# 14   1    392  https://www.bibsonomy.org/bibtex/2782f2cffc03f...    14    1.0
# 15   1    397  https://www.bibsonomy.org/bibtex/24fb13814f3a1...    15    1.0
# 16   1    439  https://www.bibsonomy.org/bibtex/297fcd73004c6...    16    1.0
# 17   1    491  https://www.bibsonomy.org/bibtex/262886c7fbed6...    17    1.0
# 18   1    702  https://www.bibsonomy.org/bibtex/2a7769172502f...    18    1.0
# 19   1    706  https://www.bibsonomy.org/bibtex/21ae4969d4a46...    19    1.0
# 20   1    714  https://www.bibsonomy.org/bibtex/2a505f5831cab...    20    1.0
# 21   1    723  https://www.bibsonomy.org/bibtex/26d7f94075b18...    21    1.0
# 22   1    749  https://www.bibsonomy.org/bibtex/2b68eb35e6361...    22    1.0
# 23   1    757  https://www.bibsonomy.org/bibtex/223c72ec15d08...    23    1.0
# 24   1    763  https://www.bibsonomy.org/bibtex/2f7de040bab63...    24    1.0
# 25   1    770  https://www.bibsonomy.org/bibtex/2230fd09f4b35...    25    1.0
# 26   1    771  https://www.bibsonomy.org/bibtex/256653f0998fb...    26    1.0
# 27   1    778  https://www.bibsonomy.org/bibtex/2eb04c8435803...    27    1.0
# 28   1    780  https://www.bibsonomy.org/bibtex/20ae7bf4980d9...    28    1.0
# 29   1    783  https://www.bibsonomy.org/bibtex/209ca7dbe37ce...    29    1.0
# 30   1    824  https://www.bibsonomy.org/bibtex/2e13ea2aac110...    30    1.0
# 31   1    868  https://www.bibsonomy.org/bibtex/2d3e7f7140925...    31    1.0
# 32   1    913  https://www.bibsonomy.org/bibtex/2832d05c324ac...    32    1.0
# 33   1    922  https://www.bibsonomy.org/bibtex/2adbb1f6955ab...    33    1.0
# 34   1    931  https://www.bibsonomy.org/bibtex/2376a792fe7e3...    34    1.0
# 35   1    949  https://www.bibsonomy.org/bibtex/2b122f09f5664...    35    1.0
# 36   1    999  https://www.bibsonomy.org/bibtex/2e3e50cbbe638...    36    1.0
#
#      query
# 0   system
# 1   system
# 2   system
# 3   system
# 4   system
# 5   system
# 6   system
# 7   system
# 8   system
# 9   system
# 10  system
# 11  system
# 12  system
# 13  system
# 14  system
# 15  system
# 16  system
# 17  system
# 18  system
# 19  system
# 20  system
# 21  system
# 22  system
# 23  system
# 24  system
# 25  system
# 26  system
# 27  system
# 28  system
# 29  system
# 30  system
# 31  system
# 32  system
# 33  system
# 34  system
# 35  system
# 36  system

# %%
search_engine.search("intelligent education")
# Out:
#   qid  docid                                              docno  rank  score  \
# 0   1    745  https://www.bibsonomy.org/bibtex/205de7939eb62...     0    1.0
# 1   1    889  https://www.bibsonomy.org/bibtex/225cc15aa8abc...     1    1.0
#
#                    query
# 0  intelligent education
# 1  intelligent education

# %%
dataset = search_engine.search("intelligent education")

# %%
dataset
# Out:
#   qid  docid                                              docno  rank  score  \
# 0   1    745  https://www.bibsonomy.org/bibtex/205de7939eb62...     0    1.0
# 1   1    889  https://www.bibsonomy.org/bibtex/225cc15aa8abc...     1    1.0
#
#                    query
# 0  intelligent education
# 1  intelligent education

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
stem = stemmer.stem("learning")
stem
# Out:
# 'learn'

# %%
lexicon = index.getLexicon()
lexicon[stem].getDocumentFrequency()
# Out:
# 9

# %%
index.getCollectionStatistics().numberOfDocuments
# Out:
# 1000

# %%
def get_idf_for_term(term, index):
    lex = index.getLexicon()
    stemmed_term = stemmer.stem(term)

    if not stemmed_term in lex:
        return

    lex_entry = lex[stemmed_term]
    
    df_term = lex_entry.getDocumentFrequency()
    N = index.getCollectionStatistics().numberOfDocuments
    
    idf = N/df_term
    
    log_idf = np.emath.logn(10, idf)
    
    return log_idf

# %%
get_idf_for_term("learning", index)
# Out:
# 2.045757490560675

# %%
#define your own tf_idf_method here:
def calc_tf_idf(query, docno,index):
    #remember that tfidf is the product of two components
    #hint: the tf model seach result contains tf frequencies
    return 0

# %%
query = "intelligent education"
docno = "https://www.bibsonomy.org/bibtex/201f2eb94f27fe662c37249be37619d8b/dblp"

print(f"The tf-idf for query: {query} and document: {docno} is {calc_tf_idf(query, docno, index)}")
# Out:
# The tf-idf for query: intelligent education and document: https://www.bibsonomy.org/bibtex/201f2eb94f27fe662c37249be37619d8b/dblp is 0

# %%
search_engine_tfidf = pt.BatchRetrieve(index, vmodel="TF_IDF")

# %%
search_engine_tfidf.search("intelligent education")
# Out:
# BR(DPH): 100%|█████████████████████████████████████| 1/1 [00:00<00:00,  6.47q/s]
#   qid  docid                                              docno  rank  \
# 0   1    745  https://www.bibsonomy.org/bibtex/205de7939eb62...     0
# 1   1    889  https://www.bibsonomy.org/bibtex/225cc15aa8abc...     1
#
#       score                  query
# 0  4.135132  intelligent education
# 1  4.087299  intelligent education

# %%
df_ai_filtered.columns
# Out:
# Index(['id', 'tags', 'label', 'description', 'date', 'changeDate', 'url',
#        'pub-type', 'year', 'author', 'authors', 'docno', 'text'],
#       dtype='object')

# %%
ai_dict = df_ai_filtered.to_dict(orient='records')

# %%
ai_dict
# Out:
# [{'id': 'https://www.bibsonomy.org/bibtex/2bdae1e1df978095e1597b14122974d9c/acka47',
#   'tags': ['scholarly_communication'],
#   'label': 'Wissenschaftskommunikation der Zukunft',
#   'description': '4. Konferenz der Zentralbibliothek Forschungszentrum Jülich. 6. - 8. November 2007 ; Beiträge und Poster',
#   'date': '2009-06-08 11:42:22',
#   'changeDate': '2009-06-08 11:42:22',
#   'url': 'http://juwel.fz-juelich.de:8080/dspace/bitstream/2128/2893/1/Ball_2007.Wisskom.pdf',
#   'pub-type': 'book',
#   'year': '2007',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2bdae1e1df978095e1597b14122974d9c/acka47',
#   'text': 'Wissenschaftskommunikation der Zukunft'},
#  {'id': 'https://www.bibsonomy.org/bibtex/229373b9b1243c4dec5e9fa4d7105bc20/wdees',
#   'tags': ['forschungsdaten', 'proceedings'],
#   'label': 'Forschungsdaten - Sammeln, sichern, strukturieren; Proceedingsband',
#   'description': 'Forschungsdaten - Sammeln, sichern, strukturieren - JuSER',
#   'date': '2019-08-06 14:45:34',
#   'changeDate': '2019-08-06 14:45:34',
#   'url': 'http://juser.fz-juelich.de/record/863008',
#   'pub-type': 'book',
#   'year': '2019',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/229373b9b1243c4dec5e9fa4d7105bc20/wdees',
#   'text': 'Forschungsdaten - Sammeln, sichern, strukturieren; Proceedingsband'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e08a1c00674b99dfd038acd7d858a08a/urhe',
#   'tags': ['bibliometrics', 'scientometrics'],
#   'label': 'Qualität und Quantität wissenschaftlicher Veröffentlichungen: Bibliometrische Aspekte der Wissenschaftskommunikation',
#   'description': '',
#   'date': '2015-02-20 13:30:54',
#   'changeDate': '2015-02-20 13:30:54',
#   'url': '',
#   'pub-type': 'book',
#   'year': '2006',
#   'author': ['Maja Jokic', 'Rafael Ball'],
#   'authors': [{'first': 'Maja', 'last': 'Jokic'},
#    {'first': 'Rafael', 'last': 'Ball'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2e08a1c00674b99dfd038acd7d858a08a/urhe',
#   'text': 'Qualität und Quantität wissenschaftlicher Veröffentlichungen: Bibliometrische Aspekte der Wissenschaftskommunikation'},
#  {'id': 'https://www.bibsonomy.org/bibtex/29d59b136207d578324fd81a54bda0370/novaesium',
#   'tags': ['Niedergermanien', 'Ubier', 'Jülich'],
#   'label': 'Jülich:  Stadt - Territorium - Geschichte:  Festschrift zum 75jährigen Jubiläum des Jülicher Geschichtsvereins 1923 e.V.',
#   'description': '',
#   'date': '2008-11-26 16:30:25',
#   'changeDate': '2008-11-26 16:30:30',
#   'url': '\\url{http://katalog.ub.uni-heidelberg.de/cgi-bin/titel.cgi?katkey=65295853}',
#   'pub-type': 'book',
#   'year': '2000',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/29d59b136207d578324fd81a54bda0370/novaesium',
#   'text': 'Jülich:  Stadt - Territorium - Geschichte:  Festschrift zum 75jährigen Jubiläum des Jülicher Geschichtsvereins 1923 e.V.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e08a1c00674b99dfd038acd7d858a08a/bibliometrie',
#   'tags': ['bibliometrie'],
#   'label': 'Qualität und Quantität wissenschaftlicher Veröffentlichungen: Bibliometrische Aspekte der Wissenschaftskommunikation',
#   'description': '',
#   'date': '2010-11-24 15:02:02',
#   'changeDate': '2010-11-24 15:02:02',
#   'url': 'http://epub.uni-regensburg.de/4914/',
#   'pub-type': 'book',
#   'year': '2006',
#   'author': ['Maja Jokic', 'Rafael Ball'],
#   'authors': [{'first': 'Maja', 'last': 'Jokic'},
#    {'first': 'Rafael', 'last': 'Ball'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2e08a1c00674b99dfd038acd7d858a08a/bibliometrie',
#   'text': 'Qualität und Quantität wissenschaftlicher Veröffentlichungen: Bibliometrische Aspekte der Wissenschaftskommunikation'},
#  {'id': 'https://www.bibsonomy.org/bibtex/29e3592cb6e1497d8021e67cdb50d8d8f/acka47',
#   'tags': ['linkeddata', 'myown', 'phresnel', 'lobid'],
#   'label': 'Zur Entwicklung eines Linked-Open-Data-Dienstes für Bibliotheksdaten',
#   'description': '',
#   'date': '2013-01-07 11:58:11',
#   'changeDate': '2013-01-07 11:58:11',
#   'url': 'http://hdl.handle.net/2128/4699',
#   'pub-type': 'inproceedings',
#   'year': '2012',
#   'author': ['Felix Ostrowski', 'Adrian Pohl'],
#   'authors': [{'first': 'Felix', 'last': 'Ostrowski'},
#    {'first': 'Adrian', 'last': 'Pohl'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/29e3592cb6e1497d8021e67cdb50d8d8f/acka47',
#   'text': 'Zur Entwicklung eines Linked-Open-Data-Dienstes für Bibliotheksdaten'},
#  {'id': 'https://www.bibsonomy.org/bibtex/28d8ba6c971543729dbdac4223c2e9689/fbw_hannover',
#   'tags': ['imported'],
#   'label': 'Entlastung der Rohstoff- und Primärenergiebilanz der Bundesrepublik Deutschland durch Recycling von Hausmüll',
#   'description': '',
#   'date': '2009-08-21 09:46:50',
#   'changeDate': '2009-08-21 09:46:53',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+010967400&sourceid=fbw_bibsonomy',
#   'pub-type': 'phdthesis',
#   'year': '1977',
#   'author': ['Roland Turowski'],
#   'authors': [{'first': 'Roland', 'last': 'Turowski'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/28d8ba6c971543729dbdac4223c2e9689/fbw_hannover',
#   'text': 'Entlastung der Rohstoff- und Primärenergiebilanz der Bundesrepublik Deutschland durch Recycling von Hausmüll'},
#  {'id': 'https://www.bibsonomy.org/bibtex/242c29a065ee5d48220fa97bd65b53a4b/voss',
#   'tags': ['bibliothekswesen', 'openaccess', 'bibliothekswissenschaft'],
#   'label': 'Der Schritt zurück als Schritt nach vorn – Macht der Siegeszug des Open Access Bibliotheken arbeitslos?',
#   'description': 'ISBN 978-3-95806-146-0',
#   'date': '2016-06-14 13:46:42',
#   'changeDate': '2016-06-14 13:46:42',
#   'url': 'http://hdl.handle.net/2128/11435',
#   'pub-type': 'proceedings',
#   'year': '2016',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/242c29a065ee5d48220fa97bd65b53a4b/voss',
#   'text': 'Der Schritt zurück als Schritt nach vorn – Macht der Siegeszug des Open Access Bibliotheken arbeitslos?'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2879c972e22403a15e9b77f58b6a2e36f/kaigrass',
#   'tags': ['imported'],
#   'label': 'Anwendung von FFT Ewald Gitter-Methoden in Simulationen von Polyelektrolyten',
#   'description': '',
#   'date': '2007-06-15 17:33:15',
#   'changeDate': '2007-06-15 17:33:19',
#   'url': '',
#   'pub-type': 'inbook',
#   'year': '1998',
#   'author': ['C. Holm'],
#   'authors': [{'first': 'C.', 'last': 'Holm'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2879c972e22403a15e9b77f58b6a2e36f/kaigrass',
#   'text': 'Anwendung von FFT Ewald Gitter-Methoden in Simulationen von Polyelektrolyten'},
#  {'id': 'https://www.bibsonomy.org/bibtex/27f26b46919b08a1bf4409a33f76217a1/mm051052',
#   'tags': ['Datenmanagement',
#    'pöppel',
#    'lv_wisskomm',
#    'practice',
#    'konferenz',
#    'eScience',
#    'theory'],
#   'label': 'WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster',
#   'description': 'Amazon.de: WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster: Rafael Ball: Bücher',
#   'date': '2008-03-06 18:55:46',
#   'changeDate': '2011-11-11 09:07:43',
#   'url': 'http://www.amazon.de/gp/redirect.html%3FASIN=3893364595%26tag=ws%26lcode=xm2%26cID=2025%26ccmID=165953%26location=/o/ASIN/3893364595%253FSubscriptionId=13CT5CVB80YFWJEPWS02',
#   'pub-type': 'book',
#   'year': '2007',
#   'author': [' ?'],
#   'authors': [{'first': '', 'last': '?'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/27f26b46919b08a1bf4409a33f76217a1/mm051052',
#   'text': 'WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster'},
#  {'id': 'https://www.bibsonomy.org/bibtex/27f26b46919b08a1bf4409a33f76217a1/niederdorfer',
#   'tags': ['2007',
#    'lv_wisskomm',
#    'Zukunft',
#    'wisskomm',
#    'wissenschaftskommunikation',
#    'theory'],
#   'label': 'WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster',
#   'description': 'Amazon.de: WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster: Rafael Ball: Bücher',
#   'date': '2008-03-09 14:14:22',
#   'changeDate': '2011-11-11 09:07:43',
#   'url': 'http://www.amazon.de/gp/redirect.html%3FASIN=3893364595%26tag=ws%26lcode=xm2%26cID=2025%26ccmID=165953%26location=/o/ASIN/3893364595%253FSubscriptionId=13CT5CVB80YFWJEPWS02',
#   'pub-type': 'book',
#   'year': '2007',
#   'author': [' ?'],
#   'authors': [{'first': '', 'last': '?'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/27f26b46919b08a1bf4409a33f76217a1/niederdorfer',
#   'text': 'WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster'},
#  {'id': 'https://www.bibsonomy.org/bibtex/27f26b46919b08a1bf4409a33f76217a1/sabesa',
#   'tags': ['lv_wisskomm',
#    'wissenschaftskommunikation_zukunft',
#    'wissenschaftskommunikation_forschung',
#    'theory'],
#   'label': 'WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster',
#   'description': 'Amazon.de: WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster: Rafael Ball: Bücher',
#   'date': '2008-03-13 11:16:40',
#   'changeDate': '2011-11-11 09:07:43',
#   'url': 'http://www.amazon.de/gp/redirect.html%3FASIN=3893364595%26tag=ws%26lcode=xm2%26cID=2025%26ccmID=165953%26location=/o/ASIN/3893364595%253FSubscriptionId=13CT5CVB80YFWJEPWS02',
#   'pub-type': 'book',
#   'year': '2007',
#   'author': [' ?'],
#   'authors': [{'first': '', 'last': '?'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/27f26b46919b08a1bf4409a33f76217a1/sabesa',
#   'text': 'WissKom 2007: Wissenschaftskommunikation der Zukunft: 4. Konferenz der Zentralbibliothek, Forschungszentrum Jülich, 6. - 8. November 2007, Beiträge und Poster'},
#  {'id': 'https://www.bibsonomy.org/bibtex/207952da2dea898ed34e25c5008eeb3c1/itv',
#   'tags': ['nrev'],
#   'label': 'Geometrical Dissipation element analysis if inhomogenous turbulence',
#   'description': '',
#   'date': '2013-03-21 15:13:41',
#   'changeDate': '2014-07-31 07:46:30',
#   'url': '',
#   'pub-type': 'inproceedings',
#   'year': '2010',
#   'author': ['Philipp Schäfer',
#    'Markus Gampert',
#    'Jens-Henrik Göbbert',
#    'David Gottschalk',
#    'Norbert Peters'],
#   'authors': [{'first': 'Philipp', 'last': 'Schäfer'},
#    {'first': 'Markus', 'last': 'Gampert'},
#    {'first': 'Jens-Henrik', 'last': 'Göbbert'},
#    {'first': 'David', 'last': 'Gottschalk'},
#    {'first': 'Norbert', 'last': 'Peters'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/207952da2dea898ed34e25c5008eeb3c1/itv',
#   'text': 'Geometrical Dissipation element analysis if inhomogenous turbulence'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2451e158ada54d9fdfc71e491622a9ea1/kaue',
#   'tags': ['deutschland', 'germany', 'fließgewässer', 'river', 'retention'],
#   'label': 'Retentionsfähigkeit von Gewässernetzen (Handbuch)',
#   'description': '',
#   'date': '2016-03-18 11:10:04',
#   'changeDate': '2016-03-18 11:10:04',
#   'url': '',
#   'pub-type': 'techreport',
#   'year': '2007',
#   'author': ['Klaus Röttcher',
#    'Christoph Linnenweber',
#    'Stephan Theobald',
#    'Ernst-Wolfgang Löffler',
#    'Günter Meon',
#    'Gero Koehler'],
#   'authors': [{'first': 'Klaus', 'last': 'Röttcher'},
#    {'first': 'Christoph', 'last': 'Linnenweber'},
#    {'first': 'Stephan', 'last': 'Theobald'},
#    {'first': 'Ernst-Wolfgang', 'last': 'Löffler'},
#    {'first': 'Günter', 'last': 'Meon'},
#    {'first': 'Gero', 'last': 'Koehler'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2451e158ada54d9fdfc71e491622a9ea1/kaue',
#   'text': 'Retentionsfähigkeit von Gewässernetzen (Handbuch)'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2beed9185eea681fa4e008a4ef0e89b1f/kaue',
#   'tags': ['deutschland', 'germany', 'fließgewässer', 'river', 'retention'],
#   'label': 'Retentionsfähigkeit von Gewässernetzen',
#   'description': '',
#   'date': '2016-03-18 11:08:22',
#   'changeDate': '2016-03-18 11:08:22',
#   'url': '',
#   'pub-type': 'techreport',
#   'year': '2007',
#   'author': ['Klaus Röttcher',
#    'Christoph Linnenweber',
#    'Stephan Theobald',
#    'Ernst-Wolfgang Löffler',
#    'Günter Meon',
#    'Gero Koehler'],
#   'authors': [{'first': 'Klaus', 'last': 'Röttcher'},
#    {'first': 'Christoph', 'last': 'Linnenweber'},
#    {'first': 'Stephan', 'last': 'Theobald'},
#    {'first': 'Ernst-Wolfgang', 'last': 'Löffler'},
#    {'first': 'Günter', 'last': 'Meon'},
#    {'first': 'Gero', 'last': 'Koehler'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2beed9185eea681fa4e008a4ef0e89b1f/kaue',
#   'text': 'Retentionsfähigkeit von Gewässernetzen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2cfbe9da2232fbad9225460bb39f6a025/elearn_fb7_rwth',
#   'tags': ['eBooks', 'E-Books'],
#   'label': 'Akzeptanz und Nutzungsperspektiven von E-Books in Lehre und Forschung: Eine Repräsentativstudie',
#   'description': '',
#   'date': '2017-04-18 10:50:18',
#   'changeDate': '2017-04-18 10:50:18',
#   'url': 'http://juser.fz-juelich.de/record/135755/files/Mundt_Bib_20.pdf',
#   'pub-type': 'conference',
#   'year': '2010',
#   'author': ['Sebastian Mundt'],
#   'authors': [{'first': 'Sebastian', 'last': 'Mundt'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2cfbe9da2232fbad9225460bb39f6a025/elearn_fb7_rwth',
#   'text': 'Akzeptanz und Nutzungsperspektiven von E-Books in Lehre und Forschung: Eine Repräsentativstudie'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e17999f0609322f34d35df347b56f23e/authorfunction',
#   'tags': [],
#   'label': 'I mediearkivet',
#   'description': '',
#   'date': '2008-03-06 22:33:14',
#   'changeDate': '2008-03-06 22:33:14',
#   'url': '',
#   'pub-type': 'incollection',
#   'year': '2006',
#   'author': ['Anders Ekström', 'Solveig Jülich', 'Pelle Snickars'],
#   'authors': [{'first': 'Anders', 'last': 'Ekström'},
#    {'first': 'Solveig', 'last': 'Jülich'},
#    {'first': 'Pelle', 'last': 'Snickars'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2e17999f0609322f34d35df347b56f23e/authorfunction',
#   'text': 'I mediearkivet'},
#  {'id': 'https://www.bibsonomy.org/bibtex/24ea2a4df1f712f27cac5137fcf5d1083/novaesium',
#   'tags': ['Niedergermanien'],
#   'label': 'Siedlungsstrukturen in Niedergermanien',
#   'description': '',
#   'date': '2009-01-07 22:05:18',
#   'changeDate': '2009-01-07 22:05:18',
#   'url': '',
#   'pub-type': 'incollection',
#   'year': '2000',
#   'author': ['Ursula Heimberg'],
#   'authors': [{'first': 'Ursula', 'last': 'Heimberg'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/24ea2a4df1f712f27cac5137fcf5d1083/novaesium',
#   'text': 'Siedlungsstrukturen in Niedergermanien'},
#  {'id': 'https://www.bibsonomy.org/bibtex/268b637817832149dc60442c2cb45a598/hilf',
#   'tags': ['imported'],
#   'label': 'Kernspaltung nach dem Tröpfchenmodell',
#   'description': 'pub-list-hilf',
#   'date': '2008-10-20 10:51:18',
#   'changeDate': '2008-10-20 10:51:18',
#   'url': 'http://www.physik.uni-oldenburg.de/Docs/THEO3/publications/ebs.kernspaltung.pdf',
#   'pub-type': 'inproceedings',
#   'year': '1967',
#   'author': ['E. R. Hilf', 'R. Hasse', ' S.Knaak', 'R. Schade'],
#   'authors': [{'first': 'E. R.', 'last': 'Hilf'},
#    {'first': 'R.', 'last': 'Hasse'},
#    {'first': '', 'last': 'S.Knaak'},
#    {'first': 'R.', 'last': 'Schade'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/268b637817832149dc60442c2cb45a598/hilf',
#   'text': 'Kernspaltung nach dem Tröpfchenmodell'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e684503243cf5149a79a6da0fe3a9e20/kw',
#   'tags': ['idp', 'bibliometrie', 'tum'],
#   'label': 'Bibliometrische Analysen - Daten, Fakten und Methoden - Grundwissen Bibliometrie für Wissenschaftler, Wissenschaftsmanager, Forschungseinrichtungen und Hochschulen',
#   'description': '',
#   'date': '2011-05-25 19:43:57',
#   'changeDate': '2011-05-25 19:43:57',
#   'url': '',
#   'pub-type': 'book',
#   'year': '2005',
#   'author': ['Rafael Ball', 'Dirk Tunger'],
#   'authors': [{'first': 'Rafael', 'last': 'Ball'},
#    {'first': 'Dirk', 'last': 'Tunger'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2e684503243cf5149a79a6da0fe3a9e20/kw',
#   'text': 'Bibliometrische Analysen - Daten, Fakten und Methoden - Grundwissen Bibliometrie für Wissenschaftler, Wissenschaftsmanager, Forschungseinrichtungen und Hochschulen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2344262596433e96a22f780010e147fb2/fbw_hannover',
#   'tags': ['Versorgungswirtschaft'],
#   'label': 'The Indonesian coal sector',
#   'description': '',
#   'date': '2009-08-21 10:05:12',
#   'changeDate': '2009-08-21 10:10:26',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+152633006&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '1988',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2344262596433e96a22f780010e147fb2/fbw_hannover',
#   'text': 'The Indonesian coal sector'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2f5d65f8ee60a623de5536cd515aeb9c5/genealogie',
#   'tags': ['dnb'],
#   'label': 'Finanzgeschichte des Herzogtums Jülich',
#   'description': '',
#   'date': '2015-09-08 15:15:53',
#   'changeDate': '2015-09-08 15:15:53',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1958',
#   'author': ['Heribert Engel'],
#   'authors': [{'first': 'Heribert', 'last': 'Engel'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2f5d65f8ee60a623de5536cd515aeb9c5/genealogie',
#   'text': 'Finanzgeschichte des Herzogtums Jülich'},
#  {'id': 'https://www.bibsonomy.org/bibtex/240e65a8c478596f6cad994d6ba1cfdf3/fbw_hannover',
#   'tags': ['Versorgungswirtschaft'],
#   'label': 'The Indonesian gas sector',
#   'description': '',
#   'date': '2009-08-21 10:05:12',
#   'changeDate': '2009-08-21 10:10:26',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+152632514&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '1988',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/240e65a8c478596f6cad994d6ba1cfdf3/fbw_hannover',
#   'text': 'The Indonesian gas sector'},
#  {'id': 'https://www.bibsonomy.org/bibtex/28e9e50761baaad60de472cc7d05d6cce/fbw_hannover',
#   'tags': ['Organisationen_<Technik_allgemein>',
#    'Forschungsprogramm',
#    'Forschung_und_Entwicklung_<Betriebswirtschaft>',
#    'Werkstoffe_mit_besonderen_Eigenschaften',
#    'Ausbildung',
#    'Hochleistungswerkstoff',
#    'Beruf'],
#   'label': 'Neue Materialien für Schlüsseltechnologien des 21. Jahrhunderts',
#   'description': '',
#   'date': '2009-08-21 11:21:56',
#   'changeDate': '2009-08-21 11:22:30',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+243934890&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '1998',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/28e9e50761baaad60de472cc7d05d6cce/fbw_hannover',
#   'text': 'Neue Materialien für Schlüsseltechnologien des 21. Jahrhunderts'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2aca06883e28697b1526aa946782e583b/uniwue_info3',
#   'tags': ['myown'],
#   'label': 'Auswirkungen der Virtualisierung auf Transparenz und Fehlerdiagnose in lokalen Netzen',
#   'description': '',
#   'date': '2016-03-10 17:34:10',
#   'changeDate': '2022-03-14 00:09:38',
#   'url': '',
#   'pub-type': 'inproceedings',
#   'year': '2003',
#   'author': ['Kurt Tutschku', 'Andreas Binzenhöfer'],
#   'authors': [{'first': 'Kurt', 'last': 'Tutschku'},
#    {'first': 'Andreas', 'last': 'Binzenhöfer'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2aca06883e28697b1526aa946782e583b/uniwue_info3',
#   'text': 'Auswirkungen der Virtualisierung auf Transparenz und Fehlerdiagnose in lokalen Netzen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2077d29bafd94075f3ff4284fe5d39137/lepsky',
#   'tags': ['kuenstliche_intelligenz'],
#   'label': 'Ungeahntes Potential',
#   'description': '',
#   'date': '2019-12-11 17:56:24',
#   'changeDate': '2019-12-11 17:57:50',
#   'url': 'https://www.jungewelt.de/artikel/368253.wissenschaft-ungeahntes-potential.html',
#   'pub-type': 'misc',
#   'year': '2019',
#   'author': ['Christa Schaffmann'],
#   'authors': [{'first': 'Christa', 'last': 'Schaffmann'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2077d29bafd94075f3ff4284fe5d39137/lepsky',
#   'text': 'Ungeahntes Potential'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2d729cc9926903fe256a5d2fbf0ac672d/fbw_hannover',
#   'tags': ['Organisationen_<Technik_allgemein>',
#    'Forschungsprogramm',
#    'Forschung_und_Entwicklung_<Betriebswirtschaft>',
#    'Werkstoffe_mit_besonderen_Eigenschaften',
#    'Ausbildung',
#    'Hochleistungswerkstoff',
#    'Beruf'],
#   'label': 'Neue Materialien für Schlüsseltechnologien des 21. Jahrhunderts',
#   'description': '',
#   'date': '2009-08-21 12:22:28',
#   'changeDate': '2009-08-21 12:23:13',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+532999258&sourceid=fbw_bibsonomy',
#   'pub-type': 'online',
#   'year': '1998',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2d729cc9926903fe256a5d2fbf0ac672d/fbw_hannover',
#   'text': 'Neue Materialien für Schlüsseltechnologien des 21. Jahrhunderts'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2cb23e99e4148a1436a596c522fb8569b/fbw_hannover',
#   'tags': ['alternative_Energieformen',
#    'Finanzierung',
#    'Investition',
#    'Regenerative_Energieformen'],
#   'label': 'Finanzierung von Windkraftanlagen',
#   'description': '',
#   'date': '2009-08-21 11:23:26',
#   'changeDate': '2011-11-11 09:07:43',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+245545433&sourceid=fbw_bibsonomy',
#   'pub-type': 'proceedings',
#   'year': '1995',
#   'author': [' ?'],
#   'authors': [{'first': '', 'last': '?'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2cb23e99e4148a1436a596c522fb8569b/fbw_hannover',
#   'text': 'Finanzierung von Windkraftanlagen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/246bc065950b2aac8d7d20f5b6cae864f/fbw_hannover',
#   'tags': ['Werkstoff',
#    'Technologietransfer',
#    'Wirtschaftswachstum',
#    'Werkstoffe_mit_besonderen_Eigenschaften'],
#   'label': 'Demonstrations-, Transfer- und Kompetenzzentren im Programm Neue Materialien - MaTech des BMBF',
#   'description': '',
#   'date': '2009-08-21 11:34:36',
#   'changeDate': '2009-08-21 11:34:48',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+331303647&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '1998',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/246bc065950b2aac8d7d20f5b6cae864f/fbw_hannover',
#   'text': 'Demonstrations-, Transfer- und Kompetenzzentren im Programm Neue Materialien - MaTech des BMBF'},
#  {'id': 'https://www.bibsonomy.org/bibtex/29910bffdcadbab4e2b996c0bd1f50ddb/lepsky',
#   'tags': ['kommunikationswissenschaft'],
#   'label': 'Wissen : und wie es kommuniziert werden kann',
#   'description': '',
#   'date': '2018-12-16 09:22:42',
#   'changeDate': '2018-12-16 09:22:42',
#   'url': '',
#   'pub-type': 'incollection',
#   'year': '2007',
#   'author': ['Ernst Pöppel'],
#   'authors': [{'first': 'Ernst', 'last': 'Pöppel'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/29910bffdcadbab4e2b996c0bd1f50ddb/lepsky',
#   'text': 'Wissen : und wie es kommuniziert werden kann'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2a802ec380858f3c17d299f8e358ed7b5/fbw_hannover',
#   'tags': ['imported'],
#   'label': 'Energie',
#   'description': '',
#   'date': '2009-08-21 12:23:46',
#   'changeDate': '2009-08-21 12:24:17',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+558124690&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '2007',
#   'author': ['Christoph Buchal'],
#   'authors': [{'first': 'Christoph', 'last': 'Buchal'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2a802ec380858f3c17d299f8e358ed7b5/fbw_hannover',
#   'text': 'Energie'},
#  {'id': 'https://www.bibsonomy.org/bibtex/24df692614a07d8bd219ebd985c3e4859/fbw_hannover',
#   'tags': ['Versorgungswirtschaft'],
#   'label': 'The Indonesian electricity sector',
#   'description': '',
#   'date': '2009-08-21 10:05:12',
#   'changeDate': '2009-08-21 10:10:27',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+152633030&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '1988',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/24df692614a07d8bd219ebd985c3e4859/fbw_hannover',
#   'text': 'The Indonesian electricity sector'},
#  {'id': 'https://www.bibsonomy.org/bibtex/28f4a698d6d2458574ed261b6a13d3db1/fbw_hannover',
#   'tags': ['Versorgungswirtschaft'],
#   'label': 'Demand devices for endusers',
#   'description': '',
#   'date': '2009-08-21 10:05:12',
#   'changeDate': '2009-08-21 10:10:27',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+152633170&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '1988',
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/28f4a698d6d2458574ed261b6a13d3db1/fbw_hannover',
#   'text': 'Demand devices for endusers'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2d658fb61d072830a4abf975fbcfb1d24/genealogie',
#   'tags': ['dnb'],
#   'label': 'Verbreitung parasitärer Tierkrankheiten im Kreise Jülich',
#   'description': '',
#   'date': '2015-09-08 14:55:39',
#   'changeDate': '2015-09-08 14:55:39',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1955',
#   'author': ['Heinrich Camp'],
#   'authors': [{'first': 'Heinrich', 'last': 'Camp'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2d658fb61d072830a4abf975fbcfb1d24/genealogie',
#   'text': 'Verbreitung parasitärer Tierkrankheiten im Kreise Jülich'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2d270d66adcf19c86a949920abf7c6d40/genealogie',
#   'tags': ['Architektur', 'Christliche_Religion', 'dnb'],
#   'label': 'Die Kartause zum Vogelsang bei Jülich',
#   'description': '',
#   'date': '2015-09-09 19:00:34',
#   'changeDate': '2015-09-09 19:00:34',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '2000',
#   'author': ['Harald Goder'],
#   'authors': [{'first': 'Harald', 'last': 'Goder'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2d270d66adcf19c86a949920abf7c6d40/genealogie',
#   'text': 'Die Kartause zum Vogelsang bei Jülich'},
#  {'id': 'https://www.bibsonomy.org/bibtex/24dea828f9519b4ccb9a7ec1d969d7b90/kaigrass',
#   'tags': ['imported'],
#   'label': 'Computer modeling of charged polymers',
#   'description': '',
#   'date': '2007-06-15 17:33:15',
#   'changeDate': '2007-06-15 17:33:20',
#   'url': '',
#   'pub-type': 'incollection',
#   'year': '2002',
#   'author': ['Christian Holm',
#    'Kurt Kremer',
#    'Markus Deserno',
#    'Hans Jörg Limbach'],
#   'authors': [{'first': 'Christian', 'last': 'Holm'},
#    {'first': 'Kurt', 'last': 'Kremer'},
#    {'first': 'Markus', 'last': 'Deserno'},
#    {'first': 'Hans Jörg', 'last': 'Limbach'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/24dea828f9519b4ccb9a7ec1d969d7b90/kaigrass',
#   'text': 'Computer modeling of charged polymers'},
#  {'id': 'https://www.bibsonomy.org/bibtex/28290411c22127ec7fcca1c0e91466d0c/genealogie',
#   'tags': ['Sozialwissenschaften',
#    'Landwirtschaft',
#    'Landschaftsgestaltung',
#    'Raumplanung',
#    'dnb',
#    'Land_und_Forstwissenschaft',
#    'Veterinärmedizin',
#    'Wirtschaftswissenschaften'],
#   'label': 'Sozio-ökonomische Wandlungen im Agrarwirtschaftsraum der Jülich-Zülpicher Börde',
#   'description': '',
#   'date': '2015-09-09 02:42:59',
#   'changeDate': '2015-09-09 02:42:59',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1979',
#   'author': ['Hartwig Arndt'],
#   'authors': [{'first': 'Hartwig', 'last': 'Arndt'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/28290411c22127ec7fcca1c0e91466d0c/genealogie',
#   'text': 'Sozio-ökonomische Wandlungen im Agrarwirtschaftsraum der Jülich-Zülpicher Börde'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2b7e0609e353c495db02c0cd7d5e88081/genealogie',
#   'tags': ['dnb'],
#   'label': 'Seuchengeschichte der Stadt und des Kreises Jülich',
#   'description': '',
#   'date': '2015-09-08 20:36:46',
#   'changeDate': '2015-09-08 20:36:46',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1940',
#   'author': ['Klara Kückhoven'],
#   'authors': [{'first': 'Klara', 'last': 'Kückhoven'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2b7e0609e353c495db02c0cd7d5e88081/genealogie',
#   'text': 'Seuchengeschichte der Stadt und des Kreises Jülich'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2ee5d6b195b8c23f0c0b7ae4b3597914b/genealogie',
#   'tags': ['dnb'],
#   'label': 'Untersuchungen an Sägeeinrichtungen von Motorkettensägen: Unter Berücks. d. Leistungsfähigkeit v. Motorsägeketten',
#   'description': '',
#   'date': '2015-09-08 18:20:52',
#   'changeDate': '2015-09-08 18:20:52',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1963',
#   'author': ['Lothar Jülich'],
#   'authors': [{'first': 'Lothar', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2ee5d6b195b8c23f0c0b7ae4b3597914b/genealogie',
#   'text': 'Untersuchungen an Sägeeinrichtungen von Motorkettensägen: Unter Berücks. d. Leistungsfähigkeit v. Motorsägeketten'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2cbb509119a42cc54b74eb9fe1ece7ade/genealogie',
#   'tags': ['Humanmedizin',
#    'dnb',
#    'Pharmazie',
#    'Gesundheit',
#    'Gesundheitswesen',
#    'Stomatologie',
#    'Medizin'],
#   'label': 'Indikationen, Techniken und Ergebnisse netzhautchirurgischer Eingriffe durch rein sklerale Operationen ohne Verwendung alloplastischer und heteroplastischer Materialien',
#   'description': '',
#   'date': '2015-09-09 06:00:42',
#   'changeDate': '2015-09-09 06:00:42',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1985',
#   'author': ['Bernd Jülich'],
#   'authors': [{'first': 'Bernd', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2cbb509119a42cc54b74eb9fe1ece7ade/genealogie',
#   'text': 'Indikationen, Techniken und Ergebnisse netzhautchirurgischer Eingriffe durch rein sklerale Operationen ohne Verwendung alloplastischer und heteroplastischer Materialien'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2f1026f6820c9455e99ebff260d9e129b/genealogie',
#   'tags': ['Kartographie',
#    'Biowissenschaften',
#    'Naturwissenschaften',
#    'Chemie',
#    'Physik',
#    'Astronomie',
#    'dnb',
#    'Geowissenschaften',
#    'Pflanzen_Botanik',
#    'Paläontologie',
#    'Biologie',
#    'Tiere_Zoologie'],
#   'label': 'Hämatologische Untersuchungen an Regenbogenforellen (Salmo gairdneri) und Karpfen (Cyprinus carpio) nach Einwirkung von subletalen Konzentrationen der Pflanzenschutzmittel Rogor, Benomyl, Pomuran und Domatol-Spezial',
#   'description': '',
#   'date': '2015-09-09 01:55:01',
#   'changeDate': '2015-09-09 01:55:01',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1977',
#   'author': ['Frank Jülich'],
#   'authors': [{'first': 'Frank', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2f1026f6820c9455e99ebff260d9e129b/genealogie',
#   'text': 'Hämatologische Untersuchungen an Regenbogenforellen (Salmo gairdneri) und Karpfen (Cyprinus carpio) nach Einwirkung von subletalen Konzentrationen der Pflanzenschutzmittel Rogor, Benomyl, Pomuran und Domatol-Spezial'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21b3f8867aea022d5bb8ad1e983f66938/genealogie',
#   'tags': ['dnb'],
#   'label': 'Beitrag zur Behandlung mit Thorakokaustik',
#   'description': '',
#   'date': '2015-09-08 20:30:04',
#   'changeDate': '2015-09-08 20:30:04',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1943',
#   'author': ['Eduard Jülich'],
#   'authors': [{'first': 'Eduard', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/21b3f8867aea022d5bb8ad1e983f66938/genealogie',
#   'text': 'Beitrag zur Behandlung mit Thorakokaustik'},
#  {'id': 'https://www.bibsonomy.org/bibtex/22b4ba74a5e08a6547b78f4ccb2e5e660/genealogie',
#   'tags': ['Biowissenschaften', 'dnb', 'Biologie'],
#   'label': 'Genetic analysis of differences in the spatiotemporal control of somitogenesis in the Zebrafish, Danio rerio',
#   'description': '',
#   'date': '2015-09-09 23:07:37',
#   'changeDate': '2015-09-09 23:07:37',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '2005',
#   'author': ['Dörthe Jülich'],
#   'authors': [{'first': 'Dörthe', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/22b4ba74a5e08a6547b78f4ccb2e5e660/genealogie',
#   'text': 'Genetic analysis of differences in the spatiotemporal control of somitogenesis in the Zebrafish, Danio rerio'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2c8010a8b52b34c6df7161dae39f6284b/genealogie',
#   'tags': ['dnb', 'Gesundheit', 'Medizin'],
#   'label': 'Beitrag zur Frage der Komplementbindungsreaktion <KBR> bei Gonorrhoe <Go>',
#   'description': '',
#   'date': '2015-09-08 17:07:33',
#   'changeDate': '2015-09-08 17:07:33',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1945',
#   'author': ['Edith Elisabeth Jülich'],
#   'authors': [{'first': 'Edith Elisabeth', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2c8010a8b52b34c6df7161dae39f6284b/genealogie',
#   'text': 'Beitrag zur Frage der Komplementbindungsreaktion <KBR> bei Gonorrhoe <Go>'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2034500ae58516eacafea27f20ebb4d05/genealogie',
#   'tags': ['dnb'],
#   'label': 'Die Geschichte der Urkundensprache des Herzogtums Jülich',
#   'description': '',
#   'date': '2015-09-08 12:36:09',
#   'changeDate': '2015-09-08 12:36:09',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1923',
#   'author': ['Maria Scheben'],
#   'authors': [{'first': 'Maria', 'last': 'Scheben'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2034500ae58516eacafea27f20ebb4d05/genealogie',
#   'text': 'Die Geschichte der Urkundensprache des Herzogtums Jülich'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2bc3df809779f24cc9fad512a1b49fb96/genealogie',
#   'tags': ['dnb', 'Gesundheit', 'Medizin'],
#   'label': 'Die Trink- und Nutzwasserversorgung des Kreises Jülich',
#   'description': '',
#   'date': '2015-09-08 14:54:18',
#   'changeDate': '2015-09-08 14:54:18',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1955',
#   'author': ['Arnold Esser'],
#   'authors': [{'first': 'Arnold', 'last': 'Esser'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2bc3df809779f24cc9fad512a1b49fb96/genealogie',
#   'text': 'Die Trink- und Nutzwasserversorgung des Kreises Jülich'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2802a28c5081cfc079cd8bced223dfd86/genealogie',
#   'tags': ['dnb', 'Gesundheit', 'Medizin'],
#   'label': 'Statistische Untersuchungen über die Einzelfeststellungen des ärztlichen Blutentnahmebefundes bei Blutalkoholwerten ab 2,2 _348 bei Straßenverkehrsdelikten',
#   'description': '',
#   'date': '2015-09-08 16:26:58',
#   'changeDate': '2015-09-08 16:26:58',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1966',
#   'author': ['Albert Jülich'],
#   'authors': [{'first': 'Albert', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2802a28c5081cfc079cd8bced223dfd86/genealogie',
#   'text': 'Statistische Untersuchungen über die Einzelfeststellungen des ärztlichen Blutentnahmebefundes bei Blutalkoholwerten ab 2,2 _348 bei Straßenverkehrsdelikten'},
#  {'id': 'https://www.bibsonomy.org/bibtex/22d787b572d1cb1dc641bc0c2ef1d8cdf/genealogie',
#   'tags': ['dnb'],
#   'label': 'Ehelicher Aufwand im Güterstande der Gütertrennung und sein Verhältnis zu den Unterhaltsnormen',
#   'description': '',
#   'date': '2015-09-08 20:30:05',
#   'changeDate': '2015-09-08 20:30:05',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1924',
#   'author': ['Lutwin Jülich'],
#   'authors': [{'first': 'Lutwin', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/22d787b572d1cb1dc641bc0c2ef1d8cdf/genealogie',
#   'text': 'Ehelicher Aufwand im Güterstande der Gütertrennung und sein Verhältnis zu den Unterhaltsnormen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21ab6c492a888452141215ea7669b7805/genealogie',
#   'tags': ['dnb'],
#   'label': 'Das Richtungshören bei Verwendung eines Schallschutzgerätes',
#   'description': '',
#   'date': '2015-09-08 20:30:05',
#   'changeDate': '2015-09-08 20:30:05',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1942',
#   'author': ['Maria Jülich'],
#   'authors': [{'first': 'Maria', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/21ab6c492a888452141215ea7669b7805/genealogie',
#   'text': 'Das Richtungshören bei Verwendung eines Schallschutzgerätes'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2b0c4cf1c231e309ef5e8012edf874b18/genealogie',
#   'tags': ['dnb'],
#   'label': 'Über Schmerzen bei Ulcus ventriculi und deren Zustandekommen oder Fehlen',
#   'description': '',
#   'date': '2015-09-08 20:30:05',
#   'changeDate': '2015-09-08 20:30:05',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1920',
#   'author': ['Walter Jülich'],
#   'authors': [{'first': 'Walter', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2b0c4cf1c231e309ef5e8012edf874b18/genealogie',
#   'text': 'Über Schmerzen bei Ulcus ventriculi und deren Zustandekommen oder Fehlen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/25da29ee1c08faeaeeef9d35c138c0813/genealogie',
#   'tags': ['dnb', 'Gesundheit', 'Gesundheitswesen', 'Biologie', 'Medizin'],
#   'label': 'Histologische und enzymhistochemische Untersuchungen des jahreszeitlichen Stützzellen-Zyklus im Testis des Grasfrosches Rana temporaria',
#   'description': '',
#   'date': '2015-09-09 07:21:51',
#   'changeDate': '2015-09-09 07:21:51',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1982',
#   'author': ['Gisela Jülich'],
#   'authors': [{'first': 'Gisela', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/25da29ee1c08faeaeeef9d35c138c0813/genealogie',
#   'text': 'Histologische und enzymhistochemische Untersuchungen des jahreszeitlichen Stützzellen-Zyklus im Testis des Grasfrosches Rana temporaria'},
#  {'id': 'https://www.bibsonomy.org/bibtex/29b28b4a1b67d7c19850c36dceb4c7603/genealogie',
#   'tags': ['Biowissenschaften',
#    'Chemie',
#    'dnb',
#    'Pflanzen_Botanik',
#    'Biologie',
#    'Tiere_Zoologie'],
#   'label': 'Strukturaufklärung der Pyoverdine aus Pseudomonas syringae Stämmen',
#   'description': '',
#   'date': '2015-09-09 17:51:44',
#   'changeDate': '2015-09-09 17:51:44',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '2000',
#   'author': ['Markus Jülich'],
#   'authors': [{'first': 'Markus', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/29b28b4a1b67d7c19850c36dceb4c7603/genealogie',
#   'text': 'Strukturaufklärung der Pyoverdine aus Pseudomonas syringae Stämmen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/272b4deb73dd3b3a123b5eea33fa79035/genealogie',
#   'tags': ['Öffentliche_Verwaltung', 'dnb', 'Recht', 'Verwaltung'],
#   'label': 'Chancengleichheit der Parteien: Zur Grenze staatl. Handelns gegenüber d. polit. Parteien nach d. Grundgesetz',
#   'description': '',
#   'date': '2015-09-08 13:41:23',
#   'changeDate': '2015-09-08 13:41:23',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1967',
#   'author': ['Christian Jülich'],
#   'authors': [{'first': 'Christian', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/272b4deb73dd3b3a123b5eea33fa79035/genealogie',
#   'text': 'Chancengleichheit der Parteien: Zur Grenze staatl. Handelns gegenüber d. polit. Parteien nach d. Grundgesetz'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e205445e92729b53f5322cfe50ff7139/genealogie',
#   'tags': ['Biowissenschaften',
#    'Chemie',
#    'dnb',
#    'Pflanzen_Botanik',
#    'Biologie',
#    'Tiere_Zoologie',
#    'Medizin'],
#   'label': 'ESR- und ENDOR-Untersuchungen an paramagnetischen Metaboliten p-chinoider Wirkstoffe',
#   'description': '',
#   'date': '2015-09-09 08:53:42',
#   'changeDate': '2015-09-09 08:53:42',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1990',
#   'author': ['Thomas Jülich'],
#   'authors': [{'first': 'Thomas', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2e205445e92729b53f5322cfe50ff7139/genealogie',
#   'text': 'ESR- und ENDOR-Untersuchungen an paramagnetischen Metaboliten p-chinoider Wirkstoffe'},
#  {'id': 'https://www.bibsonomy.org/bibtex/24f1afbe6c470d491cf7d432c7672b751/genealogie',
#   'tags': ['Druckgrafik',
#    'Technische_Chemie',
#    'Chemische_Technologie_und_Produktion',
#    'Drucke',
#    'Computerkunst',
#    'Lebensmitteltechnologie',
#    'Industrielle_und_handwerkliche_Fertigung',
#    'Textiltechnik_und_andere_Technologien',
#    'dnb',
#    'Video',
#    'Fotografie'],
#   'label': 'Entwicklung einer gaschromatographischen Headspacemethode zur Anreicherung und Identifizierung von Spurenkomponenten, dargestellt am Beispiel des Passionsfrucht- und Würzearomas',
#   'description': '',
#   'date': '2015-09-09 07:04:05',
#   'changeDate': '2015-09-09 07:04:05',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1986',
#   'author': ['Elsbeth Jülich'],
#   'authors': [{'first': 'Elsbeth', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/24f1afbe6c470d491cf7d432c7672b751/genealogie',
#   'text': 'Entwicklung einer gaschromatographischen Headspacemethode zur Anreicherung und Identifizierung von Spurenkomponenten, dargestellt am Beispiel des Passionsfrucht- und Würzearomas'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2f8a39f82142a5588522cd88304c41332/genealogie',
#   'tags': ['dnb'],
#   'label': 'Gefahren der Operativen von Uterustumoren nach Vorbestrahlung',
#   'description': '',
#   'date': '2015-09-08 20:30:04',
#   'changeDate': '2015-09-08 20:30:04',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1933',
#   'author': ['Albert Jülich'],
#   'authors': [{'first': 'Albert', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2f8a39f82142a5588522cd88304c41332/genealogie',
#   'text': 'Gefahren der Operativen von Uterustumoren nach Vorbestrahlung'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e575794e4f64ed6dc40d552e926c1ee5/genealogie',
#   'tags': ['Druckgrafik',
#    'Metallkunst',
#    'Bildende_Kunst_allgemein',
#    'Keramik',
#    'Baukunst',
#    'Künste',
#    'Plastik',
#    'Grafik',
#    'Malerei',
#    'Architektur',
#    'angewandte_Kunst',
#    'Numismatik',
#    'Drucke',
#    'dnb',
#    'Bildende_Kunst'],
#   'label': 'Gemmenkreuze: d. Farbigkeit ihres Edelsteinbesatzes bis zum 12. Jh.',
#   'description': '',
#   'date': '2015-09-08 09:07:58',
#   'changeDate': '2015-09-08 09:07:58',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1988',
#   'author': ['Theo Jülich'],
#   'authors': [{'first': 'Theo', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2e575794e4f64ed6dc40d552e926c1ee5/genealogie',
#   'text': 'Gemmenkreuze: d. Farbigkeit ihres Edelsteinbesatzes bis zum 12. Jh.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/27558a9a2498c13c8909decdfc39cf409/genealogie',
#   'tags': ['dnb', 'Gesundheit', 'Medizin'],
#   'label': 'Über einen Fall von Sirenenbildung',
#   'description': '',
#   'date': '2015-09-08 14:54:21',
#   'changeDate': '2015-09-08 14:54:21',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1955',
#   'author': ['Erwin Jülich'],
#   'authors': [{'first': 'Erwin', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/27558a9a2498c13c8909decdfc39cf409/genealogie',
#   'text': 'Über einen Fall von Sirenenbildung'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2f1d01aaf563d2ccc2661d053c236800f/genealogie',
#   'tags': ['Geografie',
#    'Paläontologie',
#    'Länderkunde',
#    'Reisen',
#    'Geographie',
#    'Etikette',
#    'Erd_und_Völkerkunde',
#    'dnb',
#    'Geowissenschaften',
#    'Geschichte',
#    'Bräuche',
#    'Land_und_Forstwissenschaft',
#    'Folklore'],
#   'label': 'Die Agrarkolonisation im Regenwald des mittleren Río Huallaga (Peru)',
#   'description': '',
#   'date': '2015-09-09 00:15:04',
#   'changeDate': '2015-09-09 00:15:04',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1974',
#   'author': ['Volker Jülich'],
#   'authors': [{'first': 'Volker', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2f1d01aaf563d2ccc2661d053c236800f/genealogie',
#   'text': 'Die Agrarkolonisation im Regenwald des mittleren Río Huallaga (Peru)'},
#  {'id': 'https://www.bibsonomy.org/bibtex/22b965cf1f0ef8f2f3041b4af0f11283e/genealogie',
#   'tags': ['Erziehung',
#    'Schul_und_Bildungswesen',
#    'dnb',
#    'Bildung',
#    'Unterricht',
#    'Recht'],
#   'label': 'Schulische Integration in den USA: bisherige Erfahrungen bei der Umsetzung des Bundesgesetzes Public Law 94-142 - dargestellt anhand einer Analyse der Annual reports to Congress',
#   'description': '',
#   'date': '2015-09-09 14:17:50',
#   'changeDate': '2015-09-09 14:17:50',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1996',
#   'author': ['Martina Jülich'],
#   'authors': [{'first': 'Martina', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/22b965cf1f0ef8f2f3041b4af0f11283e/genealogie',
#   'text': 'Schulische Integration in den USA: bisherige Erfahrungen bei der Umsetzung des Bundesgesetzes Public Law 94-142 - dargestellt anhand einer Analyse der Annual reports to Congress'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2a6b2971e39f7de8f88916bea5448bdfa/genealogie',
#   'tags': ['Alte_Geschichte', 'Technische_Chemie', 'dnb', 'Archäologie'],
#   'label': 'Die frühmittelalterliche Saline von Soest im europäischen Kontext',
#   'description': '',
#   'date': '2015-09-10 02:11:51',
#   'changeDate': '2015-09-10 02:11:51',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '2005',
#   'author': ['Susanne Jülich'],
#   'authors': [{'first': 'Susanne', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2a6b2971e39f7de8f88916bea5448bdfa/genealogie',
#   'text': 'Die frühmittelalterliche Saline von Soest im europäischen Kontext'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2aaf892e69b4798835f8c861b6d4d1fed/genealogie',
#   'tags': ['dnb'],
#   'label': 'Chancengleichheit der Parteien: Zur Grenze staatl. Handelns gegenüber d. polit. Parteien nach dem Grundgesetz',
#   'description': '',
#   'date': '2015-09-08 16:40:31',
#   'changeDate': '2015-09-08 16:40:31',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1966',
#   'author': ['Christian Jülich'],
#   'authors': [{'first': 'Christian', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2aaf892e69b4798835f8c861b6d4d1fed/genealogie',
#   'text': 'Chancengleichheit der Parteien: Zur Grenze staatl. Handelns gegenüber d. polit. Parteien nach dem Grundgesetz'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2aa4989df49678090bdcd72c39c866421/genealogie',
#   'tags': ['dnb'],
#   'label': 'Ueber die Stoffelsche Operation: Aus d. Chir. Kl. d. Univ. Bonn',
#   'description': '',
#   'date': '2015-09-08 20:30:05',
#   'changeDate': '2015-09-08 20:30:05',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1920',
#   'author': ['Paul Jülich'],
#   'authors': [{'first': 'Paul', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2aa4989df49678090bdcd72c39c866421/genealogie',
#   'text': 'Ueber die Stoffelsche Operation: Aus d. Chir. Kl. d. Univ. Bonn'},
#  {'id': 'https://www.bibsonomy.org/bibtex/275bfde1e8f98332cc9c3d75c565ed949/genealogie',
#   'tags': ['dnb'],
#   'label': 'Ein Beitrag zur Klinik und Pathologie des primären Tubencarcinoms',
#   'description': '',
#   'date': '2015-09-08 20:30:05',
#   'changeDate': '2015-09-08 20:30:05',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1932',
#   'author': ['Siegfried Jülich'],
#   'authors': [{'first': 'Siegfried', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/275bfde1e8f98332cc9c3d75c565ed949/genealogie',
#   'text': 'Ein Beitrag zur Klinik und Pathologie des primären Tubencarcinoms'},
#  {'id': 'https://www.bibsonomy.org/bibtex/213d82c21e279d943e89efa5833936505/genealogie',
#   'tags': ['dnb'],
#   'label': 'Monographie der Athelieae (Corticiaceae Basidiomycetes)',
#   'description': '',
#   'date': '2015-09-08 20:30:05',
#   'changeDate': '2015-09-08 20:30:05',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'year': '1971',
#   'author': ['Walter Jülich'],
#   'authors': [{'first': 'Walter', 'last': 'Jülich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/213d82c21e279d943e89efa5833936505/genealogie',
#   'text': 'Monographie der Athelieae (Corticiaceae Basidiomycetes)'},
#  {'id': 'https://www.bibsonomy.org/bibtex/27feae1a26191d4a09bf839de5356a758/genealogie',
#   'tags': ['Druckgrafik',
#    'Metallkunst',
#    'Bildende_Kunst_allgemein',
#    'Keramik',
#    'Künste',
#    'Plastik',
#    'Grafik',
#    'Malerei',
#    'angewandte_Kunst',
#    'Numismatik',
#    'Drucke',
#    'dnb',
#    'Bildende_Kunst'],
# ...
#   'tags': ['dblp'],
#   'label': 'Untersuchungen zum Prozess der Fehlerbewältigung bei einem Textverarbeitsprogramm.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#ZapfLW91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Dieter Zapf', 'Thomas Lang', 'Angela Wittmann'],
#   'authors': [{'first': 'Dieter', 'last': 'Zapf'},
#    {'first': 'Thomas', 'last': 'Lang'},
#    {'first': 'Angela', 'last': 'Wittmann'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2944c88558a80c56626d6367a12a583db/dblp',
#   'text': 'Untersuchungen zum Prozess der Fehlerbewältigung bei einem Textverarbeitsprogramm.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/23d942a3468b83fe33052dc1dd0999053/dblp',
#   'tags': ['dblp'],
#   'label': 'Benutzerbeteiligung aus der Sicht von Endbenutzern, Software-Entwicklern und Führungskräften.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#SpinasW91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Philipp Spinas', 'Daniel Waeber'],
#   'authors': [{'first': 'Philipp', 'last': 'Spinas'},
#    {'first': 'Daniel', 'last': 'Waeber'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/23d942a3468b83fe33052dc1dd0999053/dblp',
#   'text': 'Benutzerbeteiligung aus der Sicht von Endbenutzern, Software-Entwicklern und Führungskräften.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2b7c62c3921fdafd2c7490ed071373464/dblp',
#   'tags': ['dblp'],
#   'label': 'Partizipative Gestaltung handlungsorientierter DV-Unterstützung für Arbeitsabläufe in der Industrie.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#Apitz91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Wolfgang Apitz'],
#   'authors': [{'first': 'Wolfgang', 'last': 'Apitz'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2b7c62c3921fdafd2c7490ed071373464/dblp',
#   'text': 'Partizipative Gestaltung handlungsorientierter DV-Unterstützung für Arbeitsabläufe in der Industrie.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/215b2256e00af6731a70151875c108c82/dblp',
#   'tags': ['dblp'],
#   'label': 'Integration software-ergonomischer Forschungsergebnisse in die betriebliche Software-Entwicklung. Erfahrungen, Strategien, Potentiale und Probleme.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#Eberleh91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Edmund Eberleh'],
#   'authors': [{'first': 'Edmund', 'last': 'Eberleh'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/215b2256e00af6731a70151875c108c82/dblp',
#   'text': 'Integration software-ergonomischer Forschungsergebnisse in die betriebliche Software-Entwicklung. Erfahrungen, Strategien, Potentiale und Probleme.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2ab9521e5ff7c94f3961800f25b04c40a/dblp',
#   'tags': ['dblp'],
#   'label': 'Systemanpassung als Kooperationsproblem.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#Paetau91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Michael Paetau'],
#   'authors': [{'first': 'Michael', 'last': 'Paetau'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2ab9521e5ff7c94f3961800f25b04c40a/dblp',
#   'text': 'Systemanpassung als Kooperationsproblem.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/26442cf6c1f5302c434431bb6f25a8e3a/dblp',
#   'tags': ['dblp'],
#   'label': 'Protoyping in einem Designteam: Vorgehen und Erfahrungen bei einer Software-Entwicklung unter Benutzerbeteiligung.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#HeideH91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Bernd Müller-Holz auf der Heide', 'Susanne Hacker'],
#   'authors': [{'first': 'Bernd Müller-Holz', 'last': 'auf der Heide'},
#    {'first': 'Susanne', 'last': 'Hacker'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/26442cf6c1f5302c434431bb6f25a8e3a/dblp',
#   'text': 'Protoyping in einem Designteam: Vorgehen und Erfahrungen bei einer Software-Entwicklung unter Benutzerbeteiligung.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2288e72fea65f095e8793811d7b32c549/dblp',
#   'tags': ['dblp'],
#   'label': 'Ein Software-Ergonomie-Expertensystem.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#GornyV91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Peter Gorny', 'Axel Viereck'],
#   'authors': [{'first': 'Peter', 'last': 'Gorny'},
#    {'first': 'Axel', 'last': 'Viereck'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2288e72fea65f095e8793811d7b32c549/dblp',
#   'text': 'Ein Software-Ergonomie-Expertensystem.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/23334035b6de23ca8dd481cda5c7913fa/dblp',
#   'tags': ['dblp'],
#   'label': 'Eigenprogrammierung als Unterstützung individueller Arbeitsgestaltung.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#HaslerRSSTB91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Klaus-Peter Hasler',
#    'Heinrich Riehl',
#    'Uwe Schläger',
#    'Johannes Schnepel',
#    'Wolfgang Taube',
#    'Gabriele Winker'],
#   'authors': [{'first': 'Klaus-Peter', 'last': 'Hasler'},
#    {'first': 'Heinrich', 'last': 'Riehl'},
#    {'first': 'Uwe', 'last': 'Schläger'},
#    {'first': 'Johannes', 'last': 'Schnepel'},
#    {'first': 'Wolfgang', 'last': 'Taube'},
#    {'first': 'Gabriele', 'last': 'Winker'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/23334035b6de23ca8dd481cda5c7913fa/dblp',
#   'text': 'Eigenprogrammierung als Unterstützung individueller Arbeitsgestaltung.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2cea8b8531bc92e71f6f8dcf3fd4f8852/dblp',
#   'tags': ['dblp'],
#   'label': 'Entwicklung graphischer Benutzungsschnittstellen durch hierarchische Komposition.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#Castner91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Michael Castner'],
#   'authors': [{'first': 'Michael', 'last': 'Castner'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2cea8b8531bc92e71f6f8dcf3fd4f8852/dblp',
#   'text': 'Entwicklung graphischer Benutzungsschnittstellen durch hierarchische Komposition.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2d0f53f4aac0add59de8d4c7b7c25a854/dblp',
#   'tags': ['dblp'],
#   'label': 'Lerngewinn aus Beispielen in Abhängigkeit von der Lernform und der Aufmekrsamkeitslenkung.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#SchindlerB91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Raimund Schindler', 'Frank Belke'],
#   'authors': [{'first': 'Raimund', 'last': 'Schindler'},
#    {'first': 'Frank', 'last': 'Belke'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2d0f53f4aac0add59de8d4c7b7c25a854/dblp',
#   'text': 'Lerngewinn aus Beispielen in Abhängigkeit von der Lernform und der Aufmekrsamkeitslenkung.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2c7ada64ceed6ba3fad8ab957a1d4b09f/dblp',
#   'tags': ['dblp'],
#   'label': 'Die Konstruktion von Benutzungsschnittstellen: Ein neuer Ansatz für Systemarchitektur und Werzeuge.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#Greutmann91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Thomas Greutmann'],
#   'authors': [{'first': 'Thomas', 'last': 'Greutmann'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2c7ada64ceed6ba3fad8ab957a1d4b09f/dblp',
#   'text': 'Die Konstruktion von Benutzungsschnittstellen: Ein neuer Ansatz für Systemarchitektur und Werzeuge.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/25565dcd4bc9fa57903fa91ea3b6ba618/dblp',
#   'tags': ['dblp'],
#   'label': 'Die Integration von Dialogablauf-Beschreibungen in eine objektorientierte User-Interface-Architektur.',
#   'description': '',
#   'date': '2020-11-23 00:00:00',
#   'changeDate': '2020-11-24 11:36:30',
#   'url': 'http://dblp.uni-trier.de/db/conf/softerg/softerg1991.html#Voss91',
#   'pub-type': 'inproceedings',
#   'year': '1991',
#   'author': ['Josef Voss'],
#   'authors': [{'first': 'Josef', 'last': 'Voss'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/25565dcd4bc9fa57903fa91ea3b6ba618/dblp',
#   'text': 'Die Integration von Dialogablauf-Beschreibungen in eine objektorientierte User-Interface-Architektur.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2c46fd7161a0e5c7ef5615298706ff7e2/fbw_hannover',
#   'tags': ['imported'],
#   'label': 'Innovation und Veränderung in Organisationen und Gemeinwesen',
#   'description': '',
#   'date': '2009-08-21 09:49:34',
#   'changeDate': '2009-08-21 09:49:49',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+023752084&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '1979',
#   'author': ['Jack Rothman', 'John L. Erlich', 'Joseph G. Teresa'],
#   'authors': [{'first': 'Jack', 'last': 'Rothman'},
#    {'first': 'John L.', 'last': 'Erlich'},
#    {'first': 'Joseph G.', 'last': 'Teresa'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2c46fd7161a0e5c7ef5615298706ff7e2/fbw_hannover',
#   'text': 'Innovation und Veränderung in Organisationen und Gemeinwesen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/206bd2c7d4dbe1955ab227f83ce1f2cda/dblp',
#   'tags': ['dblp'],
#   'label': 'INPUT WORT - Ansätze der Simulation wortweiser Textverarbeitung.',
#   'description': '',
#   'date': '2003-01-09 00:00:00',
#   'changeDate': '2016-11-17 11:42:25',
#   'url': 'http://dblp.uni-trier.de/db/conf/ling/ling1988.html#AulichDRS88',
#   'pub-type': 'inproceedings',
#   'year': '1988',
#   'author': ['Manfred Aulich',
#    'Guido Drexel',
#    'Gert Rickheit',
#    'Hans Strohner'],
#   'authors': [{'first': 'Manfred', 'last': 'Aulich'},
#    {'first': 'Guido', 'last': 'Drexel'},
#    {'first': 'Gert', 'last': 'Rickheit'},
#    {'first': 'Hans', 'last': 'Strohner'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/206bd2c7d4dbe1955ab227f83ce1f2cda/dblp',
#   'text': 'INPUT WORT - Ansätze der Simulation wortweiser Textverarbeitung.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/23ee221d2ddee41f4ab8ea53949685396/dblp',
#   'tags': ['dblp'],
#   'label': 'ÜPS - Ein autorenfreundliches Trainingssystem für SQLAnfragen.',
#   'description': '',
#   'date': '2018-04-16 00:00:00',
#   'changeDate': '2019-11-15 11:48:22',
#   'url': 'http://dblp.uni-trier.de/db/conf/delfi/delfi2014.html#IflandJSP14',
#   'pub-type': 'inproceedings',
#   'year': '2014',
#   'author': ['Marianus Ifland',
#    'Michael Jedich',
#    'Christian Schneider',
#    'Frank Puppe'],
#   'authors': [{'first': 'Marianus', 'last': 'Ifland'},
#    {'first': 'Michael', 'last': 'Jedich'},
#    {'first': 'Christian', 'last': 'Schneider'},
#    {'first': 'Frank', 'last': 'Puppe'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/23ee221d2ddee41f4ab8ea53949685396/dblp',
#   'text': 'ÜPS - Ein autorenfreundliches Trainingssystem für SQLAnfragen.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2a3e003865c3eba9fca2b62d33bbf3e2a/dblp',
#   'tags': ['dblp'],
#   'label': 'Identification of dynamic equivalents based on heuristic optimization for smart grid applications.',
#   'description': '',
#   'date': '2017-06-01 00:00:00',
#   'changeDate': '2019-10-17 15:48:10',
#   'url': 'http://dblp.uni-trier.de/db/conf/cec/cec2012.html#CepedaRE12',
#   'pub-type': 'inproceedings',
#   'year': '2012',
#   'author': ['Jaime C. Cepeda', 'José Luis Rueda', 'István Erlich'],
#   'authors': [{'first': 'Jaime C.', 'last': 'Cepeda'},
#    {'first': 'José Luis', 'last': 'Rueda'},
#    {'first': 'István', 'last': 'Erlich'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2a3e003865c3eba9fca2b62d33bbf3e2a/dblp',
#   'text': 'Identification of dynamic equivalents based on heuristic optimization for smart grid applications.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2f8da7161f85a3b25c612783d42fd62d4/dblp',
#   'tags': ['dblp'],
#   'label': 'Lower Bound on VC-Dimension by Local Shattering.',
#   'description': '',
#   'date': '2020-09-01 00:00:00',
#   'changeDate': '2020-09-09 12:28:59',
#   'url': 'http://dblp.uni-trier.de/db/journals/neco/neco9.html#ErlichCPL97',
#   'pub-type': 'article',
#   'year': '1997',
#   'author': ['Yossi Erlich', 'Dan Chazan', 'Scott Petrack', 'Avi Levi'],
#   'authors': [{'first': 'Yossi', 'last': 'Erlich'},
#    {'first': 'Dan', 'last': 'Chazan'},
#    {'first': 'Scott', 'last': 'Petrack'},
#    {'first': 'Avi', 'last': 'Levi'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2f8da7161f85a3b25c612783d42fd62d4/dblp',
#   'text': 'Lower Bound on VC-Dimension by Local Shattering.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2d075c0b0cd8537471ec0fb80529e91b4/dblp',
#   'tags': ['dblp'],
#   'label': 'Spatial Reasoning in Native Speakers of Russian and German.',
#   'description': '',
#   'date': '2016-02-25 00:00:00',
#   'changeDate': '2016-02-26 11:37:59',
#   'url': 'http://dblp.uni-trier.de/db/conf/cogsci/cogsci2013.html#MikheevaBNK13',
#   'pub-type': 'inproceedings',
#   'year': '2013',
#   'author': ['Maria Mikheeva',
#    'Leandra Bucher',
#    'Jelica Nejasmic',
#    'Markus Knauff'],
#   'authors': [{'first': 'Maria', 'last': 'Mikheeva'},
#    {'first': 'Leandra', 'last': 'Bucher'},
#    {'first': 'Jelica', 'last': 'Nejasmic'},
#    {'first': 'Markus', 'last': 'Knauff'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2d075c0b0cd8537471ec0fb80529e91b4/dblp',
#   'text': 'Spatial Reasoning in Native Speakers of Russian and German.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/279c50e871f86aa27fe0adf46965e968a/fbw_hannover',
#   'tags': ['Community_organization',
#    'Diffusion_of_innovations',
#    'etc.',
#    'Handbooks',
#    'Community_development',
#    'Evaluation_research_(Social_action_programs)',
#    'manuals',
#    'United_States'],
#   'label': 'Promoting innovation and change in organizations and communities',
#   'description': '',
#   'date': '2009-08-21 12:28:26',
#   'changeDate': '2009-08-21 12:28:32',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+020335474&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'year': '1976',
#   'author': ['Jack Rothman', 'John L. Erlich', 'Joseph G. Teresa'],
#   'authors': [{'first': 'Jack', 'last': 'Rothman'},
#    {'first': 'John L.', 'last': 'Erlich'},
#    {'first': 'Joseph G.', 'last': 'Teresa'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/279c50e871f86aa27fe0adf46965e968a/fbw_hannover',
#   'text': 'Promoting innovation and change in organizations and communities'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e3e50cbbe638775e456b3acd861018f9/dblp',
#   'tags': ['dblp'],
#   'label': 'PEGASE pan-European test-beds for testing of algorithms on very large scale power systems.',
#   'description': '',
#   'date': '2013-09-11 00:00:00',
#   'changeDate': '2013-09-12 11:33:58',
#   'url': 'http://dblp.uni-trier.de/db/conf/isgteurope/isgteurope2012.html#VillellaLER12',
#   'pub-type': 'inproceedings',
#   'year': '2012',
#   'author': ['Fortunato Villella',
#    'Sylvain Leclerc',
#    'István Erlich',
#    'Stephane Rapoport'],
#   'authors': [{'first': 'Fortunato', 'last': 'Villella'},
#    {'first': 'Sylvain', 'last': 'Leclerc'},
#    {'first': 'István', 'last': 'Erlich'},
#    {'first': 'Stephane', 'last': 'Rapoport'}],
#   'docno': 'https://www.bibsonomy.org/bibtex/2e3e50cbbe638775e456b3acd861018f9/dblp',
#   'text': 'PEGASE pan-European test-beds for testing of algorithms on very large scale power systems.'}]

# %%
index_folder_mult = "./juelich2_index_mult"

fields = ['docno', 'text', 'tags', 'description']

indexer_mult = pt.IterDictIndexer(index_folder_mult, meta={'docno' : 200, 'text' : 4096}, overwrite = True)
index_ref_mult = indexer_mult.index(ai_dict, fields=fields)

print(f"path to our index: {index_ref_mult.toString()}")
# Out:
# path to our index: ./juelich2_index_mult/data.properties

# %%
index_mult = pt.IndexFactory.of(index_ref_mult)

# %%
print(index_mult.getCollectionStatistics().toString())
# Out:
# Number of documents: 1000
# Number of terms: 4501
# Number of postings: 17595
# Number of fields: 4
# Number of tokens: 19165
# Field names: [docno, text, tags, description]
# Positions:   false

# %%
search_engine_mult = pt.BatchRetrieve(index_mult, vmodel="TF_IDF")

# %%
res = search_engine_mult.search("intelligence")
res
# Out:
# BR(DPH): 100%|█████████████████████████████████████| 1/1 [00:00<00:00,  1.71q/s]
#   qid  docid                                              docno  rank  \
# 0   1    889  https://www.bibsonomy.org/bibtex/225cc15aa8abc...     0
# 1   1    745  https://www.bibsonomy.org/bibtex/205de7939eb62...     1
#
#       score         query
# 0  4.615414  intelligence
# 1  4.606457  intelligence

# %%
pickle.dump(df_ai_filtered, open("./juelich2_publicaions.pkl", "wb"))

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /home/barbara/anaconda3/lib/python3.8/site-packages (1.30.0)
# Requirement already satisfied: altair<6,>=4.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (7.0.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (10.0.1)
# Requirement already satisfied: protobuf<5,>=3.20 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (4.25.2)
# Requirement already satisfied: pyarrow>=6.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (3.1.41)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /home/barbara/anaconda3/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barbara/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: backports.zoneinfo in /home/barbara/anaconda3/lib/python3.8/site-packages (from tzlocal<6,>=1.1->streamlit) (0.2.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (6.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /home/barbara/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
ergebnis1 = requests.get(url)
daten1 = ergebnis1.json()

# %%
daten1
# Out:
# {'types': {'Bookmark': {'pluralLabel': 'Bookmarks'},
#   'Publication': {'pluralLabel': 'Publications'},
#   'GoldStandardPublication': {'pluralLabel': 'GoldStandardPublications'},
#   'GoldStandardBookmark': {'pluralLabel': 'GoldStandardBookmarks'},
#   'Tag': {'pluralLabel': 'Tags'},
#   'User': {'pluralLabel': 'Users'},
#   'Group': {'pluralLabel': 'Groups'},
#   'Sphere': {'pluralLabel': 'Spheres'}},
#  'properties': {'count': {'valueType': 'number'},
#   'date': {'valueType': 'date'},
#   'changeDate': {'valueType': 'date'},
#   'url': {'valueType': 'url'},
#   'id': {'valueType': 'url'},
#   'tags': {'valueType': 'item'},
#   'user': {'valueType': 'item'}},
#  'items': [{'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/e5557907b1206e81eb5d65bf5758fb5d/alberska',
#    'tags': ['inm',
#     'ethic',
#     'studies',
#     'medical_imaging',
#     'institute',
#     'internship',
#     'neurocience',
#     'cognitive_neurosciences',
#     'research'],
#    'intraHash': 'e5557907b1206e81eb5d65bf5758fb5d',
#    'label': 'Forschungszentrum Jülich - INM',
#    'user': 'alberska',
#    'description': 'Institut für Neurowissenschaften und Medizin - Jülich Forschungszentrum.',
#    'date': '2018-12-12 22:27:23',
#    'changeDate': '2018-12-12 22:29:52',
#    'count': 1,
#    'url': 'http://www.fz-juelich.de/inm/DE/Home/home_node.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f6ac83276c20b9aecaa6a6fa786cce40/torstenschuenemann',
#    'tags': ['Innovation', 'Lernwerkstatt', 'LW1'],
#    'intraHash': 'f6ac83276c20b9aecaa6a6fa786cce40',
#    'label': 'heise online - RWTH Aachen und Forschungszentrum Jülich kooperieren',
#    'user': 'torstenschuenemann',
#    'description': 'RWTH Aachen und Forschungszentrum Jülich kooperieren',
#    'date': '2007-08-06 18:02:08',
#    'changeDate': '2008-06-01 22:04:56',
#    'count': 1,
#    'url': 'http://www.heise.de/newsticker/meldung/93915/from/rss09'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/e8161c5dc17bb1c9376898c37756c1a8/schmidt2',
#    'tags': ['jülich',
#     'forschungszentrum',
#     'bottleneck',
#     'phenotyping',
#     'phänotypisierung'],
#    'intraHash': 'e8161c5dc17bb1c9376898c37756c1a8',
#    'label': 'Forschungszentrum Jülich - Forschung - Phänotypisierung',
#    'user': 'schmidt2',
#    'description': 'Phänotypisierung ist die quantitative Analyse pflanzlicher Strukturen und Funktionen. Die quantitative Analyse von strukturellen und funktionellen Eigenschaften ist der Schlüssel, mit dem Grundlagenwissen in die Praxis von Landwirtschaft, aber auch in die ökologische Forschung überführt wird. In der Grundlagenforschung ist die Phänotypisierung das bottle-neck für Erkenntnisgewinn in der funktionellen Genomforschung.',
#    'date': '2013-02-13 15:55:45',
#    'changeDate': '2013-02-13 15:55:45',
#    'count': 1,
#    'url': 'https://www.fz-juelich.de/ibg/ibg-2/DE/Forschung/Ph%C3%A4notypisierung/artikel.html?nn=548268'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/ce228a1fd03d4ca5b798187e650f9d55/schmidt2',
#    'tags': ['jülich', 'jppc', 'phenotyping'],
#    'intraHash': 'ce228a1fd03d4ca5b798187e650f9d55',
#    'label': 'JPPC: the Jülich Plant Phenotyping Centre at the Forschungszentrum Jülich ICG-3 - Phytosphere',
#    'user': 'schmidt2',
#    'description': '',
#    'date': '2011-09-22 13:45:30',
#    'changeDate': '2011-09-22 13:48:48',
#    'count': 1,
#    'url': 'http://www2.fz-juelich.de/icg/icg-3/jppc'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/0ac911d2dc1c1db4e66681f544205e13/schmidt2',
#    'tags': ['jülich', 'forschungszentrum', 'whitepaper', 'phenotyping'],
#    'intraHash': '0ac911d2dc1c1db4e66681f544205e13',
#    'label': 'Forschungszentrum Jülich - White Paper Phenotyping (2009)',
#    'user': 'schmidt2',
#    'description': '',
#    'date': '2013-02-13 15:56:06',
#    'changeDate': '2013-02-13 15:56:06',
#    'count': 1,
#    'url': 'https://www.fz-juelich.de/ibg/ibg-2/DE/_SharedDocs/Dokumente/2009%20White%20Paper%20Phenotyping/_node.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/8aef4d1d71e4d0cf89c6de848cc8d557/vitelot',
#    'tags': ['Chrome', 'stack', 'Bookmarks_Bar'],
#    'intraHash': '8aef4d1d71e4d0cf89c6de848cc8d557',
#    'label': 'Young Investigators Group Leader - Forschungszentrum Jülich | Academic Positions Europe',
#    'user': 'vitelot',
#    'description': '',
#    'date': '2017-08-14 13:30:39',
#    'changeDate': '2017-08-14 13:43:37',
#    'count': 1,
#    'url': 'http://academicpositions.eu/ad/forschungszentrum-julich/2015/young-investigators-group-leader/60012/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/dab6f0c6641226f2fa25f30dd284dedc/danilola',
#    'tags': ['bibliothek',
#     'schule',
#     'bibinalert',
#     'angebot',
#     'deutschlandliest',
#     'benutzer_in',
#     'öb',
#     'aktion'],
#    'intraHash': 'dab6f0c6641226f2fa25f30dd284dedc',
#    'label': 'AZ-Web.de - Schüler finden in Stadtbücherei Jülich ihren Platz',
#    'user': 'danilola',
#    'description': 'Jülich. Nach dem erfolgreichen Jahr 2008, in dem die Stadtbücherei Jülicher Leseratten zahlreiche aufregende Aktionen rund um Bücher und Literatur bot, hat ihr Leiter, Werner Wieczoreck, eine positive Bilanz gezogen.  Besonders die Aktion «Deutschland liest sei sehr gut angekommen.',
#    'date': '2009-01-27 07:37:39',
#    'changeDate': '2009-07-16 18:14:35',
#    'count': 1,
#    'url': 'http://www.az-web.de/lokales/juelich-detail-az/792817?_link=&skip=&_g=Schueler-finden-in-Stadtbuecherei-Juelich-ihren-Platz.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/d8287ab5eaafea553c4e0b0a4b952da9/flimm',
#    'tags': ['kinder'],
#    'intraHash': 'd8287ab5eaafea553c4e0b0a4b952da9',
#    'label': 'Brückenkopf-Park Jülich',
#    'user': 'flimm',
#    'description': '',
#    'date': '2010-04-06 13:05:11',
#    'changeDate': '2010-04-06 13:05:11',
#    'count': 1,
#    'url': 'http://www.brueckenkopf-park.de/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/524cd4378bf6be541d8a3835d42445b7/anabas',
#    'tags': ['web2.0', 'library2.0', 'del.icio.us', 'social_media'],
#    'intraHash': '524cd4378bf6be541d8a3835d42445b7',
#    'label': 'Delicious am FZ Jülich',
#    'user': 'anabas',
#    'description': '',
#    'date': '2010-08-30 13:43:48',
#    'changeDate': '2010-09-23 14:43:50',
#    'count': 1,
#    'url': 'http://www.fz-juelich.de/zb/datapool/general/tutorial_delicious_praesentation.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a477450f82d7967c9f8a73a9d57a8545/sjanzen',
#    'tags': ['materials'],
#    'intraHash': 'a477450f82d7967c9f8a73a9d57a8545',
#    'label': 'Projektträger Jülich Werkstofftechnologien',
#    'user': 'sjanzen',
#    'description': '',
#    'date': '2011-11-10 15:01:50',
#    'changeDate': '2011-11-11 08:48:54',
#    'count': 1,
#    'url': 'http://www.fz-juelich.de/ptj/werkstofftechnologien'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/922a7fe7d8f824f8d7ac292d6434ae5e/maier',
#    'tags': ['eLearning'],
#    'intraHash': '922a7fe7d8f824f8d7ac292d6434ae5e',
#    'label': 'GoInfo: Online-Tutorial FZ Jülich',
#    'user': 'maier',
#    'description': '',
#    'date': '2008-08-25 16:11:09',
#    'changeDate': '2008-08-25 16:11:10',
#    'count': 1,
#    'url': 'http://wwwzb.zb.kfa-juelich.de/goinfo/inhalt.htm'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/4e101d8db00d532b775529b4d8e4254c/robingarcia',
#    'tags': ['Weitere_Lesezeichen'],
#    'intraHash': '4e101d8db00d532b775529b4d8e4254c',
#    'label': 'Projektträger Jülich: Systemmedizin der Leber - LiSyM',
#    'user': 'robingarcia',
#    'description': '',
#    'date': '2017-03-17 10:35:12',
#    'changeDate': '2017-04-13 10:01:50',
#    'count': 1,
#    'url': 'https://www.ptj.de/lisym'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/980c4f1ebb929d9e3afb25a5cfbeada5/danilola',
#    'tags': ['kinder',
#     'leitung',
#     'bibliothek',
#     'schule',
#     'bibinalert',
#     'personal',
#     'angebot',
#     '2009-02',
#     'kooperation',
#     'leseförderung',
#     'öb',
#     'stadtbibliothek'],
#    'intraHash': '980c4f1ebb929d9e3afb25a5cfbeada5',
#    'label': 'Das JüLichT - Stadtteile: Stadtbücherei Jülich plant Lesecafé, Theatergruppe und School Corner',
#    'user': 'danilola',
#    'description': 'Von seiner besten Seite zeigt sich der neue Leiter der Jülicher Stadtbücherei Werner Wieczorek: Ein erfolgreiches erstes Jahr liegt hinter ihm. Auch, wenn der Bibliothekar auf die gute Arbeit seiner Vorgängerin Christa Bartels bauen konnte, stellt er seine eigenen Weichen.',
#    'date': '2009-02-15 10:01:25',
#    'changeDate': '2009-07-16 18:14:24',
#    'count': 1,
#    'url': 'http://www.das-juelicht.de/nachrichten/artikel/8400.php'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9220d5e71e2f2cceed6b0bffc5087917/a_olympia',
#    'tags': ['aachen', 'j'],
#    'intraHash': '9220d5e71e2f2cceed6b0bffc5087917',
#    'label': 'heise online - RWTH Aachen und Forschungszentrum Jülich kooperieren',
#    'user': 'a_olympia',
#    'description': '',
#    'date': '2007-08-06 21:53:41',
#    'changeDate': '2007-08-18 13:01:15',
#    'count': 1,
#    'url': 'http://www.heise.de/newsticker/meldung/93915'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/dc6fc99e2644a226b740c4b154b7f309/schmidt2',
#    'tags': ['overview', 'technologies', 'jppc'],
#    'intraHash': 'dc6fc99e2644a226b740c4b154b7f309',
#    'label': 'ICG-3 JPPC-Jülich Plant Phenotyping Centre: technologies for plant phenotyping',
#    'user': 'schmidt2',
#    'description': '',
#    'date': '2011-09-22 13:47:04',
#    'changeDate': '2011-09-22 13:48:40',
#    'count': 1,
#    'url': 'http://www2.fz-juelich.de/icg/icg-3/jppc/methods'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f4e405abc3e878a4b48f83f1b70dc947/schmidt2',
#    'tags': ['2009', 'slides', 'workshop', 'epso', 'jppc'],
#    'intraHash': 'f4e405abc3e878a4b48f83f1b70dc947',
#    'label': 'Jülich Plant Phenotyping Centre - JPPC - EPSO Workshop 2009 on Plant Phenotyping',
#    'user': 'schmidt2',
#    'description': '',
#    'date': '2011-09-22 13:53:29',
#    'changeDate': '2011-09-22 13:53:29',
#    'count': 1,
#    'url': 'http://www.plantphenomics.com/phenotyping2009/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f2a9dd3e4de40be3fec437bcc963547b/swatschi',
#    'tags': ['lv_wisskomm', 'conference', 'theory'],
#    'intraHash': 'f2a9dd3e4de40be3fec437bcc963547b',
#    'label': 'JUWEL - Volltextserver des Forschungszentrums Jülich: Item 2128/2893',
#    'user': 'swatschi',
#    'description': '',
#    'date': '2008-03-13 17:10:03',
#    'changeDate': '2008-03-13 17:10:03',
#    'count': 2,
#    'url': 'http://juwel.fz-juelich.de:8080/dspace/handle/2128/2893'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/c2ca92adaf56a3e73eb31a138af7cd53/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'c2ca92adaf56a3e73eb31a138af7cd53',
#    'label': 'Home Page of Bin A. Wang and Bin Wang',
#    'user': 'dblp',
#    'description': 'homepages/193/8273,\nBin A. Wang and Bin Wang, Home Page, https://www.wikidata.org/entity/Q87293810, Research Centre Jülich, Institute of Neuroscience and Medicine, Jülich, Germany',
#    'date': '2020-09-09 15:20:09',
#    'changeDate': '2020-09-09 15:20:09',
#    'count': 1,
#    'url': 'https://www.wikidata.org/entity/Q87293810'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f3a456f8900d2a3976fdf0bc73c36b8c/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'f3a456f8900d2a3976fdf0bc73c36b8c',
#    'label': 'Home Page of Tao Liu',
#    'user': 'dblp',
#    'description': 'homepages/43/656-15,\nTao Liu, Home Page, https://www.researchgate.net/profile/Tao_Liu142, Forschungszentrum Jülich, Germany',
#    'date': '2020-05-21 11:59:32',
#    'changeDate': '2020-05-21 11:59:32',
#    'count': 1,
#    'url': 'https://www.researchgate.net/profile/Tao_Liu142'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/258e8e47d605fa39f4aa11bcd4aa53ce/dblp',
#    'tags': ['dblp'],
#    'intraHash': '258e8e47d605fa39f4aa11bcd4aa53ce',
#    'label': 'Home Page of Stefanie Haustein',
#    'user': 'dblp',
#    'description': 'homepages/03/9465,\nStefanie Haustein, Home Page, https://id.loc.gov/authorities/names/n2012030867, Forschungszentrum Jülich',
#    'date': '2020-09-19 12:14:33',
#    'changeDate': '2020-09-19 12:14:33',
#    'count': 1,
#    'url': 'https://id.loc.gov/authorities/names/n2012030867'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/eca54bd2d962d4083b375fda5817fccf/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'eca54bd2d962d4083b375fda5817fccf',
#    'label': 'Home Page of Markus Diesmann',
#    'user': 'dblp',
#    'description': 'homepages/95/5761,\nMarkus Diesmann, Home Page, https://www.researcherid.com/rid/H-3722-2013, Forschungszentrum Jülich, Germany',
#    'date': '2019-01-11 12:22:58',
#    'changeDate': '2019-01-11 12:22:58',
#    'count': 1,
#    'url': 'https://www.researcherid.com/rid/H-3722-2013'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/54724b5ef62f14310e8de375534bf047/dblp',
#    'tags': ['dblp'],
#    'intraHash': '54724b5ef62f14310e8de375534bf047',
#    'label': 'Home Page of Felix Fischer',
#    'user': 'dblp',
#    'description': 'homepages/f/FelixFischer,\nFelix Fischer, Home Page, http://www.medizinischeinformatik.fh-aachen.de/mitarbeiter/fischer.html, FH Aachen, Jülich, Germany',
#    'date': '2020-07-31 11:53:58',
#    'changeDate': '2020-07-31 11:53:58',
#    'count': 1,
#    'url': 'http://www.medizinischeinformatik.fh-aachen.de/mitarbeiter/fischer.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/1ca7444f8be0af3a515a07906ab216e7/dblp',
#    'tags': ['dblp'],
#    'intraHash': '1ca7444f8be0af3a515a07906ab216e7',
#    'label': 'Home Page of Edoardo Di Napoli',
#    'user': 'dblp',
#    'description': 'homepages/10/7481,\nEdoardo Di Napoli, Home Page, https://www.mendeley.com/profiles/edoardo-di-napoli//, Forschungszentrum Jülich, Germany',
#    'date': '2020-09-19 12:06:58',
#    'changeDate': '2020-09-19 12:06:58',
#    'count': 1,
#    'url': 'https://www.mendeley.com/profiles/edoardo-di-napoli//'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/fe3fc71c28b5ebeb8dce4c1019c47e44/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'fe3fc71c28b5ebeb8dce4c1019c47e44',
#    'label': 'Home Page of Martin G. Schultz',
#    'user': 'dblp',
#    'description': 'homepages/132/0161,\nMartin G. Schultz, Home Page, https://www.researcherid.com/rid/I-9512-2012, Forschungszentrum Jülich GmbH, Germany',
#    'date': '2019-01-11 13:09:23',
#    'changeDate': '2019-01-11 13:09:23',
#    'count': 1,
#    'url': 'https://www.researcherid.com/rid/I-9512-2012'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a5ab39edc55614340c35d1c6608d6ff0/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'a5ab39edc55614340c35d1c6608d6ff0',
#    'label': 'Home Page of Lukas Arnold',
#    'user': 'dblp',
#    'description': 'homepages/49/1004,\nLukas Arnold, Home Page, https://orcid.org/0000-0002-5939-8995, Jülich Supercomputing Centre, Germany',
#    'date': '2017-12-08 02:29:41',
#    'changeDate': '2017-12-08 02:29:41',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0002-5939-8995'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/67ab87e8af4f4d68bbd9e235ea055c1d/dblp',
#    'tags': ['dblp'],
#    'intraHash': '67ab87e8af4f4d68bbd9e235ea055c1d',
#    'label': 'Home Page of Dirk Pleiter',
#    'user': 'dblp',
#    'description': 'homepages/70/3241,\nDirk Pleiter, Home Page, https://orcid.org/0000-0001-7296-7817, Jülich Supercomputing Centre, Germany',
#    'date': '2019-10-03 11:39:57',
#    'changeDate': '2019-10-03 11:39:57',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0001-7296-7817'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/4da3bf4844498b9a2cf830bc5665fbe5/dblp',
#    'tags': ['dblp'],
#    'intraHash': '4da3bf4844498b9a2cf830bc5665fbe5',
#    'label': 'Home Page of Thomas Meyer',
#    'user': 'dblp',
#    'description': 'homepages/m/ThomasMeyer5,\nThomas Meyer, Home Page, https://orcid.org/0000-0002-6582-1278, Forschungszentrum Jülich, Institute of Bio- and Geosciences, Germany',
#    'date': '2018-12-20 11:39:54',
#    'changeDate': '2018-12-20 11:39:54',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0002-6582-1278'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/1d18e6e369fc5eb4b76aa2300778b062/dblp',
#    'tags': ['dblp'],
#    'intraHash': '1d18e6e369fc5eb4b76aa2300778b062',
#    'label': 'Home Page of Christian Wagner',
#    'user': 'dblp',
#    'description': 'homepages/01/2903-7,\nChristian Wagner, Home Page, https://d-nb.info/gnd/1166883922, FZ Jülich, Peter Grünberg Institute (PGI), Germany',
#    'date': '2020-05-20 12:01:23',
#    'changeDate': '2020-05-20 12:01:23',
#    'count': 1,
#    'url': 'https://d-nb.info/gnd/1166883922'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/739dacb2bccf76c8b736cec405918a9e/dblp',
#    'tags': ['dblp'],
#    'intraHash': '739dacb2bccf76c8b736cec405918a9e',
#    'label': 'Home Page of Alexander Grünberger and Alexander Manuel Grünberger',
#    'user': 'dblp',
#    'description': 'homepages/136/0886,\nAlexander Grünberger and Alexander Manuel Grünberger, Home Page, https://gepris.dfg.de/gepris/person/420450975, Jülich Research Centre, Germany',
#    'date': '2020-12-01 11:40:07',
#    'changeDate': '2020-12-01 11:40:07',
#    'count': 1,
#    'url': 'https://gepris.dfg.de/gepris/person/420450975'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a21d1d0d2b7498fbbb10a02e0b4e3e22/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'a21d1d0d2b7498fbbb10a02e0b4e3e22',
#    'label': 'Home Page of Simon B. Eickhoff',
#    'user': 'dblp',
#    'description': 'homepages/03/7228,\nSimon B. Eickhoff, Home Page, https://d-nb.info/gnd/132476576, Research Centre Jülich, Institute of Neuroscience and Medicine, Germany',
#    'date': '2019-01-11 12:30:00',
#    'changeDate': '2019-01-11 12:30:00',
#    'count': 1,
#    'url': 'https://d-nb.info/gnd/132476576'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/c889ca8ca097b5e912f1c67d59deecf0/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'c889ca8ca097b5e912f1c67d59deecf0',
#    'label': 'Home Page of Marc-André Hermanns',
#    'user': 'dblp',
#    'description': 'homepages/84/1090,\nMarc-André Hermanns, Home Page, https://www.linkedin.com/in/marcandrehermanns/, Research Centre Jülich, Central Institute for Applied Mathematics, Germany',
#    'date': '2020-11-28 11:40:09',
#    'changeDate': '2020-11-28 11:40:09',
#    'count': 1,
#    'url': 'https://www.linkedin.com/in/marcandrehermanns/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/efe69d268c7b2a0896e0072c297c8145/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'efe69d268c7b2a0896e0072c297c8145',
#    'label': 'Home Page of Qi Tang',
#    'user': 'dblp',
#    'description': 'homepages/40/4498-4,\nQi Tang, Home Page, https://orcid.org/0000-0002-2109-7935, Forschungszentrum Jülich, Institute of Bio- and Geosciences, Germany',
#    'date': '2018-01-31 11:45:28',
#    'changeDate': '2018-01-31 11:45:28',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0002-2109-7935'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/e68bd6093727e93489f9c5290ba91ff7/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'e68bd6093727e93489f9c5290ba91ff7',
#    'label': 'Home Page of Ahmed Shiraz Memon and A. Shiraz Memon',
#    'user': 'dblp',
#    'description': 'homepages/79/3774,\nAhmed Shiraz Memon and A. Shiraz Memon, Home Page, https://orcid.org/0000-0001-6500-8968, Jülich Supercomputing Centre, Germany',
#    'date': '2019-09-27 11:42:10',
#    'changeDate': '2019-09-27 11:42:10',
#    'count': 1,
#    'url': 'https://orcid.org/0000-0001-6500-8968'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/414b98caf7af02698dd5750d4ae4c524/dblp',
#    'tags': ['dblp'],
#    'intraHash': '414b98caf7af02698dd5750d4ae4c524',
#    'label': 'Home Page of Stephan Graf',
#    'user': 'dblp',
#    'description': 'homepages/36/2912-2,\nStephan Graf, Home Page, https://www.fz-juelich.de/SharedDocs/Personen/IAS/JSC/EN/staff/graf_st.html, Forschungszentrum Jülich, Germany',
#    'date': '2016-12-03 11:34:45',
#    'changeDate': '2016-12-03 11:34:45',
#    'count': 1,
#    'url': 'https://www.fz-juelich.de/SharedDocs/Personen/IAS/JSC/EN/staff/graf_st.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/3e60dcc512fc92b587799bd39ee70653/dblp',
#    'tags': ['dblp'],
#    'intraHash': '3e60dcc512fc92b587799bd39ee70653',
#    'label': 'Home Page of Piotr M. Kowalski',
#    'user': 'dblp',
#    'description': 'homepages/146/8462,\nPiotr M. Kowalski, Home Page, https://www.researcherid.com/rid/L-7411-2013, Forschungszentrum Jülich, Institute of Energy & Climate Research, Germany',
#    'date': '2020-05-20 11:55:31',
#    'changeDate': '2020-05-20 11:55:31',
#    'count': 1,
#    'url': 'https://www.researcherid.com/rid/L-7411-2013'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/2083ce92cb0db7037f5df57d2767c12e/dblp',
#    'tags': ['dblp'],
#    'intraHash': '2083ce92cb0db7037f5df57d2767c12e',
#    'label': 'Home Page of Andreas Bauer',
#    'user': 'dblp',
#    'description': 'homepages/116/1833-5,\nAndreas Bauer, Home Page, https://www.scopus.com/authid/detail.uri?authorId=56673523600, Research Centre Jülich, Institute of Neuroscience and Medicine, Germany',
#    'date': '2019-01-11 11:42:10',
#    'changeDate': '2019-01-11 11:42:10',
#    'count': 1,
#    'url': 'https://www.scopus.com/authid/detail.uri?authorId=56673523600'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/0b5472ce59e2f9a5e6919c0a0a8899a1/dblp',
#    'tags': ['dblp'],
#    'intraHash': '0b5472ce59e2f9a5e6919c0a0a8899a1',
#    'label': 'Home Page of Frank Boers and Franks Boers',
#    'user': 'dblp',
#    'description': 'homepages/37/11401,\nFrank Boers and Franks Boers, Home Page, http://www.fz-juelich.de/SharedDocs/Kontaktdaten/Mitarbeiter/B/Boers_f_boers_fz_juelich_de.html?nn=573170, Research Centre Jülich, Institute of Neuroscience and Medicine',
#    'date': '2017-01-07 11:39:11',
#    'changeDate': '2017-01-07 11:39:11',
#    'count': 1,
#    'url': 'http://www.fz-juelich.de/SharedDocs/Kontaktdaten/Mitarbeiter/B/Boers_f_boers_fz_juelich_de.html?nn=573170'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/7774ab21ecab00f03a8346e42b5b2bf0/calidius',
#    'tags': ['Zürich', 'Hotel'],
#    'intraHash': '7774ab21ecab00f03a8346e42b5b2bf0',
#    'label': 'Hotel Rex',
#    'user': 'calidius',
#    'description': 'Hotels in Zürich: Hotel Rex Zürich / Arte in Spreitenbach / Sonnental in Dübendorf',
#    'date': '2006-10-31 09:31:27',
#    'changeDate': '2013-03-02 20:19:46',
#    'count': 1,
#    'url': 'http://www.zuerich-hotels.ch/hotel_rex/hotel.php'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/afaa7dabf30f0d8b375f2f18fb4a0535/novaesium',
#    'tags': ['Museum', 'Zülpich', 'Thermen'],
#    'intraHash': 'afaa7dabf30f0d8b375f2f18fb4a0535',
#    'label': 'Römerthermen Zülpich',
#    'user': 'novaesium',
#    'description': 'Internetseiten der Römerthermen Zülpich - Museum der Badekultur.',
#    'date': '2009-05-14 23:44:11',
#    'changeDate': '2009-05-14 23:47:01',
#    'count': 1,
#    'url': 'http://www.zuelpich.de/index.php?option=com_content&view=article&id=437&Itemid=100068'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9b7b04c2547d0d5b6df63b0e4de9382f/ksteitz',
#    'tags': ['docendo', 'Zürich', 'ETH', 'KOM', 'WBT', 'elc', 'Tittel', 'Blog'],
#    'intraHash': '9b7b04c2547d0d5b6df63b0e4de9382f',
#    'label': 'docendo blog',
#    'user': 'ksteitz',
#    'description': 'Blog der ETH Zürich zu docendo',
#    'date': '2010-05-10 09:58:43',
#    'changeDate': '2011-01-31 15:25:50',
#    'count': 1,
#    'url': 'http://blogs.ethz.ch/docendo/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a4868b938c2f172eaac21c4702bca7e4/mauszfabrick',
#    'tags': ['ch', 'literatur', 'uschtrinneu', 'zürich'],
#    'intraHash': 'a4868b938c2f172eaac21c4702bca7e4',
#    'label': 'index wort und wirkung',
#    'user': 'mauszfabrick',
#    'description': 'ulrike ulrichs literatur/kulturgruppe, die vergeben auch stipendien in zürich',
#    'date': '2011-09-29 12:58:28',
#    'changeDate': '2011-09-29 12:58:28',
#    'count': 1,
#    'url': 'http://www.wortundwirkung.ch/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/6451c043c7bded740ef55b6ad44b6ff3/bibliothecaire',
#    'tags': ['illich'],
#    'intraHash': '6451c043c7bded740ef55b6ad44b6ff3',
#    'label': 'Alain Giffard: Lecture, mémoire, bibliothèque, lecture numérique',
#    'user': 'bibliothecaire',
#    'description': ' Une interprétation duDidascalicona été proposé récemment par Ivan Illich : «Du lisible au visible. Sur l’Art de lire de Hugues de Saint Victor ».   ',
#    'date': '2007-11-18 10:36:02',
#    'changeDate': '2007-11-29 18:19:12',
#    'count': 1,
#    'url': 'http://alaingiffard.blogs.com/culture/lecture_mmoire_bibliothque_lecture_numrique/page/2'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/c1b9cb7aa3cefb37e2c0dd1c47982d89/torstenschuenemann',
#    'tags': ['Hamburg/Lokal', 'Regionalfoerderung', 'Uni'],
#    'intraHash': 'c1b9cb7aa3cefb37e2c0dd1c47982d89',
#    'label': 'heise online - Deutsches Klimarechenzentrum investiert in neuen Supercomputer',
#    'user': 'torstenschuenemann',
#    'description': 'Um die Prognosen zukünftiger Klimaänderungen wesentlich genauer zu berechnen, investiert das Deutsche Klimarechenzentrum zu seinem 20-jährigen Bestehen in einen neuen Supercomputer. Er arbeitet mit Power6-Prozessoren von IBM und soll eine Spitzenleistung von 140 TFlop/s erreichen. Damit würde er sich in der Top500-Liste der Supercomputer auf Platz drei gleich hinter dem vom Forschungszentrum Jülich betriebenen JUGENE einreihen und zu den schnellsten zivil genutzten Supercomputern der Welt zählen.',
#    'date': '2007-12-16 18:14:08',
#    'changeDate': '2008-06-01 22:12:51',
#    'count': 1,
#    'url': 'http://www.heise.de/newsticker/meldung/100658/from/rss09'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9217a09989add6aeb29c1123b82e90c5/bibliothecaire',
#    'tags': ['illich'],
#    'intraHash': '9217a09989add6aeb29c1123b82e90c5',
#    'label': 'LISTSERV 15.0 - SHARP-L Archives',
#    'user': 'bibliothecaire',
#    'description': " My interest in the subject of books and print culture has beenguided largely by reading Ivan Illich, whose thinking I have beengrappling with for several years now. It was through him that Idiscovered Ong's Orality and Literacy, began to think about the",
#    'date': '2007-11-21 09:54:26',
#    'changeDate': '2007-11-29 18:19:10',
#    'count': 1,
#    'url': 'https://listserv.indiana.edu/cgi-bin/wa-iub.exe?A2=ind9408&L=SHARP-L&P=R2019'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/2cb76dc0ec5e842ce632174221b33bbb/novaesium',
#    'tags': ['Rheinland', 'Museum', 'Zülpich', 'Thermen', 'Landschaftsverband'],
#    'intraHash': '2cb76dc0ec5e842ce632174221b33bbb',
#    'label': 'Römerthermen Zülpich: LVR übernimmt Betriebsführung (Archäologie Online)',
#    'user': 'novaesium',
#    'description': 'Der Landschaftsverband Rheinland (LVR) wird zum 1. April die Betriebsführung in den Römerthermen Zülpich übernehmen. Im Museum unterzeichneten LVR-Direktor Harry K. Voigtsberger, der Zülpicher Bürgermeister Albert Bergmann sowie der Geschäftsführer des Fördervereins Zülpicher Geschichte und Kulturdenkmäler e.V., Helmut Limper nun den Kooperationsvertrag.',
#    'date': '2009-05-14 23:46:22',
#    'changeDate': '2009-05-14 23:46:22',
#    'count': 1,
#    'url': 'http://www.archaeologie-online.de/magazin/nachrichten/view/roemerthermen_zuelpich_lvr_uebernimmt_betriebsfuehrung/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/0f40018322eefae382a435db25b5f141/bibliothecaire',
#    'tags': ['content_management', 'illich'],
#    'intraHash': '0f40018322eefae382a435db25b5f141',
#    'label': 'LISTSERV 15.0 - SHARP-L Archives',
#    'user': 'bibliothecaire',
#    'description': ' "Media theorist Ivan Illich articulated an ideal\'conviviality\': the notion that it should be as easy to author in a mediumas it is to experience works created in it. I think we should keep thisideal at the front of our minds as we build the next generat',
#    'date': '2007-11-21 09:56:36',
#    'changeDate': '2007-11-29 18:19:10',
#    'count': 1,
#    'url': 'https://listserv.indiana.edu/cgi-bin/wa-iub.exe?A2=ind9312&L=SHARP-L&P=R1064'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f360dd91baa82aa4104526c87a0a0b76/danilola',
#    'tags': ['pdf',
#     'disziplin',
#     'transdisziplinarität',
#     'volltext',
#     'bericht',
#     'zürich',
#     'studium'],
#    'intraHash': 'f360dd91baa82aa4104526c87a0a0b76',
#    'label': 'tagensanzeiger zürich: Neuer Master in Transdiszipiinarität',
#    'user': 'danilola',
#    'description': 'Zürich. - Als sich vor einem guten Jahr die Hochschule für Gestaltung und Kunst und die Musikhochschule zur Zürcher Hochschule der Künste (ZHdK) zusammenschlossen, war viel von Transdisziplinarität die Rede, die man mit dieser Fusion fördern wolle. Was damit gemeint war, blieb einigermassen wolkig, und die Vermutung, dass das Schlagwort eines bleiben würde, lag nahe. Sie war falsch. Im nächsten Semester startet nun ein Master of Arts in Transdisziplinarität.',
#    'date': '2008-11-18 19:12:09',
#    'changeDate': '2009-07-16 18:15:24',
#    'count': 1,
#    'url': 'http://trans.zhdk.ch/fileadmin/data/trans/presse/ta_081027.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a14fe889223e4381e47a865899565977/kfutter',
#    'tags': ['Zürich', 'Lehrplan21'],
#    'intraHash': 'a14fe889223e4381e47a865899565977',
#    'label': '159 Lehrplan 21 - Bildungsdirektion - Internet Kanton Zürich',
#    'user': 'kfutter',
#    'description': 'er Bildungsrat des Kantons Zürich hat die Vernehmlassung zu den Grundlagen für den Lehrplan 21 der deutsch- und mehrsprachigen Kantone verabschiedet. Er unterstützt das Ziel eines gemeinsamen Lehrplans und befürwortet die in den Grundlagen vorgesehenen Fachbereiche. Hingegen erachtet er die Grundlagen noch als ungenügend für die Entwicklung eines direkt einführbaren Lehrplans.  Annotated link http://www.diigo.com/bookmark/http%3A%2F%2Fwww.bi.zh.ch%2Finternet%2Fbi%2Fde%2Faktuell%2Fnews09%2F159.html',
#    'date': '2009-07-03 13:29:03',
#    'changeDate': '2009-08-30 12:38:08',
#    'count': 1,
#    'url': 'http://www.bi.zh.ch/internet/bi/de/aktuell/news09/159.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/d4649ca9e301b8d744ee08d7cf805374/meneteqel',
#    'tags': ['army',
#     'warfare',
#     'terrorism',
#     'eth',
#     'nato',
#     'stay-behind',
#     'zürich',
#     'gladio'],
#    'intraHash': 'd4649ca9e301b8d744ee08d7cf805374',
#    'label': 'PHP – Secret Warfare: Operation Gladio and NATO’s Stay-Behind Armies',
#    'user': 'meneteqel',
#    'description': 'Das Parallel History Project on Cooperative Security (PHP, das ehemalige Parallel History Project on NATO and the Warsaw Pact), bietet eine neue wissenschaftliche Perspektive für die internationale Zeitgeschichte durch das Sammeln, die Publikation und Interpretation von ehemals geheimen Regierungsdokumenten. Das PHP wird vom Center for Security Studies (CSS) an der Eidgenössischen Technischen Hochschule (ETH Zürich) betrieben und ergänzt die Dienstleistungen des International Relations and Security Network (ISN).',
#    'date': '2013-02-17 18:55:04',
#    'changeDate': '2013-02-17 18:55:04',
#    'count': 1,
#    'url': 'http://www.php.isn.ethz.ch/collections/colltopic.cfm?lng=en&id=15301'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/df1cfc087e844a8edbfd07bd18e479c3/brenz',
#    'tags': ['pers', 'fnd.lfm'],
#    'intraHash': 'df1cfc087e844a8edbfd07bd18e479c3',
#    'label': 'Robert F. Stärk',
#    'user': 'brenz',
#    'description': 'ETH Zürich',
#    'date': '2006-07-25 16:45:59',
#    'changeDate': '2006-07-25 16:45:59',
#    'count': 1,
#    'url': 'http://www.inf.ethz.ch/personal/staerk/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/762de8578f73ff20ff68772ce5df8c23/brenz',
#    'tags': ['pers', 'swt'],
#    'intraHash': '762de8578f73ff20ff68772ce5df8c23',
#    'label': 'Martin Glinz',
#    'user': 'brenz',
#    'description': 'Uni Zürich',
#    'date': '2008-01-29 13:42:47',
#    'changeDate': '2008-01-29 13:42:47',
#    'count': 2,
#    'url': 'http://www.ifi.uzh.ch/rerg/people/glinz/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/7000f90d8cc07b73693486ba6e33aec9/filologanoga',
#    'tags': ['hrvlat-internet', 'dominis'],
#    'intraHash': '7000f90d8cc07b73693486ba6e33aec9',
#    'label': 'De radiis visus et lucis in vi... (Venetiis, 1611)',
#    'user': 'filologanoga',
#    'description': 'ETH-Bibliothek Zürich',
#    'date': '2010-04-26 10:27:00',
#    'changeDate': '2010-04-26 10:27:00',
#    'count': 1,
#    'url': 'http://www.e-rara.ch/zut/content/titleinfo/272855'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/8e5a340619f01530efe723028d67f192/filologanoga',
#    'tags': ['didacusPyrrhus', 'hrvlat-internet', 'didakPir'],
#    'intraHash': '8e5a340619f01530efe723028d67f192',
#    'label': '129 - Didaci Pyrrhi Lusitani carmen. - Page view - e-rara',
#    'user': 'filologanoga',
#    'description': 'ETH-Bibliothek Zürich (NEBIS); ;',
#    'date': '2012-04-26 21:30:39',
#    'changeDate': '2012-04-26 21:30:39',
#    'count': 1,
#    'url': 'http://www.e-rara.ch/zut/content/pageview/1107970'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/aaa8349c03990a030ef6ef655391ad7d/voss',
#    'tags': ['digitalscholarship'],
#    'intraHash': 'aaa8349c03990a030ef6ef655391ad7d',
#    'label': 'Digital Humanities Cooperation',
#    'user': 'voss',
#    'description': 'Darmstadt, Konstanz, ETH Zürich',
#    'date': '2019-05-10 15:11:09',
#    'changeDate': '2019-05-10 15:11:09',
#    'count': 1,
#    'url': 'https://www.digitalhumanitiescooperation.de/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/4ffb820f7d5042c67f564f2a1336a923/beat07',
#    'tags': ['bibliothek', 'schule'],
#    'intraHash': '4ffb820f7d5042c67f564f2a1336a923',
#    'label': 'Bischu - Bibliothek und Schule',
#    'user': 'beat07',
#    'description': 'Bildungsdirektion Kanton Zürich',
#    'date': '2018-06-18 10:44:49',
#    'changeDate': '2018-06-18 10:44:49',
#    'count': 2,
#    'url': 'http://www.bischu.zh.ch/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a928619e74050dc0dc128349c844d2f9/kooptech',
#    'tags': ['Reputation', 'Sozialkapital'],
#    'intraHash': 'a928619e74050dc0dc128349c844d2f9',
#    'label': 'Vortrag zu Sozialkapital',
#    'user': 'kooptech',
#    'description': 'von Andreas Diekman, ETH Zürich',
#    'date': '2007-10-18 10:21:10',
#    'changeDate': '2008-02-26 14:51:20',
#    'count': 1,
#    'url': 'http://www.socio.ethz.ch/modsim/tagungen/zuerich04/Andreas_Diekmann.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/ae2ce2334afac039446a3199c891b82e/juku',
#    'tags': ['maarb', '2d', 'generalization', 'quality', 'carthographic'],
#    'intraHash': 'ae2ce2334afac039446a3199c891b82e',
#    'label': '28 - Measures for the generalization of polygonal maps with categorical data',
#    'user': 'juku',
#    'description': 'Beat Peter, Zürich, 2001',
#    'date': '2010-11-01 10:08:07',
#    'changeDate': '2012-02-07 23:05:21',
#    'count': 1,
#    'url': 'http://www.geo.unizh.ch/ICA/docs/beijing2001/papers/Peter_v2.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/506eab3bc5b585df9ef2bc9e297eb70c/dblp',
#    'tags': ['dblp'],
#    'intraHash': '506eab3bc5b585df9ef2bc9e297eb70c',
#    'label': 'Home Page of István Erlich',
#    'user': 'dblp',
#    'description': 'homepages/21/11538,\nIstván Erlich, Home Page, http://www.uni-due.de/mvmo/erlich, University of Duisburg-Essen, Germany',
#    'date': '2016-02-10 11:57:08',
#    'changeDate': '2016-02-10 11:57:08',
#    'count': 1,
#    'url': 'http://www.uni-due.de/mvmo/erlich'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/f0d0014497ed28986c3d4296484fba72/kfutter',
#    'tags': ['Dossier',
#     'Fachhochschule',
#     'Information',
#     'eLearning',
#     'Hochschuldidaktik'],
#    'intraHash': 'f0d0014497ed28986c3d4296484fba72',
#    'label': 'Dossier - Magazin - CSPC e-Learning - ZFH Zürcher Fachhochschule',
#    'user': 'kfutter',
#    'description': 'Dossierreihe der Fachhochschulen Zürich ZFH',
#    'date': '2009-02-28 09:25:07',
#    'changeDate': '2009-08-30 12:38:08',
#    'count': 1,
#    'url': 'http://www.elearning.zfh.ch/magazin/dossier/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/1efce5d82cc6f5de1020d40f79e3b8de/toennies',
#    'tags': ['PUMA'],
#    'intraHash': '1efce5d82cc6f5de1020d40f79e3b8de',
#    'label': 'Swistry',
#    'user': 'toennies',
#    'description': 'P2P Stremaing Solution der ETH Zürich',
#    'date': '2007-05-07 15:15:40',
#    'changeDate': '2007-05-07 15:15:40',
#    'count': 1,
#    'url': 'http://dcg.ethz.ch/projects/swistry/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/cfaec737ada1220a01b336dc49e30e7d/kfutter',
#    'tags': ['Lernziele', 'Unterricht', 'Lernzielgenerator'],
#    'intraHash': 'cfaec737ada1220a01b336dc49e30e7d',
#    'label': 'RadioJames Objectives Builder',
#    'user': 'kfutter',
#    'description': 'Lernzielgenerator entwickelt vom ELC UZH Zürich',
#    'date': '2008-12-12 17:46:06',
#    'changeDate': '2009-08-30 12:38:08',
#    'count': 1,
#    'url': 'http://www.radiojames.com/ObjectivesBuilder/German/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/28e164841f5fa2ed549a9e1ea5f85067/gender_h2stendal',
#    'tags': ['publikation', 'literatur', 'mentoring', 'peer-mentoring'],
#    'intraHash': '28e164841f5fa2ed549a9e1ea5f85067',
#    'label': 'UZH - Mentoring - Literatur',
#    'user': 'gender_h2stendal',
#    'description': 'Publikationen zum  Peer-Mentoring Universität Zürich ',
#    'date': '2010-01-26 11:05:17',
#    'changeDate': '2010-01-26 11:05:17',
#    'count': 1,
#    'url': 'http://www.mentoring.uzh.ch/literatur.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/24d8559616c7a53727003ff9641e2372/mdrechsler',
#    'tags': [],
#    'intraHash': '24d8559616c7a53727003ff9641e2372',
#    'label': 'Les Binbins - Accueil -',
#    'user': 'mdrechsler',
#    'description': 'des exercices sous JClic Syllabes, lecture, orthographe (tags: motscroisés logiciels libre jclic cycle2 cycle1 combinatoire)',
#    'date': '2008-08-02 19:04:23',
#    'changeDate': '2008-08-02 19:04:23',
#    'count': 1,
#    'url': 'http://www.lesbinbins.com'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/24cdab155ab204d1ac6d56f7d27407cc/dblp',
#    'tags': ['dblp'],
#    'intraHash': '24cdab155ab204d1ac6d56f7d27407cc',
#    'label': 'Home Page of Jim Reich and James Reich',
#    'user': 'dblp',
#    'description': 'homepages/p/JReich,\nJim Reich and James Reich, Home Page, http://www2.parc.com/spl/members/jreich/, Palo Alto Research Center Incorporated, PARC, California, USA',
#    'date': '2016-03-04 12:34:09',
#    'changeDate': '2016-03-04 12:34:09',
#    'count': 1,
#    'url': 'http://www2.parc.com/spl/members/jreich/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/6c20bf24b31ded06b31a3a76611732a1/julianausserhofer',
#    'tags': ['art', 'hom', 'switzerland', 'media-art', 'media'],
#    'intraHash': '6c20bf24b31ded06b31a3a76611732a1',
#    'label': 'Mediengruppe Bitnik',
#    'user': 'julianausserhofer',
#    'description': 'scheizer mediengruppe, aus zürich, sehr cool gestaltete homepage',
#    'date': '2006-09-24 22:15:06',
#    'changeDate': '2008-04-16 18:59:42',
#    'count': 1,
#    'url': 'http://www.bitnik.org/en/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/a6602fe5bef2e1c06176959740c8687b/walterra',
#    'tags': ['e-learning', 'via:hannes'],
#    'intraHash': 'a6602fe5bef2e1c06176959740c8687b',
#    'label': 'NZZ Online: Vom E-Learning zum «Blended Learning»',
#    'user': 'walterra',
#    'description': 'Uni Zürich leistet mit Software-Eigenentwicklung Pionierarbeit',
#    'date': '2007-03-11 11:49:18',
#    'changeDate': '2007-09-04 13:19:14',
#    'count': 1,
#    'url': 'http://www.nzz.ch/2007/03/09/em/articleEZGNX.print.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/34f3872335f4a9cdfac26bd74b1b98d1/steffi.braeuning',
#    'tags': ['bibliothek', 'naturwissenschaften', 'recherche'],
#    'intraHash': '34f3872335f4a9cdfac26bd74b1b98d1',
#    'label': 'Informationszentrum Chemie Biologie Pharmazie',
#    'user': 'steffi.braeuning',
#    'description': 'Informationszentrum Chemie Biologie Pharmazie der ETH Zürich.',
#    'date': '2009-05-08 09:25:05',
#    'changeDate': '2009-05-08 09:25:05',
#    'count': 1,
#    'url': 'http://www.infochembio.ethz.ch/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/3549ba6f6d248fd1da99fc91de04b2fa/mdrechsler',
#    'tags': ['biographies'],
#    'intraHash': '3549ba6f6d248fd1da99fc91de04b2fa',
#    'label': 'Biographie de Ivan Illich',
#    'user': 'mdrechsler',
#    'description': 'Ivan illich, un homme fascinant par ses (tags: biographies)',
#    'date': '2008-08-02 19:04:23',
#    'changeDate': '2009-03-16 18:53:19',
#    'count': 1,
#    'url': 'http://savoirscdi.cndp.fr/culturepro/biographie/illich/illich.htm'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/16ba0b41a23bba329e5ea9eb2013de41/mdrechsler',
#    'tags': [],
#    'intraHash': '16ba0b41a23bba329e5ea9eb2013de41',
#    'label': "Le plus féroce des loups - JClic.Edu le portail des activités JClic pour l'école",
#    'user': 'mdrechsler',
#    'description': '(tags: logiciels libre jclic)',
#    'date': '2008-08-02 19:04:23',
#    'changeDate': '2008-08-02 19:04:23',
#    'count': 1,
#    'url': 'http://jclic.clicapplic.net/spip.php?article93'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/20a170ec30187fcd081ee9d855d97386/domwass',
#    'tags': ['landkarten'],
#    'intraHash': '20a170ec30187fcd081ee9d855d97386',
#    'label': 'Die Welt der Karten',
#    'user': 'domwass',
#    'description': 'Portal der Uni Zürich rund um das Kartenwesen',
#    'date': '2006-08-21 14:30:08',
#    'changeDate': '2007-03-15 12:53:32',
#    'count': 4,
#    'url': 'http://www.maps.ethz.ch/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/7f410414369640c4acf65383b289dd06/lysander07',
#    'tags': ['searchengine', 'annotation', 'presentation', '2007', 'mpeg-7'],
#    'intraHash': '7f410414369640c4acf65383b289dd06',
#    'label': 'H. Sack: Effiziente Suche in Multimediadaten durch automatische und kollaborative Annptation',
#    'user': 'lysander07',
#    'description': 'Präsentation an der ETH Zürich, 18. Oktober 2007\r\nin Deutsch',
#    'date': '2006-10-20 12:57:14',
#    'changeDate': '2009-01-28 19:07:51',
#    'count': 1,
#    'url': 'http://www.db-thueringen.de/servlets/DerivateServlet/Derivate-9872/osotis.pdf'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/47b688fe157f46d8991c2e7b0c51402b/zettel',
#    'tags': ['literatur', 'Dostojewskij'],
#    'intraHash': '47b688fe157f46d8991c2e7b0c51402b',
#    'label': 'Deutschlandradio Kultur - Kritik - Universum eines Schriftstellers',
#    'user': 'zettel',
#    'description': 'Fjodor Dostojewski: "Der Spieler", Ammann Verlag, Zürich 2009, 231 Seiten',
#    'date': '2010-08-12 17:16:12',
#    'changeDate': '2011-03-10 11:47:15',
#    'count': 1,
#    'url': 'http://www.dradio.de/dkultur/sendungen/kritik/1098607/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/b49c868398427b38519d434844575c71/mdrechsler',
#    'tags': [],
#    'intraHash': 'b49c868398427b38519d434844575c71',
#    'label': "ClicLire aide à l'apprentissage de la lecture",
#    'user': 'mdrechsler',
#    'description': "Exercices d'aide pour l'apprentissage à la lecture avec JCLIC (tags: prélecture logiciels libre lecture jclic cycle2 combinatoire)",
#    'date': '2008-08-02 19:04:23',
#    'changeDate': '2008-08-02 19:04:23',
#    'count': 1,
#    'url': 'http://cliclire.free.fr'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/5d918f870da047071f13461cda0182fe/robingarcia',
#    'tags': ['Weitere_Lesezeichen'],
#    'intraHash': '5d918f870da047071f13461cda0182fe',
#    'label': 'sayes, coaching, psychotherapie, schwerhörigkeit, auftrittskompetenz, kommunikation, Barbara Goossens, Zürich',
#    'user': 'robingarcia',
#    'description': 'sayes, coaching, psychotherapie, schwerhörigkeit, auftrittskompetenz, kommunikation, Barbara Goossens, Zürich',
#    'date': '2017-03-17 10:35:12',
#    'changeDate': '2017-04-13 10:01:45',
#    'count': 1,
#    'url': 'http://www.sayes.ch/ueber-mich.html'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9fa4ce5486e38e6edf29fadbc90053a4/mc.k',
#    'tags': ['resume', 'howto', 'application', 'google', 'job'],
#    'intraHash': '9fa4ce5486e38e6edf29fadbc90053a4',
#    'label': 'Google Job Opportunities: Zurich',
#    'user': 'mc.k',
#    'description': 'howto apply at google in Zürich, how to write a resume',
#    'date': '2006-06-04 18:47:51',
#    'changeDate': '2006-06-04 18:47:51',
#    'count': 2,
#    'url': 'http://www.google.ch/intl/en/jobs/#apply'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/79381e6bf408fb6a474d0379d5e9d856/hansgeorgbecker',
#    'tags': ['Ranking', 'Kriterien', '#inetbib10', 'Katalog', 'Suchmaschine'],
#    'intraHash': '79381e6bf408fb6a474d0379d5e9d856',
#    'label': 'Sortierung von Suchergebnissen',
#    'user': 'hansgeorgbecker',
#    'description': 'Kurzvortrag auf der Inetbib-Tagung 2010, Zürich, 16. April 2010',
#    'date': '2010-04-16 09:21:29',
#    'changeDate': '2011-04-26 10:30:38',
#    'count': 1,
#    'url': 'http://www.slideshare.net/tillk/lt-inetbib'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/23aa16d65f7bd8639926cab7c53374f4/mauszfabrick',
#    'tags': ['tv',
#     'vampire',
#     'fernsehserie',
#     'wiki',
#     'vampirkulturen',
#     'trueblood',
#     'fernsehen',
#     'serie'],
#    'intraHash': '23aa16d65f7bd8639926cab7c53374f4',
#    'label': 'True Blood Wiki',
#    'user': 'mauszfabrick',
#    'description': 'true blood fanwiki, wie üblich sehr gut mit episodeguide etc.pp.',
#    'date': '2011-09-29 12:56:41',
#    'changeDate': '2011-09-30 08:34:50',
#    'count': 1,
#    'url': 'http://trueblood.wikia.com/wiki/True_Blood_Wiki'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/52468c926f24061bddbb38f0fe20eef8/dblp',
#    'tags': ['dblp'],
#    'intraHash': '52468c926f24061bddbb38f0fe20eef8',
#    'label': 'Home Page of Massimiliano Nolich',
#    'user': 'dblp',
#    'description': 'homepages/41/191,\nMassimiliano Nolich, Home Page, https://www.wikidata.org/entity/Q92119302',
#    'date': '2020-05-13 12:36:45',
#    'changeDate': '2020-05-13 12:36:45',
#    'count': 1,
#    'url': 'https://www.wikidata.org/entity/Q92119302'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/9e421b9c85a4b7d525c56b353f7841cd/textundblog',
#    'tags': ['css3', 'webdesign', 'farben', 'importmw'],
#    'intraHash': '9e421b9c85a4b7d525c56b353f7841cd',
#    'label': 'Farbverlufe (Gradients) mit CSS3 | WordPress & Webwork',
#    'user': 'textundblog',
#    'description': 'Das ist bei weitem nicht alles was mit CSS3 mglich ist, wie der Artikel CSS gradients for all web browsers und der Eintrag in der Mozilla-Dokumentation es deutlich zeigen. Es ist nicht nur mglich lineare sondern auch radiale Verlufe zu erzeugen.  Das ganze ist nicht nur in Firefox sondern auch in anderen Browser mglich.   (tags: webdesign css3 farben)',
#    'date': '2013-06-28 16:41:21',
#    'changeDate': '2013-06-28 16:41:21',
#    'count': 1,
#    'url': 'http://www.perun.net/2011/11/20/farbverlaeufe-gradients-mit-css3/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/fa32af5a7f662723ef0e8f00a6a8b056/dblp',
#    'tags': ['dblp'],
#    'intraHash': 'fa32af5a7f662723ef0e8f00a6a8b056',
#    'label': 'Home Page of Philipp Grohs',
#    'user': 'dblp',
#    'description': 'homepages/11/7839,\nPhilipp Grohs, Home Page, http://www.sam.math.ethz.ch/~pgrohs/, ETH Zürich, Switzerland',
#    'date': '2016-03-25 11:37:46',
#    'changeDate': '2016-03-25 11:37:46',
#    'count': 1,
#    'url': 'http://www.sam.math.ethz.ch/~pgrohs/'},
#   {'type': 'Bookmark',
#    'id': 'https://www.bibsonomy.org/url/0d0496471687d0f16f3b46685085b60b/blostben',
#    'tags': ['writing', 'Schreiben', 'wissenschaftliches-Arbeiten'],
#    'intraHash': '0d0496471687d0f16f3b46685085b60b',
#    'label': 'EDINGER Vom Datenmaterial zur Publikation. Wissenschaftliches Schreib…',
#    'user': 'blostben',
#    'description': 'Präsentation zum Vortrag am 24. November 2016, am Zentrum für Qualitiative Sozialforschung Zürich',
# ...
#    'count': 1,
#    'pub-type': 'inproceedings',
#    'booktitle': 'AMCIS',
#    'publisher': 'Association for Information Systems',
#    'year': '2005',
#    'url': 'http://dblp.uni-trier.de/db/conf/amcis/amcis2005.html#Erlich05',
#    'author': ['Donna M. Erlich'],
#    'authors': [{'first': 'Donna M.', 'last': 'Erlich'}],
#    'editor': ['Deepak Khazanchi', 'Ilze Zigurs'],
#    'editors': [{'first': 'Deepak', 'last': 'Khazanchi'},
#     {'first': 'Ilze', 'last': 'Zigurs'}],
#    'pages': '147',
#    'ee': 'http://aisel.aisnet.org/amcis2005/147',
#    'bibtexKey': 'conf/amcis/Erlich05'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/20cee2fe3419e61e5125c487368a244ed/genealogie',
#    'tags': ['Chemie', 'dnb'],
#    'intraHash': '0cee2fe3419e61e5125c487368a244ed',
#    'interHash': '38d998344f9ac6d7bb0cc1bfbf51b6a3',
#    'label': 'Oxidative Dimerisierung von Enolaten chiraler Carbonsäurederivate',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2015-09-09 10:35:07',
#    'changeDate': '2015-09-09 12:31:17',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '1992',
#    'url': '',
#    'author': ['Michael Georg Illich'],
#    'authors': [{'first': 'Michael Georg', 'last': 'Illich'}],
#    'dnbtitleid': '941470288',
#    'bibtexKey': 'illich1992oxidative'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/21ae1a1eb689f9cce1959a457b2838fdd/dblp',
#    'tags': ['dblp'],
#    'intraHash': '1ae1a1eb689f9cce1959a457b2838fdd',
#    'interHash': '673962450c69d4803def2e4ce937776f',
#    'label': 'Experiences on bio-medical sensing using ultra wideband communications and radar technology.',
#    'user': 'dblp',
#    'description': '',
#    'date': '2020-07-03 00:00:00',
#    'changeDate': '2020-07-04 11:55:17',
#    'count': 1,
#    'pub-type': 'article',
#    'journal': 'Int. J. Ultra Wideband Commun. Syst.',
#    'year': '2010',
#    'url': 'http://dblp.uni-trier.de/db/journals/ijuwbcs/ijuwbcs1.html#Bilich10',
#    'author': ['Carlos G. Bilich'],
#    'authors': [{'first': 'Carlos G.', 'last': 'Bilich'}],
#    'volume': '1',
#    'number': '4',
#    'pages': '248-262',
#    'ee': 'https://doi.org/10.1504/IJUWBCS.2010.034306',
#    'bibtexKey': 'journals/ijuwbcs/Bilich10'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2dd3b66ff30b42a92b7b0d01fc9ff1e41/sieber',
#    'tags': ['myown', 'Eide'],
#    'intraHash': 'dd3b66ff30b42a92b7b0d01fc9ff1e41',
#    'interHash': '82c58606c97003007a27beee7a15734a',
#    'label': 'Eidleistungen und Schwörtage im spätmittelalterlichen Zürich',
#    'user': 'sieber',
#    'description': '',
#    'date': '2015-05-04 12:11:51',
#    'changeDate': '2015-05-04 12:14:08',
#    'count': 4,
#    'pub-type': 'incollection',
#    'booktitle': 'Zürich 650 Jahre eidgenössisch',
#    'address': 'Zürich',
#    'year': '2001',
#    'url': '',
#    'author': ['Christian Sieber'],
#    'authors': [{'first': 'Christian', 'last': 'Sieber'}],
#    'editor': ['Staatsarchiv des Kantons Zürich', 'Zentralbibliothek Zürich'],
#    'editors': [{'first': 'Staatsarchiv', 'last': 'des Kantons Zürich'},
#     {'first': 'Zentralbibliothek', 'last': 'Zürich'}],
#    'pages': '19-58',
#    'abstract': 'Sieber, Eidleistungen',
#    'bibtexKey': 'VuFind-193734400'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2c5811e416bda7a64a79ee8238ce83fc3/fbw_hannover',
#    'tags': ['Lagerplanung',
#     'Materialwirtschaft',
#     'Wechselbehälter',
#     'Güterverkehr',
#     'Kombinierter_Verkehr',
#     'Beschaffung'],
#    'intraHash': 'c5811e416bda7a64a79ee8238ce83fc3',
#    'interHash': '94ec9ce1a6d54832aac02474d199b031',
#    'label': 'Entlastung der Straße durch ein innovatives technisch-organisatorisches Gesamtkonzept mit Wechselbrücken, Phase 1: Machbarkeitsstudie',
#    'user': 'fbw_hannover',
#    'description': '',
#    'date': '2009-08-21 12:15:08',
#    'changeDate': '2009-08-21 12:15:30',
#    'count': 2,
#    'pub-type': 'online',
#    'address': 'Hannover',
#    'year': '2002',
#    'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+364076240&sourceid=fbw_bibsonomy',
#    'editor': ['Crispin Mühlich'],
#    'editors': [{'first': 'Crispin', 'last': 'Mühlich'}],
#    'subtitle': 'Abschlussbericht',
#    'pagetotal': 'Online-Ressource (60 p., 2,14 Mb.)',
#    'ppn_gvk': '364076240',
#    'bibtexKey': 'GVK364076240'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2e85d1969b9d07a3033b5421a41225ac1/antares',
#    'tags': ['urheberrecht', 'OpenAccess', 'schweiz'],
#    'intraHash': 'e85d1969b9d07a3033b5421a41225ac1',
#    'interHash': 'f9ed6212f87066c185a65584c056d84c',
#    'label': 'Open Access - Zugang zu wissenschaftlichen Publikationen im schweizerischen Recht',
#    'user': 'antares',
#    'description': '',
#    'date': '2010-04-07 09:52:23',
#    'changeDate': '2010-04-07 09:52:23',
#    'count': 1,
#    'pub-type': 'techreport',
#    'year': '2009',
#    'url': 'http://www.oai.uzh.ch/images/stories/oa_medien/oa_rechtsgutachten_hilty.pdf',
#    'author': ['Reto M. Hilty', 'Matthias Seemann'],
#    'authors': [{'first': 'Reto M.', 'last': 'Hilty'},
#     {'first': 'Matthias', 'last': 'Seemann'}],
#    'editor': ['Universität Zürich'],
#    'editors': [{'first': 'Universität', 'last': 'Zürich'}],
#    'bibtexKey': 'hilty2009access'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/25608d112b1fa453a56b7a86d5d2d66e4/dblp',
#    'tags': ['dblp'],
#    'intraHash': '5608d112b1fa453a56b7a86d5d2d66e4',
#    'interHash': 'a73ec33f64c50c657474be2f47e8d5d0',
#    'label': 'On the Performance of COBOL Programs in Large vs. Mini Computers.',
#    'user': 'dblp',
#    'description': '',
#    'date': '2020-04-09 00:00:00',
#    'changeDate': '2020-04-10 11:53:29',
#    'count': 1,
#    'pub-type': 'article',
#    'journal': 'Softw. Pract. Exp.',
#    'year': '1982',
#    'url': 'http://dblp.uni-trier.de/db/journals/spe/spe12.html#Jalics82',
#    'author': ['Paul J. Jalics'],
#    'authors': [{'first': 'Paul J.', 'last': 'Jalics'}],
#    'volume': '12',
#    'number': '2',
#    'pages': '103-114',
#    'ee': 'https://doi.org/10.1002/spe.4380120202',
#    'bibtexKey': 'journals/spe/Jalics82'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/201ffc0bf6a419250c7a2efa71ebfb3b8/genealogie',
#    'tags': ['dnb', 'Gesundheit', 'Medizin'],
#    'intraHash': '01ffc0bf6a419250c7a2efa71ebfb3b8',
#    'interHash': 'f08535dc5524cd4e44b9ae2a9897c272',
#    'label': 'Die Bedeutung der Matrix-Metalloproteinase-9 (MMP-9) für die Prognose von PatientInnen mit koronarer Herzkrankheit',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2015-09-09 21:11:03',
#    'changeDate': '2015-09-09 21:11:03',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '2003',
#    'url': '',
#    'author': ['Daniel Klaus Gütlich'],
#    'authors': [{'first': 'Daniel Klaus', 'last': 'Gütlich'}],
#    'dnbtitleid': '969845707',
#    'bibtexKey': 'gutlich2003bedeutung'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/24d655ae52d063f0fe684a6d59b42b7c7/genealogie',
#    'tags': ['dnb', 'Gesundheit', 'Biologie', 'Medizin'],
#    'intraHash': '4d655ae52d063f0fe684a6d59b42b7c7',
#    'interHash': '257f8b126732b29fb11dc447228af454',
#    'label': 'Einfluss des Tumorpromotors Phorbol-Myristat-Acetat auf die Aktivität des Plasminogen-Aktivators in Zellkulturen von Patienten mit Neurofibromatose (v. Recklinghausen)',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2015-09-09 08:31:36',
#    'changeDate': '2015-09-09 08:31:36',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '1989',
#    'url': '',
#    'author': ['Markus Sebastian Gulich'],
#    'authors': [{'first': 'Markus Sebastian', 'last': 'Gulich'}],
#    'dnbtitleid': '891600329',
#    'bibtexKey': 'gulich1989einfluss'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/26ddaab18c3d0d67c7e10a3194d6f866b/genealogie',
#    'tags': ['dnb'],
#    'intraHash': '6ddaab18c3d0d67c7e10a3194d6f866b',
#    'interHash': 'eb473a1c87fb4a286d100718b70aae5c',
#    'label': 'Direkte Steuern in Jugoslawien: Ihre Moral u. Technik',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2016-05-31 02:16:02',
#    'changeDate': '2016-05-31 02:16:02',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '1939',
#    'url': '',
#    'author': ['Dušan Jovanović-Jolić'],
#    'authors': [{'first': 'Dušan', 'last': 'Jovanović-Jolić'}],
#    'dnbtitleid': '570751616',
#    'bibtexKey': 'jovanovicjolic1939direkte'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2fa076ceccf033083e3c8199fed42811c/genealogie',
#    'tags': ['dnb', 'Ingenieurbau_und_Umwelttechnik'],
#    'intraHash': 'fa076ceccf033083e3c8199fed42811c',
#    'interHash': 'cff4a7f6e9d7ec98e8f00c5b76c64f2f',
#    'label': '\x98Ein\x9c Beitrag zur allgemeinen Beschreibung des Tragverhaltens von schlanken Betondruckgliedern',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2016-05-30 21:01:57',
#    'changeDate': '2016-05-30 21:01:57',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '2015',
#    'url': '',
#    'author': ['Günther Werner Illich'],
#    'authors': [{'first': 'Günther Werner', 'last': 'Illich'}],
#    'dnbtitleid': '1073598039',
#    'bibtexKey': 'illich2015beitrag'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2dd3b66ff30b42a92b7b0d01fc9ff1e41/mischaffner16',
#    'tags': ['Eid'],
#    'intraHash': 'dd3b66ff30b42a92b7b0d01fc9ff1e41',
#    'interHash': '82c58606c97003007a27beee7a15734a',
#    'label': 'Eidleistungen und Schwörtage im spätmittelalterlichen Zürich',
#    'user': 'mischaffner16',
#    'description': 'Behandelt die Bedeutung von Eidleistungen in den Bereichen Stadt (Schwörtag und Bürgereid), Landschaft (Untertaneneid), Reich (Huldigung), Herrschaft Österreich (Bündniseide) und Eidgenossenschaft (Neubeschwörungen der Bünde).',
#    'date': '2017-01-24 10:52:53',
#    'changeDate': '2017-01-24 16:08:48',
#    'count': 4,
#    'pub-type': 'incollection',
#    'booktitle': 'Zürich 650 Jahre eidgenössisch',
#    'address': 'Zürich',
#    'year': '2001',
#    'url': '',
#    'author': ['Christian Sieber'],
#    'authors': [{'first': 'Christian', 'last': 'Sieber'}],
#    'editor': ['Staatsarchiv des Kantons Zürich', 'Zentralbibliothek Zürich'],
#    'editors': [{'first': 'Staatsarchiv', 'last': 'des Kantons Zürich'},
#     {'first': 'Zentralbibliothek', 'last': 'Zürich'}],
#    'pages': '19-58',
#    'abstract': 'Sieber 2001',
#    'bibtexKey': 'VuFind-193734400'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/23321bbb339c0506d0ab0295f0c8c0c08/eladnoor',
#    'tags': ['imported'],
#    'intraHash': '3321bbb339c0506d0ab0295f0c8c0c08',
#    'interHash': '8a8943111c5578f483abee0261dee23e',
#    'label': 'SUMOFLUX: A Generalized Method for Targeted 13C Metabolic Flux Ratio Analysis',
#    'user': 'eladnoor',
#    'description': '',
#    'date': '2017-09-19 09:22:19',
#    'changeDate': '2017-09-19 09:22:19',
#    'count': 2,
#    'pub-type': 'article',
#    'journal': 'PLoS Comput. Biol.',
#    'year': '2016',
#    'url': '',
#    'author': ['Maria Kogadeeva', 'Nicola Zamboni'],
#    'authors': [{'first': 'Maria', 'last': 'Kogadeeva'},
#     {'first': 'Nicola', 'last': 'Zamboni'}],
#    'volume': '12',
#    'number': '9',
#    'pages': 'e1005109',
#    'affiliation': 'Institute of Molecular Systems Biology, ETH Zürich, Zürich, Switzerland. Life Science Zürich Graduate School, Zürich, Switzerland. Institute of Molecular Systems Biology, ETH Zürich, Zürich, Switzerland.',
#    'language': 'en',
#    'bibtexKey': 'Kogadeeva2016-yf'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2f6d8d90f390c958f12a08ec6e2a70d58/pedocs',
#    'tags': ['Weiterbildung',
#     'Integration',
#     'Lernen',
#     'Nordrhein-Westfalen',
#     'Bildungspolitik',
#     'Erwachsenenbildung',
#     'Ausländerpolitik',
#     'Netzwerk',
#     'Arbeitswelt',
#     'Deutschland',
#     'Bildungsangebot',
#     'Politische_Bildung',
#     'Region'],
#    'intraHash': 'f6d8d90f390c958f12a08ec6e2a70d58',
#    'interHash': '82c6a229a6eb303969ab28956abbf8b0',
#    'label': 'Netze und lose Fäden. Politische Bildung gegen gesellschaftliche Desintegration',
#    'user': 'pedocs',
#    'description': '',
#    'date': '2010-12-20 19:32:13',
#    'changeDate': '2010-12-20 19:32:17',
#    'count': 1,
#    'pub-type': 'book',
#    'publisher': 'Wochenschau-Verl.',
#    'address': 'Schwalbach, Taunus',
#    'year': '2002',
#    'url': 'http://www.pedocs.de/volltexte/2009/1880',
#    'editor': ['Günter Schneider', 'Franz-Josef Jelich'],
#    'editors': [{'first': 'Günter', 'last': 'Schneider'},
#     {'first': 'Franz-Josef', 'last': 'Jelich'}],
#    'abstract': 'Die Begriffe "Netz" und "Netzwerk" bestimmen allerorten den Diskurs - von der Biologie bis zur Philosophie, von der Politik bis zur Ökonomie und nicht zuletzt auch im Bereich von Bildung und Weiterbildung. Offensichtlich eignet sich der Terminus "Netzwerk" für Gestaltungsansätze in Ökonomie, Politik und Kultur, mit denen aktiv Prozessen der Desintegration und Entgrenzung entgegengearbeitet wird, wie sie mit den Schlagworten Individualisierung, Flexibilisierung, Deregulierung, Globalisierung... benannt werden. Eine reflektierte Auseinandersetzung mit veränderten Anforderungen an Gesellschaft und Kultur, an Bildung und Weiterbildung im gegenwärtigen gesellschaftlichen Transformationsprozess soll mit dem vorliegenden Band geleistet werden. Darüber hinaus werden Projektzusammenhänge gegenwärtiger Bildungsarbeit von Arbeit und Leben unter der Perspektive von Netzwerkgründungen vor- und dargestellt. Der Band enthält Beiträge zur Bedeutung von Netzwerken für die Veränderung von Ökonomie, Politik und Kultur, die Veränderung von Bildung und Weiterbildung, die Veränderung von Bildungsorganisation und Weiterbildungsangeboten. (DIPF/Orig.).',
#    'isbn': '3-87920-086-6',
#    'bibtexKey': 'Schneider.2002'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2880e048a2349f038ac124f2e7d7d4afe/genealogie',
#    'tags': ['dnb'],
#    'intraHash': '880e048a2349f038ac124f2e7d7d4afe',
#    'interHash': 'f9df0cec33d6207551df003df6775aff',
#    'label': 'Arbeiten zur o-Phenanthrolin-Synthese',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2015-09-08 20:43:37',
#    'changeDate': '2015-09-08 20:43:37',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '1934',
#    'url': '',
#    'author': ['Hanns-Rolf Lüllich'],
#    'authors': [{'first': 'Hanns-Rolf', 'last': 'Lüllich'}],
#    'dnbtitleid': '570867002',
#    'bibtexKey': 'lullich1934arbeiten'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/2000c6ccd514a668e8f29e4c7d339f4b2/genealogie',
#    'tags': ['Landwirtschaft',
#     'Landschaftsgestaltung',
#     'Raumplanung',
#     'dnb',
#     'Land_und_Forstwissenschaft',
#     'Veterinärmedizin'],
#    'intraHash': '000c6ccd514a668e8f29e4c7d339f4b2',
#    'interHash': 'b6519ae81c1b344dd1ca0d6f2cd5432b',
#    'label': 'Der Nadelschnittholzmarkt und -verbrauch der Niederlande mit besonderer Berücksichtigung des baden-württembergischen Beschaffungsmarktes: Grundlagen und Ergebnisse einer empirischen Marktforschung',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2015-09-09 02:07:17',
#    'changeDate': '2015-09-09 02:07:17',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '1977',
#    'url': '',
#    'author': ['August-Wilhelm Jülicher'],
#    'authors': [{'first': 'August-Wilhelm', 'last': 'Jülicher'}],
#    'dnbtitleid': '780833325',
#    'bibtexKey': 'julicher1977nadelschnittholzmarkt'},
#   {'type': 'Publication',
#    'id': 'https://www.bibsonomy.org/bibtex/286b97af8efdd85eae7c6a4f04342fdca/genealogie',
#    'tags': ['Englische_Literatur_Amerikas', 'dnb'],
#    'intraHash': '86b97af8efdd85eae7c6a4f04342fdca',
#    'interHash': '96cf2730749fefd2f6f40438ecf3c883',
#    'label': 'Die Darstellung des Sterbensprozesses im neueren amerikanischen Drama',
#    'user': 'genealogie',
#    'description': '',
#    'date': '2015-09-10 01:19:25',
#    'changeDate': '2015-09-10 02:02:52',
#    'count': 1,
#    'pub-type': 'phdthesis',
#    'year': '2007',
#    'url': '',
#    'author': ['Julica Mareike Zacharias'],
#    'authors': [{'first': 'Julica Mareike', 'last': 'Zacharias'}],
#    'dnbtitleid': '990806693',
#    'bibtexKey': 'zacharias2007darstellung'},
#   ...]}

# %%
search_engine_mult = pt.BatchRetrieve(index_mult, vmodel="TF_IDF")
search_engine_mult2 = pt.BatchRetrieve(index_mult, vmodel="BM25")

# %%
search_engine_mult.search("intelligence")
# Out:
# BR(DPH): 100%|█████████████████████████████████████| 1/1 [00:00<00:00,  6.18q/s]
#   qid  docid                                              docno  rank  \
# 0   1    889  https://www.bibsonomy.org/bibtex/225cc15aa8abc...     0
# 1   1    745  https://www.bibsonomy.org/bibtex/205de7939eb62...     1
#
#       score         query
# 0  4.615414  intelligence
# 1  4.606457  intelligence

# %%
search_engine_mult2.search("intellicence")
# Out:
# BR(DPH): 100%|█████████████████████████████████████| 1/1 [00:00<00:00,  3.51q/s]
# Empty DataFrame
# Columns: [docid, docno, rank, score, qid, query]
# Index: []

# %%
search_engine_mult.search("cosi")
# Out:
# BR(DPH): 100%|█████████████████████████████████████| 1/1 [00:00<00:00, 11.77q/s]
#   qid  docid                                              docno  rank  \
# 0   1     72  https://www.bibsonomy.org/bibtex/2803c410487bc...     0
# 1   1     92  https://www.bibsonomy.org/bibtex/20fafe3019649...     1
# 2   1     93  https://www.bibsonomy.org/bibtex/262261cab9960...     2
# 3   1     97  https://www.bibsonomy.org/bibtex/2b300bdefc3c7...     3
# 4   1    130  https://www.bibsonomy.org/bibtex/2f499d8f2002d...     4
# 5   1    106  https://www.bibsonomy.org/bibtex/23f4d61e3f749...     5
# 6   1    105  https://www.bibsonomy.org/bibtex/2897adac82e37...     6
# 7   1    146  https://www.bibsonomy.org/bibtex/2ab86fc6c0b77...     7
# 8   1    153  https://www.bibsonomy.org/bibtex/2d7f851a98d99...     8
# 9   1    161  https://www.bibsonomy.org/bibtex/2e0c4d9fd5954...     9
#
#       score query
# 0  3.603503  cosi
# 1  3.538546  cosi
# 2  3.538546  cosi
# 3  3.538546  cosi
# 4  3.524819  cosi
# 5  3.510775  cosi
# 6  3.482129  cosi
# 7  3.453208  cosi
# 8  3.424389  cosi
# 9  3.424389  cosi

# %%
search_engine_mult2.search("cosi")
# Out:
# BR(DPH): 100%|█████████████████████████████████████| 1/1 [00:00<00:00, 18.67q/s]
#   qid  docid                                              docno  rank  \
# 0   1     72  https://www.bibsonomy.org/bibtex/2803c410487bc...     0
# 1   1     92  https://www.bibsonomy.org/bibtex/20fafe3019649...     1
# 2   1     93  https://www.bibsonomy.org/bibtex/262261cab9960...     2
# 3   1     97  https://www.bibsonomy.org/bibtex/2b300bdefc3c7...     3
# 4   1    130  https://www.bibsonomy.org/bibtex/2f499d8f2002d...     4
# 5   1    106  https://www.bibsonomy.org/bibtex/23f4d61e3f749...     5
# 6   1    105  https://www.bibsonomy.org/bibtex/2897adac82e37...     6
# 7   1    146  https://www.bibsonomy.org/bibtex/2ab86fc6c0b77...     7
# 8   1    153  https://www.bibsonomy.org/bibtex/2d7f851a98d99...     8
# 9   1    161  https://www.bibsonomy.org/bibtex/2e0c4d9fd5954...     9
#
#       score query
# 0  3.603503  cosi
# 1  3.538546  cosi
# 2  3.538546  cosi
# 3  3.538546  cosi
# 4  3.524819  cosi
# 5  3.510775  cosi
# 6  3.482129  cosi
# 7  3.453208  cosi
# 8  3.424389  cosi
# 9  3.424389  cosi
