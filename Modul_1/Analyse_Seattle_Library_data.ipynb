# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7fc729bd6ad0>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997    Digital      Freegal         SONG          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
# 9999   Physical      Horizon    SOUNDDISC          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
checkouts_df[checkouts_df["materialtype"] == "BOOK" ]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 7      Physical      Horizon         BOOK          2018              2
# 20     Physical      Horizon         BOOK          2018              3
# 25     Physical      Horizon         BOOK          2018              3
# 30     Physical      Horizon         BOOK          2018              3
# 43     Physical      Horizon         BOOK          2018              8
# ...         ...          ...          ...           ...            ...
# 9985   Physical      Horizon         BOOK          2018              1
# 9986   Physical      Horizon         BOOK          2018              1
# 9987   Physical      Horizon         BOOK          2018              1
# 9990   Physical      Horizon         BOOK          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
checkouts_books_df = checkouts_df[checkouts_df["materialtype"] == "BOOK" ]

# %%
checkouts_books_df.shape
# Out:
# (4268, 12)

# %%
checkouts_books_df.to_csv("checkout_books_only.csv")

# %%
checkouts_df["creator"].value_counts()
# Out:
# creator
# Agatha Christie               14
# James Patterson               13
# Mary Pope Osborne              9
# Elvis Presley                  8
# John Williams                  8
#                               ..
# Cutler, Judith                 1
# Palahniuk, Chuck               1
# Polacco, Patricia              1
# Bechtold, Alan R., 1952-       1
# Brzezinski, Matthew, 1965-     1
# Name: count, Length: 7220, dtype: int64

# %%
# %matplotlib inline

# %%
checkouts_df["materialtype"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='materialtype'>

# %%
checkouts_df["materialtype"].value_counts().plot(kind='bar', color="#FF4040")
# Out:
# <Axes: xlabel='materialtype'>
